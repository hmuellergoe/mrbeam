# %% [markdown]
# This tutorial shows the complete pipeline for the analysis of sparse VLBI data with the ring-image observed with EHT2017 coverage. Many cells are explained in previous tutorials.

# %%
#-------------------------------------------------------------------------------
# Modules
#-------------------------------------------------------------------------------
import ehtim as eh
import numpy as np

from imagingbase.ehtim_calibration import Calibrator
from imagingbase.minimization_handler import MinimizationHandler

import ehtplot.color
cfun = 'afmhot_u'

import pathlib 
current_path = str(pathlib.Path().absolute())

import logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s %(levelname)s %(name)-20s :: %(message)s'
)
# Out:
# Welcome to eht-imaging! v 1.2.4

# %%
#-------------------------------------------------------------------------------
# Fixed imaging parameters
#-------------------------------------------------------------------------------
ttype     = 'direct'            # Type of Fourier transform ('direct', 'nfft', or 'fast')

zbl       = 0.6                 # Total compact flux density (Jy)
npix      = 128                 # Number of pixels across the reconstructed image
fov       = 2*128*eh.RADPERUAS    # Field of view of the reconstructed image

prior_fwhm = 40.0*eh.RADPERUAS  # Gaussian prior FWHM (radians)
sys_noise  = 0.02               # fractional systematic noise
                                # added to complex visibilities
                                                               
#data weights
data_term = {'amp'    : 0.2,    # visibility amplitudes
             'cphase' : 1.0,    # closure phases
             'logcamp': 1.0}    # log closure amplitudes

stop      = 1e-4                # Imager stopping criterion
gain_tol  = [0.02,0.2]          # Asymmetric gain tolerance for self-cal; we expect larger values
                                # for unaccounted sensitivity loss
                                # than for unaccounted sensitivity improvement
uv_zblcut = 0.1e9               # uv-distance that separates the inter-site "zero"-baselines
                                # from intra-site baselines
zero_baseline = ['AA', 'AP']    # baseline to measure zero-spacing flux
rescaling = 0.0001              # rescale intensities per pixel to obtain values of the order ~1

cbar_lims = [0, 8*10**9]       #cbar-lims for interactive plotting (brightness temperature)

# %% [markdown]
# Prepare data set, see tutorial 3

# %%
#-------------------------------------------------------------------------------
# Observe synthetic image and reduce/precalibrate synthetic observation
#-------------------------------------------------------------------------------

obs = eh.obsdata.load_uvfits(current_path+r'/../synthetic_data/ring_eht2017.uvfits')

#calibration object
cal = Calibrator(obs, zero_baseline, zbl, uv_zblcut, 0, sys_noise)
#prepare (coherently average) data
cal.prepare_data()
#precalibrate data
cal.precalibrate_data()

obs_sc = cal.obs_sc #precalibrated and reduced data set

exact_solution = eh.image.load_fits(current_path+r'/../synthetic_data/ring.fits')

exact_solution.display()

res = obs_sc.res()
# Out:
# Loading uvfits:  /homes/hmueller/mr_beam/synthesis_regpy/examples/../synthetic_data/ring_eht2017.uvfits
# no IF in uvfits header!
# POLREP_UVFITS: circ
# Number of uvfits Correlation Products: 4
# No NX table in uvfits!
# /aux/vlb051a/anaconda3/envs/mrbeam/lib/python3.10/site-packages/ehtim/obsdata.py:509: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(datalist)
# Warning: Specified total compact flux density exceeds total flux density
# Loading fits image:  /homes/hmueller/mr_beam/synthesis_regpy/examples/../synthetic_data/ring.fits

# %%
prior = eh.image.make_square(obs_sc, npix, fov) #prior image, make a prior image
prior = prior.add_gauss(zbl, (prior_fwhm, prior_fwhm, 0, 0, 0))
prior = prior.add_gauss(1e-2*zbl, (prior_fwhm, prior_fwhm, 0, prior_fwhm, prior_fwhm))

# %% [markdown]
# This time we fit the widths of the wavelets to the array. Moreover, we add wavelet filters with the size of 1 pixels, 2 pixels and 4 pixels to complete the dictionary down to the pixel scale. However, these scales will be suppressed during imaging procedure.

# %%
#------------------------------------------------------------------------------
# Prepare Minimization Procedure
#------------------------------------------------------------------------------
#clean beam fwhm
psf_fwhm = 20*eh.RADPERUAS

#threshold for identifying gaps in uv-coverage
threshold = 0.15*10**9
#add short baselines wavelets 
short_bl_wl=[39.98, 47.24]
#add long baseline wavelets
long_bl_wl=[1, 2, 4]
#the final handler for the minimization procedure
handler = MinimizationHandler(psf_fwhm, npix, fov, obs_sc, prior, zbl, rescaling, data_term, cbar_lims, threshold, short_bl_wl, long_bl_wl) 
#widths of wavelet filters
widths = handler.widths
# Out:
# Generating I image...
# Generating I image...
# Generating I image...
# Generating I image...

# %% [markdown]
# Instead of the dirty map, we are using an unpenalized ehtim reconstruction here to define an initial guess. The reconstruction is done with alternative blurring with the resolution of the observation to help global convergence in five cycles. The ehtim reconstruction is done internally by MrBeam by the command handler.first_round. Moreover, after each imaging round self-calibration could be done. Everytime the observation file is updated externally, the handler should be updated with the new observation file, i.e. the wrapper and functionals to the amplitude, phase, closure phase and closure amplitude are updated.

# %%
#------------------------------------------------------------------------------
# First round of imaging: Unconstrained ehtim reconstruction
# alternating imaging and blurring to help global convergence
#------------------------------------------------------------------------------
print("Round 1: Unconstrained Imaging with visibility amplitudes and closure quantities ...")

#run minimization
img = handler.first_round(prior, data_term, cycles=5)

img.display(cbar_unit=['Tb'], cfun=cfun, cbar_lims=cbar_lims)

#phase-calibration
obs_sc = eh.selfcal(obs_sc, img, method='phase', ttype=ttype)
handler.updateobs(obs_sc.copy())
# Out:
# Round 1: Unconstrained Imaging with visibility amplitudes and closure quantities ...
# Initializing imager data products . . .
# U-V flagged 16/168 visibilities
# U-V flagged 152/168 visibilities
# ==============================
# Imager run 1
# time: 14.798883 s
# J: 34.755581
# chi2_amp : 69.97 chi2_cphase : 9.73 chi2_logcamp : 13.17
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 2
# time: 10.471344 s
# J: 4.993907
# chi2_amp : 16.27 chi2_cphase : 2.22 chi2_logcamp : 1.69
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 3
# time: 7.830437 s
# J: 0.122184
# chi2_amp : 3.28 chi2_cphase : 1.05 chi2_logcamp : 0.61
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 4
# time: 11.942744 s
# J: -0.505056
# chi2_amp : 1.68 chi2_cphase : 0.80 chi2_logcamp : 0.56
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 5
# time: 9.846299 s
# J: -0.661474
# chi2_amp : 1.40 chi2_cphase : 0.81 chi2_logcamp : 0.45
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 6
# time: 11.780704 s
# J: -0.769592
# chi2_amp : 1.02 chi2_cphase : 0.77 chi2_logcamp : 0.45
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 7
# time: 0.735705 s
# J: -0.770059
# chi2_amp : 1.02 chi2_cphase : 0.77 chi2_logcamp : 0.45
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 8
# time: 0.891877 s
# J: -0.770435
# chi2_amp : 1.02 chi2_cphase : 0.77 chi2_logcamp : 0.45
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 9
# time: 0.753440 s
# J: -0.770641
# chi2_amp : 1.01 chi2_cphase : 0.77 chi2_logcamp : 0.45
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 10
# time: 0.690705 s
# J: -0.770953
# chi2_amp : 1.01 chi2_cphase : 0.77 chi2_logcamp : 0.45
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 11
# time: 0.533931 s
# J: -0.771138
# chi2_amp : 1.01 chi2_cphase : 0.77 chi2_logcamp : 0.45
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 12
# time: 11.072247 s
# J: 0.903693
# chi2_amp : 4.99 chi2_cphase : 1.25 chi2_logcamp : 0.85
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 13
# time: 11.451077 s
# J: -0.281836
# chi2_amp : 2.52 chi2_cphase : 0.77 chi2_logcamp : 0.64
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 14
# time: 10.844132 s
# J: -0.657691
# chi2_amp : 1.34 chi2_cphase : 0.78 chi2_logcamp : 0.49
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 15
# time: 14.407348 s
# J: -0.793832
# chi2_amp : 1.02 chi2_cphase : 0.76 chi2_logcamp : 0.44
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 16
# time: 0.980718 s
# J: -0.794079
# chi2_amp : 1.02 chi2_cphase : 0.76 chi2_logcamp : 0.44
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 17
# time: 1.120021 s
# J: -0.794313
# chi2_amp : 1.02 chi2_cphase : 0.76 chi2_logcamp : 0.44
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 18
# time: 0.979807 s
# J: -0.794496
# chi2_amp : 1.02 chi2_cphase : 0.76 chi2_logcamp : 0.44
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 19
# time: 0.691019 s
# J: -0.794740
# chi2_amp : 1.02 chi2_cphase : 0.76 chi2_logcamp : 0.44
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 20
# time: 0.777530 s
# J: -0.794903
# chi2_amp : 1.02 chi2_cphase : 0.76 chi2_logcamp : 0.44
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 21
# time: 1.003772 s
# J: -0.795136
# chi2_amp : 1.02 chi2_cphase : 0.76 chi2_logcamp : 0.44
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 22
# time: 0.948470 s
# J: -0.795289
# chi2_amp : 1.02 chi2_cphase : 0.76 chi2_logcamp : 0.44
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 23
# time: 13.961577 s
# J: 0.231466
# chi2_amp : 3.61 chi2_cphase : 0.89 chi2_logcamp : 0.82
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 24
# time: 14.080770 s
# J: -0.441793
# chi2_amp : 1.94 chi2_cphase : 0.82 chi2_logcamp : 0.55
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 25
# time: 13.006173 s
# J: -0.711448
# chi2_amp : 1.25 chi2_cphase : 0.75 chi2_logcamp : 0.46
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 26
# time: 10.960830 s
# J: -0.828239
# chi2_amp : 1.03 chi2_cphase : 0.75 chi2_logcamp : 0.42
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 27
# time: 6.821126 s
# J: -0.853345
# chi2_amp : 0.98 chi2_cphase : 0.74 chi2_logcamp : 0.41
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 28
# time: 1.029490 s
# J: -0.853432
# chi2_amp : 0.98 chi2_cphase : 0.74 chi2_logcamp : 0.41
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 29
# time: 1.109583 s
# J: -0.853488
# chi2_amp : 0.98 chi2_cphase : 0.74 chi2_logcamp : 0.41
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 30
# time: 0.878429 s
# J: -0.853541
# chi2_amp : 0.98 chi2_cphase : 0.74 chi2_logcamp : 0.41
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 31
# time: 0.796266 s
# J: -0.853593
# chi2_amp : 0.98 chi2_cphase : 0.74 chi2_logcamp : 0.41
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 32
# time: 0.705958 s
# J: -0.853644
# chi2_amp : 0.98 chi2_cphase : 0.74 chi2_logcamp : 0.41
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 33
# time: 1.016864 s
# J: -0.853695
# chi2_amp : 0.98 chi2_cphase : 0.74 chi2_logcamp : 0.41
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 34
# time: 10.760733 s
# J: 0.970674
# chi2_amp : 5.29 chi2_cphase : 1.18 chi2_logcamp : 0.94
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 35
# time: 9.444601 s
# J: -0.150296
# chi2_amp : 2.90 chi2_cphase : 0.77 chi2_logcamp : 0.70
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 36
# time: 10.533261 s
# J: -0.570298
# chi2_amp : 1.66 chi2_cphase : 0.77 chi2_logcamp : 0.52
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 37
# time: 11.648317 s
# J: -0.754981
# chi2_amp : 1.26 chi2_cphase : 0.75 chi2_logcamp : 0.44
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 38
# time: 0.678153 s
# J: -0.755218
# chi2_amp : 1.26 chi2_cphase : 0.75 chi2_logcamp : 0.44
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 39
# time: 0.860598 s
# J: -0.755352
# chi2_amp : 1.26 chi2_cphase : 0.75 chi2_logcamp : 0.44
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 40
# time: 0.816044 s
# J: -0.755495
# chi2_amp : 1.26 chi2_cphase : 0.75 chi2_logcamp : 0.44
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 41
# time: 0.872603 s
# J: -0.755609
# chi2_amp : 1.26 chi2_cphase : 0.75 chi2_logcamp : 0.44
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 42
# time: 1.024477 s
# J: -0.755798
# chi2_amp : 1.26 chi2_cphase : 0.75 chi2_logcamp : 0.44
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 43
# time: 0.757885 s
# J: -0.755951
# chi2_amp : 1.26 chi2_cphase : 0.75 chi2_logcamp : 0.44
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 44
# time: 0.794511 s
# J: -0.756068
# chi2_amp : 1.26 chi2_cphase : 0.75 chi2_logcamp : 0.44
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 45
# time: 12.027738 s
# J: 0.698633
# chi2_amp : 4.70 chi2_cphase : 1.12 chi2_logcamp : 0.84
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 46
# time: 11.846700 s
# J: -0.315441
# chi2_amp : 2.66 chi2_cphase : 0.76 chi2_logcamp : 0.59
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 47
# time: 9.776335 s
# J: -0.664705
# chi2_amp : 1.55 chi2_cphase : 0.77 chi2_logcamp : 0.46
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 48
# time: 10.901870 s
# J: -0.771431
# chi2_amp : 1.35 chi2_cphase : 0.74 chi2_logcamp : 0.42
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# ==============================
# Imager run 49
# time: 0.733653 s
# J: -0.771702
# chi2_amp : 1.34 chi2_cphase : 0.74 chi2_logcamp : 0.42
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 50
# time: 0.758524 s
# J: -0.771852
# chi2_amp : 1.34 chi2_cphase : 0.74 chi2_logcamp : 0.42
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 51
# time: 7.782637 s
# J: -0.810266
# chi2_amp : 1.22 chi2_cphase : 0.73 chi2_logcamp : 0.41
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 52
# time: 0.901489 s
# J: -0.810312
# chi2_amp : 1.22 chi2_cphase : 0.73 chi2_logcamp : 0.41
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 53
# time: 0.689276 s
# J: -0.810359
# chi2_amp : 1.22 chi2_cphase : 0.73 chi2_logcamp : 0.41
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 54
# time: 1.012432 s
# J: -0.810406
# chi2_amp : 1.22 chi2_cphase : 0.73 chi2_logcamp : 0.41
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 55
# time: 0.871629 s
# J: -0.810452
# chi2_amp : 1.22 chi2_cphase : 0.73 chi2_logcamp : 0.41
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================
# ==============================
# Imager run 56
# time: 10.473327 s
# J: 0.732622
# chi2_amp : 4.65 chi2_cphase : 1.14 chi2_logcamp : 0.86
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ==============================
# No stations specified in self cal: defaulting to calibrating all stations!
# Computing the Model Visibilities with direct Fourier Transform...
# Producing clean visibilities from image with direct FT . . .
# Not Using Multiprocessing
# Scan 18/19 : [----------------------------  ]94%
# self_cal time: 2.206093 s
# /aux/vlb051a/anaconda3/envs/mrbeam/lib/python3.10/site-packages/ehtim/obsdata.py:509: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(datalist)

# %% [markdown]
# Now we are computing the DoG-HiT minimization as in tutorial 5. The narrative here is somehow different than before. In previous examples we started from a clean image and looked for an image compatible with data. This time, the initial guess fits the data already very well, but is over-resolving and has image artifacts. DoG-HiT adds regularization while simultaneously keeping the quality of the fit (data fidelity term) and contrast in the image (total flux constraint).

# %%
#-------------------------
# Second Round of Imaging: closure-quantities + sparsity penalization + total flux constraint
#-------------------------

print("Round 2: Multiscalar Imaging with closure quantities ...")

alpha=0.5 #wavelet sparsity constraint
tau=10 #stepsize in minimization

#run mminimization
wtfcts, img = handler.second_round_minimization(img.copy(), alpha, tau, maxiter=10)

img.display(cbar_unit=['Tb'], cfun=cfun, cbar_lims=cbar_lims)

#phase-calibration
obs_sc = eh.selfcal(obs_sc, img, method='phase', ttype=ttype)
handler.updateobs(obs_sc.copy())
# Out:
# Round 2: Multiscalar Imaging with closure quantities ...
# We use  7 scales with threshold 4.5
# Current minimum 12.652708399879188
# Start optimization with thresholds [1.0e+04 1.0e+04 1.0e+04 1.0e+04 4.5e+00 4.5e+00 4.5e+00 4.5e+00 4.5e+00
#  4.5e+00 4.5e+00 4.5e+00]
# reverse mode: True
# Updated at scale 4 to threshold 8.0 to minimum 12.651587037110563
# Updated at scale 4 to threshold 8.5 to minimum 12.641042948037741
# Updated at scale 4 to threshold 9.0 to minimum 12.620976607435516
# Updated at scale 4 to threshold 9.5 to minimum 12.585954174872786
# Updated at scale 5 to threshold 9.5 to minimum 12.580097625309186
# Updated at scale 7 to threshold 0.5 to minimum 12.485879619063528
# Updated at scale 8 to threshold 0.5 to minimum 12.13705491739169
# Updated at scale 9 to threshold 8.0 to minimum 12.065223745887321
# Updated at scale 9 to threshold 8.5 to minimum 12.018859277957464
# Updated at scale 9 to threshold 9.0 to minimum 12.015847545124359
# Updated at scale 9 to threshold 9.5 to minimum 11.936086321835074
# Updated at scale 10 to threshold 5.0 to minimum 11.9327367847112
# Updated at scale 10 to threshold 5.5 to minimum 11.925210868887072
# Updated at scale 10 to threshold 6.0 to minimum 11.916366289234514
# Updated at scale 10 to threshold 6.5 to minimum 11.912977079225826
# Updated at scale 10 to threshold 7.0 to minimum 11.90856269094855
# Updated at scale 10 to threshold 7.5 to minimum 11.902007227543553
# Updated at scale 10 to threshold 8.0 to minimum 11.895383002485833
# Updated at scale 10 to threshold 8.5 to minimum 11.8907813096205
# Updated at scale 10 to threshold 9.0 to minimum 11.88684136488981
# Updated at scale 10 to threshold 9.5 to minimum 11.88425671001999
# Updated at scale 11 to threshold 5.0 to minimum 11.808336787496742
# Updated at scale 11 to threshold 5.5 to minimum 11.709702506881303
# Updated at scale 11 to threshold 6.0 to minimum 11.64872297829556
# Updated at scale 11 to threshold 6.5 to minimum 11.615124176269227
# Updated at scale 11 to threshold 7.0 to minimum 11.562531404013235
# Updated at scale 11 to threshold 7.5 to minimum 11.504850296626913
# Updated at scale 11 to threshold 8.0 to minimum 11.450105329847329
# Updated at scale 11 to threshold 8.5 to minimum 11.415212210309782
# Updated at scale 11 to threshold 9.0 to minimum 11.376757807285127
# Updated at scale 11 to threshold 9.5 to minimum 11.360412714270206
# We use thresholds:  [1.0e+04 1.0e+04 1.0e+04 1.0e+04 9.5e+00 9.5e+00 4.5e+00 5.0e-01 5.0e-01
#  9.5e+00 9.5e+00 9.5e+00]
# 2022-08-05 11:10:16,562 INFO CountIterations      :: iteration = 1 / 25
# 2022-08-05 11:10:16,564 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:17,235 INFO CountIterations      :: iteration = 2 / 25
# 2022-08-05 11:10:17,237 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:17,885 INFO CountIterations      :: iteration = 3 / 25
# 2022-08-05 11:10:17,887 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:18,607 INFO CountIterations      :: iteration = 4 / 25
# 2022-08-05 11:10:18,609 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:19,257 INFO CountIterations      :: iteration = 5 / 25
# 2022-08-05 11:10:19,259 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:19,843 INFO CountIterations      :: iteration = 6 / 25
# 2022-08-05 11:10:19,845 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:20,626 INFO CountIterations      :: iteration = 7 / 25
# 2022-08-05 11:10:20,628 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:21,409 INFO CountIterations      :: iteration = 8 / 25
# 2022-08-05 11:10:21,411 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:22,210 INFO CountIterations      :: iteration = 9 / 25
# 2022-08-05 11:10:22,213 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:23,075 INFO CountIterations      :: iteration = 10 / 25
# 2022-08-05 11:10:23,078 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:23,817 INFO CountIterations      :: iteration = 11 / 25
# 2022-08-05 11:10:23,819 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:24,599 INFO CountIterations      :: iteration = 12 / 25
# 2022-08-05 11:10:24,601 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:25,358 INFO CountIterations      :: iteration = 13 / 25
# 2022-08-05 11:10:25,362 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:26,108 INFO CountIterations      :: iteration = 14 / 25
# 2022-08-05 11:10:26,110 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:26,856 INFO CountIterations      :: iteration = 15 / 25
# 2022-08-05 11:10:26,858 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:27,560 INFO CountIterations      :: iteration = 16 / 25
# 2022-08-05 11:10:27,562 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:28,140 INFO CountIterations      :: iteration = 17 / 25
# 2022-08-05 11:10:28,142 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:28,894 INFO CountIterations      :: iteration = 18 / 25
# 2022-08-05 11:10:28,896 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:29,614 INFO CountIterations      :: iteration = 19 / 25
# 2022-08-05 11:10:29,616 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:30,362 INFO CountIterations      :: iteration = 20 / 25
# 2022-08-05 11:10:30,364 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:31,117 INFO CountIterations      :: iteration = 21 / 25
# 2022-08-05 11:10:31,119 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:31,810 INFO CountIterations      :: iteration = 22 / 25
# 2022-08-05 11:10:31,812 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:32,528 INFO CountIterations      :: iteration = 23 / 25
# 2022-08-05 11:10:32,532 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:33,244 INFO CountIterations      :: iteration = 24 / 25
# 2022-08-05 11:10:33,247 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:33,958 INFO CountIterations      :: iteration = 25 / 25
# 2022-08-05 11:10:33,959 INFO CombineRules         :: Rule CountIterations(max_iterations=25) triggered.
# 2022-08-05 11:10:33,960 INFO Forward_Backward_Splitting :: Stopping rule triggered.
# 3958.1270953808853
# Data Fidelity:  3.863561793659613
# 2022-08-05 11:10:35,041 INFO CountIterations      :: iteration = 1 / 25
# 2022-08-05 11:10:35,042 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:35,789 INFO CountIterations      :: iteration = 2 / 25
# 2022-08-05 11:10:35,791 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:36,471 INFO CountIterations      :: iteration = 3 / 25
# 2022-08-05 11:10:36,473 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:37,156 INFO CountIterations      :: iteration = 4 / 25
# 2022-08-05 11:10:37,158 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:37,858 INFO CountIterations      :: iteration = 5 / 25
# 2022-08-05 11:10:37,860 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:38,582 INFO CountIterations      :: iteration = 6 / 25
# 2022-08-05 11:10:38,584 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:39,336 INFO CountIterations      :: iteration = 7 / 25
# 2022-08-05 11:10:39,338 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:40,021 INFO CountIterations      :: iteration = 8 / 25
# 2022-08-05 11:10:40,023 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:40,650 INFO CountIterations      :: iteration = 9 / 25
# 2022-08-05 11:10:40,651 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:41,346 INFO CountIterations      :: iteration = 10 / 25
# 2022-08-05 11:10:41,348 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:41,967 INFO CountIterations      :: iteration = 11 / 25
# 2022-08-05 11:10:41,968 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:42,746 INFO CountIterations      :: iteration = 12 / 25
# 2022-08-05 11:10:42,747 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:43,351 INFO CountIterations      :: iteration = 13 / 25
# 2022-08-05 11:10:43,353 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:44,065 INFO CountIterations      :: iteration = 14 / 25
# 2022-08-05 11:10:44,067 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:44,727 INFO CountIterations      :: iteration = 15 / 25
# 2022-08-05 11:10:44,728 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:45,380 INFO CountIterations      :: iteration = 16 / 25
# 2022-08-05 11:10:45,382 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:46,099 INFO CountIterations      :: iteration = 17 / 25
# 2022-08-05 11:10:46,101 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:46,705 INFO CountIterations      :: iteration = 18 / 25
# 2022-08-05 11:10:46,707 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:47,379 INFO CountIterations      :: iteration = 19 / 25
# 2022-08-05 11:10:47,381 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:48,152 INFO CountIterations      :: iteration = 20 / 25
# 2022-08-05 11:10:48,154 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:48,892 INFO CountIterations      :: iteration = 21 / 25
# 2022-08-05 11:10:48,894 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:49,488 INFO CountIterations      :: iteration = 22 / 25
# 2022-08-05 11:10:49,491 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:50,277 INFO CountIterations      :: iteration = 23 / 25
# 2022-08-05 11:10:50,278 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:50,892 INFO CountIterations      :: iteration = 24 / 25
# 2022-08-05 11:10:50,894 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:51,492 INFO CountIterations      :: iteration = 25 / 25
# 2022-08-05 11:10:51,494 INFO CombineRules         :: Rule CountIterations(max_iterations=25) triggered.
# 2022-08-05 11:10:51,494 INFO Forward_Backward_Splitting :: Stopping rule triggered.
# 5991.1549368173
# Data Fidelity:  3.5989095199752086
# 2022-08-05 11:10:52,643 INFO CountIterations      :: iteration = 1 / 25
# 2022-08-05 11:10:52,645 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:53,318 INFO CountIterations      :: iteration = 2 / 25
# 2022-08-05 11:10:53,321 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:54,019 INFO CountIterations      :: iteration = 3 / 25
# 2022-08-05 11:10:54,021 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:54,764 INFO CountIterations      :: iteration = 4 / 25
# 2022-08-05 11:10:54,767 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:55,477 INFO CountIterations      :: iteration = 5 / 25
# 2022-08-05 11:10:55,480 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:56,211 INFO CountIterations      :: iteration = 6 / 25
# 2022-08-05 11:10:56,213 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:56,937 INFO CountIterations      :: iteration = 7 / 25
# 2022-08-05 11:10:56,939 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:57,655 INFO CountIterations      :: iteration = 8 / 25
# 2022-08-05 11:10:57,656 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:58,338 INFO CountIterations      :: iteration = 9 / 25
# 2022-08-05 11:10:58,340 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:59,032 INFO CountIterations      :: iteration = 10 / 25
# 2022-08-05 11:10:59,034 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:10:59,777 INFO CountIterations      :: iteration = 11 / 25
# 2022-08-05 11:10:59,779 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:00,525 INFO CountIterations      :: iteration = 12 / 25
# 2022-08-05 11:11:00,527 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:01,273 INFO CountIterations      :: iteration = 13 / 25
# 2022-08-05 11:11:01,275 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:02,026 INFO CountIterations      :: iteration = 14 / 25
# 2022-08-05 11:11:02,027 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:02,715 INFO CountIterations      :: iteration = 15 / 25
# 2022-08-05 11:11:02,717 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:03,378 INFO CountIterations      :: iteration = 16 / 25
# 2022-08-05 11:11:03,381 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:04,098 INFO CountIterations      :: iteration = 17 / 25
# 2022-08-05 11:11:04,100 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:04,919 INFO CountIterations      :: iteration = 18 / 25
# 2022-08-05 11:11:04,920 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:05,549 INFO CountIterations      :: iteration = 19 / 25
# 2022-08-05 11:11:05,551 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:06,343 INFO CountIterations      :: iteration = 20 / 25
# 2022-08-05 11:11:06,345 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:06,933 INFO CountIterations      :: iteration = 21 / 25
# 2022-08-05 11:11:06,935 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:07,583 INFO CountIterations      :: iteration = 22 / 25
# 2022-08-05 11:11:07,585 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:08,233 INFO CountIterations      :: iteration = 23 / 25
# 2022-08-05 11:11:08,235 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:08,976 INFO CountIterations      :: iteration = 24 / 25
# 2022-08-05 11:11:08,978 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:09,715 INFO CountIterations      :: iteration = 25 / 25
# 2022-08-05 11:11:09,716 INFO CombineRules         :: Rule CountIterations(max_iterations=25) triggered.
# 2022-08-05 11:11:09,716 INFO Forward_Backward_Splitting :: Stopping rule triggered.
# 5993.618581427056
# Data Fidelity:  3.4114292213839836
# 2022-08-05 11:11:10,849 INFO CountIterations      :: iteration = 1 / 25
# 2022-08-05 11:11:10,851 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:11,455 INFO CountIterations      :: iteration = 2 / 25
# 2022-08-05 11:11:11,457 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:12,212 INFO CountIterations      :: iteration = 3 / 25
# 2022-08-05 11:11:12,214 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:12,940 INFO CountIterations      :: iteration = 4 / 25
# 2022-08-05 11:11:12,942 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:13,606 INFO CountIterations      :: iteration = 5 / 25
# 2022-08-05 11:11:13,608 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:14,270 INFO CountIterations      :: iteration = 6 / 25
# 2022-08-05 11:11:14,272 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:14,921 INFO CountIterations      :: iteration = 7 / 25
# 2022-08-05 11:11:14,922 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:15,618 INFO CountIterations      :: iteration = 8 / 25
# 2022-08-05 11:11:15,620 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:16,326 INFO CountIterations      :: iteration = 9 / 25
# 2022-08-05 11:11:16,328 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:16,962 INFO CountIterations      :: iteration = 10 / 25
# 2022-08-05 11:11:16,964 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:17,677 INFO CountIterations      :: iteration = 11 / 25
# 2022-08-05 11:11:17,679 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:18,343 INFO CountIterations      :: iteration = 12 / 25
# 2022-08-05 11:11:18,344 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:18,980 INFO CountIterations      :: iteration = 13 / 25
# 2022-08-05 11:11:18,981 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:19,689 INFO CountIterations      :: iteration = 14 / 25
# 2022-08-05 11:11:19,691 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:20,460 INFO CountIterations      :: iteration = 15 / 25
# 2022-08-05 11:11:20,463 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:21,207 INFO CountIterations      :: iteration = 16 / 25
# 2022-08-05 11:11:21,209 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:21,882 INFO CountIterations      :: iteration = 17 / 25
# 2022-08-05 11:11:21,883 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:22,577 INFO CountIterations      :: iteration = 18 / 25
# 2022-08-05 11:11:22,578 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:23,299 INFO CountIterations      :: iteration = 19 / 25
# 2022-08-05 11:11:23,301 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:24,148 INFO CountIterations      :: iteration = 20 / 25
# 2022-08-05 11:11:24,150 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:24,826 INFO CountIterations      :: iteration = 21 / 25
# 2022-08-05 11:11:24,828 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:25,460 INFO CountIterations      :: iteration = 22 / 25
# 2022-08-05 11:11:25,461 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:26,132 INFO CountIterations      :: iteration = 23 / 25
# 2022-08-05 11:11:26,135 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:26,831 INFO CountIterations      :: iteration = 24 / 25
# 2022-08-05 11:11:26,833 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:27,638 INFO CountIterations      :: iteration = 25 / 25
# 2022-08-05 11:11:27,639 INFO CombineRules         :: Rule CountIterations(max_iterations=25) triggered.
# 2022-08-05 11:11:27,639 INFO Forward_Backward_Splitting :: Stopping rule triggered.
# 5995.634186030017
# Data Fidelity:  3.270583311660593
# 2022-08-05 11:11:28,866 INFO CountIterations      :: iteration = 1 / 25
# 2022-08-05 11:11:28,868 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:29,549 INFO CountIterations      :: iteration = 2 / 25
# 2022-08-05 11:11:29,551 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:30,220 INFO CountIterations      :: iteration = 3 / 25
# 2022-08-05 11:11:30,222 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:30,816 INFO CountIterations      :: iteration = 4 / 25
# 2022-08-05 11:11:30,818 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:31,508 INFO CountIterations      :: iteration = 5 / 25
# 2022-08-05 11:11:31,510 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:32,257 INFO CountIterations      :: iteration = 6 / 25
# 2022-08-05 11:11:32,258 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:32,924 INFO CountIterations      :: iteration = 7 / 25
# 2022-08-05 11:11:32,925 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:33,549 INFO CountIterations      :: iteration = 8 / 25
# 2022-08-05 11:11:33,553 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:34,263 INFO CountIterations      :: iteration = 9 / 25
# 2022-08-05 11:11:34,264 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:34,937 INFO CountIterations      :: iteration = 10 / 25
# 2022-08-05 11:11:34,939 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:35,719 INFO CountIterations      :: iteration = 11 / 25
# 2022-08-05 11:11:35,720 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:36,483 INFO CountIterations      :: iteration = 12 / 25
# 2022-08-05 11:11:36,486 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:37,156 INFO CountIterations      :: iteration = 13 / 25
# 2022-08-05 11:11:37,158 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:37,826 INFO CountIterations      :: iteration = 14 / 25
# 2022-08-05 11:11:37,828 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:38,530 INFO CountIterations      :: iteration = 15 / 25
# 2022-08-05 11:11:38,532 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:39,180 INFO CountIterations      :: iteration = 16 / 25
# 2022-08-05 11:11:39,182 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:39,966 INFO CountIterations      :: iteration = 17 / 25
# 2022-08-05 11:11:39,968 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:40,658 INFO CountIterations      :: iteration = 18 / 25
# 2022-08-05 11:11:40,660 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:41,404 INFO CountIterations      :: iteration = 19 / 25
# 2022-08-05 11:11:41,406 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:42,112 INFO CountIterations      :: iteration = 20 / 25
# 2022-08-05 11:11:42,114 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:42,736 INFO CountIterations      :: iteration = 21 / 25
# 2022-08-05 11:11:42,738 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:43,398 INFO CountIterations      :: iteration = 22 / 25
# 2022-08-05 11:11:43,400 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:44,060 INFO CountIterations      :: iteration = 23 / 25
# 2022-08-05 11:11:44,062 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:44,806 INFO CountIterations      :: iteration = 24 / 25
# 2022-08-05 11:11:44,808 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:45,495 INFO CountIterations      :: iteration = 25 / 25
# 2022-08-05 11:11:45,496 INFO CombineRules         :: Rule CountIterations(max_iterations=25) triggered.
# 2022-08-05 11:11:45,497 INFO Forward_Backward_Splitting :: Stopping rule triggered.
# 5997.284550199145
# Data Fidelity:  3.1606268843362257
# 2022-08-05 11:11:46,718 INFO CountIterations      :: iteration = 1 / 25
# 2022-08-05 11:11:46,721 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:47,432 INFO CountIterations      :: iteration = 2 / 25
# 2022-08-05 11:11:47,434 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:48,072 INFO CountIterations      :: iteration = 3 / 25
# 2022-08-05 11:11:48,073 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:48,823 INFO CountIterations      :: iteration = 4 / 25
# 2022-08-05 11:11:48,825 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:49,557 INFO CountIterations      :: iteration = 5 / 25
# 2022-08-05 11:11:49,560 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:50,257 INFO CountIterations      :: iteration = 6 / 25
# 2022-08-05 11:11:50,259 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:51,025 INFO CountIterations      :: iteration = 7 / 25
# 2022-08-05 11:11:51,027 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:51,821 INFO CountIterations      :: iteration = 8 / 25
# 2022-08-05 11:11:51,823 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:52,567 INFO CountIterations      :: iteration = 9 / 25
# 2022-08-05 11:11:52,569 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:53,283 INFO CountIterations      :: iteration = 10 / 25
# 2022-08-05 11:11:53,284 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:53,951 INFO CountIterations      :: iteration = 11 / 25
# 2022-08-05 11:11:53,953 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:54,580 INFO CountIterations      :: iteration = 12 / 25
# 2022-08-05 11:11:54,582 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:55,261 INFO CountIterations      :: iteration = 13 / 25
# 2022-08-05 11:11:55,263 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:55,938 INFO CountIterations      :: iteration = 14 / 25
# 2022-08-05 11:11:55,939 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:56,619 INFO CountIterations      :: iteration = 15 / 25
# 2022-08-05 11:11:56,622 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:57,296 INFO CountIterations      :: iteration = 16 / 25
# 2022-08-05 11:11:57,298 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:58,039 INFO CountIterations      :: iteration = 17 / 25
# 2022-08-05 11:11:58,041 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:58,747 INFO CountIterations      :: iteration = 18 / 25
# 2022-08-05 11:11:58,749 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:11:59,499 INFO CountIterations      :: iteration = 19 / 25
# 2022-08-05 11:11:59,501 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:00,200 INFO CountIterations      :: iteration = 20 / 25
# 2022-08-05 11:12:00,202 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:00,900 INFO CountIterations      :: iteration = 21 / 25
# 2022-08-05 11:12:00,901 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:01,483 INFO CountIterations      :: iteration = 22 / 25
# 2022-08-05 11:12:01,486 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:02,130 INFO CountIterations      :: iteration = 23 / 25
# 2022-08-05 11:12:02,132 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:02,767 INFO CountIterations      :: iteration = 24 / 25
# 2022-08-05 11:12:02,768 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:03,441 INFO CountIterations      :: iteration = 25 / 25
# 2022-08-05 11:12:03,442 INFO CombineRules         :: Rule CountIterations(max_iterations=25) triggered.
# 2022-08-05 11:12:03,442 INFO Forward_Backward_Splitting :: Stopping rule triggered.
# 5998.6383204918675
# Data Fidelity:  3.072216917398
# 2022-08-05 11:12:04,519 INFO CountIterations      :: iteration = 1 / 25
# 2022-08-05 11:12:04,521 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:05,209 INFO CountIterations      :: iteration = 2 / 25
# 2022-08-05 11:12:05,211 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:05,848 INFO CountIterations      :: iteration = 3 / 25
# 2022-08-05 11:12:05,850 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:06,560 INFO CountIterations      :: iteration = 4 / 25
# 2022-08-05 11:12:06,562 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:07,163 INFO CountIterations      :: iteration = 5 / 25
# 2022-08-05 11:12:07,164 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:07,873 INFO CountIterations      :: iteration = 6 / 25
# 2022-08-05 11:12:07,874 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:08,634 INFO CountIterations      :: iteration = 7 / 25
# 2022-08-05 11:12:08,636 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:09,354 INFO CountIterations      :: iteration = 8 / 25
# 2022-08-05 11:12:09,356 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:10,109 INFO CountIterations      :: iteration = 9 / 25
# 2022-08-05 11:12:10,111 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:10,798 INFO CountIterations      :: iteration = 10 / 25
# 2022-08-05 11:12:10,800 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:11,470 INFO CountIterations      :: iteration = 11 / 25
# 2022-08-05 11:12:11,472 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:12,124 INFO CountIterations      :: iteration = 12 / 25
# 2022-08-05 11:12:12,126 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:12,793 INFO CountIterations      :: iteration = 13 / 25
# 2022-08-05 11:12:12,795 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:13,500 INFO CountIterations      :: iteration = 14 / 25
# 2022-08-05 11:12:13,501 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:14,204 INFO CountIterations      :: iteration = 15 / 25
# 2022-08-05 11:12:14,206 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:14,996 INFO CountIterations      :: iteration = 16 / 25
# 2022-08-05 11:12:14,998 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:15,746 INFO CountIterations      :: iteration = 17 / 25
# 2022-08-05 11:12:15,748 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:16,516 INFO CountIterations      :: iteration = 18 / 25
# 2022-08-05 11:12:16,518 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:17,247 INFO CountIterations      :: iteration = 19 / 25
# 2022-08-05 11:12:17,249 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:18,077 INFO CountIterations      :: iteration = 20 / 25
# 2022-08-05 11:12:18,079 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:18,880 INFO CountIterations      :: iteration = 21 / 25
# 2022-08-05 11:12:18,882 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:19,673 INFO CountIterations      :: iteration = 22 / 25
# 2022-08-05 11:12:19,675 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:20,357 INFO CountIterations      :: iteration = 23 / 25
# 2022-08-05 11:12:20,359 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:21,180 INFO CountIterations      :: iteration = 24 / 25
# 2022-08-05 11:12:21,182 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:21,874 INFO CountIterations      :: iteration = 25 / 25
# 2022-08-05 11:12:21,875 INFO CombineRules         :: Rule CountIterations(max_iterations=25) triggered.
# 2022-08-05 11:12:21,876 INFO Forward_Backward_Splitting :: Stopping rule triggered.
# 5999.750924859806
# Data Fidelity:  2.999326501073311
# 2022-08-05 11:12:23,148 INFO CountIterations      :: iteration = 1 / 25
# 2022-08-05 11:12:23,150 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:23,891 INFO CountIterations      :: iteration = 2 / 25
# 2022-08-05 11:12:23,894 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:24,666 INFO CountIterations      :: iteration = 3 / 25
# 2022-08-05 11:12:24,668 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:25,409 INFO CountIterations      :: iteration = 4 / 25
# 2022-08-05 11:12:25,411 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:26,062 INFO CountIterations      :: iteration = 5 / 25
# 2022-08-05 11:12:26,064 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:26,822 INFO CountIterations      :: iteration = 6 / 25
# 2022-08-05 11:12:26,824 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:27,605 INFO CountIterations      :: iteration = 7 / 25
# 2022-08-05 11:12:27,608 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:28,318 INFO CountIterations      :: iteration = 8 / 25
# 2022-08-05 11:12:28,320 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:28,953 INFO CountIterations      :: iteration = 9 / 25
# 2022-08-05 11:12:28,955 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:29,679 INFO CountIterations      :: iteration = 10 / 25
# 2022-08-05 11:12:29,681 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:30,435 INFO CountIterations      :: iteration = 11 / 25
# 2022-08-05 11:12:30,436 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:31,217 INFO CountIterations      :: iteration = 12 / 25
# 2022-08-05 11:12:31,219 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:31,931 INFO CountIterations      :: iteration = 13 / 25
# 2022-08-05 11:12:31,932 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:32,591 INFO CountIterations      :: iteration = 14 / 25
# 2022-08-05 11:12:32,593 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:33,313 INFO CountIterations      :: iteration = 15 / 25
# 2022-08-05 11:12:33,315 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:33,928 INFO CountIterations      :: iteration = 16 / 25
# 2022-08-05 11:12:33,929 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:34,635 INFO CountIterations      :: iteration = 17 / 25
# 2022-08-05 11:12:34,637 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:35,272 INFO CountIterations      :: iteration = 18 / 25
# 2022-08-05 11:12:35,274 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:35,855 INFO CountIterations      :: iteration = 19 / 25
# 2022-08-05 11:12:35,856 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:36,554 INFO CountIterations      :: iteration = 20 / 25
# 2022-08-05 11:12:36,556 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:37,259 INFO CountIterations      :: iteration = 21 / 25
# 2022-08-05 11:12:37,261 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:37,974 INFO CountIterations      :: iteration = 22 / 25
# 2022-08-05 11:12:37,976 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:38,765 INFO CountIterations      :: iteration = 23 / 25
# 2022-08-05 11:12:38,767 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:39,463 INFO CountIterations      :: iteration = 24 / 25
# 2022-08-05 11:12:39,465 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:40,086 INFO CountIterations      :: iteration = 25 / 25
# 2022-08-05 11:12:40,087 INFO CombineRules         :: Rule CountIterations(max_iterations=25) triggered.
# 2022-08-05 11:12:40,087 INFO Forward_Backward_Splitting :: Stopping rule triggered.
# 6000.666780798729
# Data Fidelity:  2.9378657355063313
# 2022-08-05 11:12:41,127 INFO CountIterations      :: iteration = 1 / 25
# 2022-08-05 11:12:41,129 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:41,828 INFO CountIterations      :: iteration = 2 / 25
# 2022-08-05 11:12:41,830 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:42,462 INFO CountIterations      :: iteration = 3 / 25
# 2022-08-05 11:12:42,465 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:43,171 INFO CountIterations      :: iteration = 4 / 25
# 2022-08-05 11:12:43,173 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:43,821 INFO CountIterations      :: iteration = 5 / 25
# 2022-08-05 11:12:43,823 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:44,576 INFO CountIterations      :: iteration = 6 / 25
# 2022-08-05 11:12:44,578 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:45,235 INFO CountIterations      :: iteration = 7 / 25
# 2022-08-05 11:12:45,237 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:46,032 INFO CountIterations      :: iteration = 8 / 25
# 2022-08-05 11:12:46,034 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:46,766 INFO CountIterations      :: iteration = 9 / 25
# 2022-08-05 11:12:46,768 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:47,439 INFO CountIterations      :: iteration = 10 / 25
# 2022-08-05 11:12:47,441 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:48,044 INFO CountIterations      :: iteration = 11 / 25
# 2022-08-05 11:12:48,046 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:48,806 INFO CountIterations      :: iteration = 12 / 25
# 2022-08-05 11:12:48,808 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:49,654 INFO CountIterations      :: iteration = 13 / 25
# 2022-08-05 11:12:49,656 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:50,417 INFO CountIterations      :: iteration = 14 / 25
# 2022-08-05 11:12:50,420 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:51,112 INFO CountIterations      :: iteration = 15 / 25
# 2022-08-05 11:12:51,113 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:51,845 INFO CountIterations      :: iteration = 16 / 25
# 2022-08-05 11:12:51,848 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:52,531 INFO CountIterations      :: iteration = 17 / 25
# 2022-08-05 11:12:52,534 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:53,219 INFO CountIterations      :: iteration = 18 / 25
# 2022-08-05 11:12:53,221 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:53,945 INFO CountIterations      :: iteration = 19 / 25
# 2022-08-05 11:12:53,947 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:54,691 INFO CountIterations      :: iteration = 20 / 25
# 2022-08-05 11:12:54,693 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:55,383 INFO CountIterations      :: iteration = 21 / 25
# 2022-08-05 11:12:55,385 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:56,073 INFO CountIterations      :: iteration = 22 / 25
# 2022-08-05 11:12:56,076 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:56,794 INFO CountIterations      :: iteration = 23 / 25
# 2022-08-05 11:12:56,796 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:57,440 INFO CountIterations      :: iteration = 24 / 25
# 2022-08-05 11:12:57,442 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:12:58,166 INFO CountIterations      :: iteration = 25 / 25
# 2022-08-05 11:12:58,167 INFO CombineRules         :: Rule CountIterations(max_iterations=25) triggered.
# 2022-08-05 11:12:58,168 INFO Forward_Backward_Splitting :: Stopping rule triggered.
# 6001.421454774942
# Data Fidelity:  2.88496836191186
# 2022-08-05 11:12:59,279 INFO CountIterations      :: iteration = 1 / 25
# 2022-08-05 11:12:59,281 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:00,071 INFO CountIterations      :: iteration = 2 / 25
# 2022-08-05 11:13:00,073 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:00,742 INFO CountIterations      :: iteration = 3 / 25
# 2022-08-05 11:13:00,744 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:01,374 INFO CountIterations      :: iteration = 4 / 25
# 2022-08-05 11:13:01,376 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:02,075 INFO CountIterations      :: iteration = 5 / 25
# 2022-08-05 11:13:02,077 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:02,802 INFO CountIterations      :: iteration = 6 / 25
# 2022-08-05 11:13:02,804 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:03,648 INFO CountIterations      :: iteration = 7 / 25
# 2022-08-05 11:13:03,650 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:04,449 INFO CountIterations      :: iteration = 8 / 25
# 2022-08-05 11:13:04,451 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:05,216 INFO CountIterations      :: iteration = 9 / 25
# 2022-08-05 11:13:05,218 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:06,009 INFO CountIterations      :: iteration = 10 / 25
# 2022-08-05 11:13:06,011 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:06,690 INFO CountIterations      :: iteration = 11 / 25
# 2022-08-05 11:13:06,692 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:07,387 INFO CountIterations      :: iteration = 12 / 25
# 2022-08-05 11:13:07,389 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:08,120 INFO CountIterations      :: iteration = 13 / 25
# 2022-08-05 11:13:08,122 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:08,854 INFO CountIterations      :: iteration = 14 / 25
# 2022-08-05 11:13:08,855 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:09,570 INFO CountIterations      :: iteration = 15 / 25
# 2022-08-05 11:13:09,571 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:10,359 INFO CountIterations      :: iteration = 16 / 25
# 2022-08-05 11:13:10,361 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:11,031 INFO CountIterations      :: iteration = 17 / 25
# 2022-08-05 11:13:11,033 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:11,763 INFO CountIterations      :: iteration = 18 / 25
# 2022-08-05 11:13:11,765 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:12,492 INFO CountIterations      :: iteration = 19 / 25
# 2022-08-05 11:13:12,494 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:13,161 INFO CountIterations      :: iteration = 20 / 25
# 2022-08-05 11:13:13,164 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:13,935 INFO CountIterations      :: iteration = 21 / 25
# 2022-08-05 11:13:13,937 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:14,668 INFO CountIterations      :: iteration = 22 / 25
# 2022-08-05 11:13:14,669 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:15,441 INFO CountIterations      :: iteration = 23 / 25
# 2022-08-05 11:13:15,443 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:16,171 INFO CountIterations      :: iteration = 24 / 25
# 2022-08-05 11:13:16,173 INFO Display              :: Penalty--> 9.154853010008761
# 2022-08-05 11:13:16,833 INFO CountIterations      :: iteration = 25 / 25
# 2022-08-05 11:13:16,834 INFO CombineRules         :: Rule CountIterations(max_iterations=25) triggered.
# 2022-08-05 11:13:16,835 INFO Forward_Backward_Splitting :: Stopping rule triggered.
# 6002.0434906667
# Data Fidelity:  2.838581426375013
# No stations specified in self cal: defaulting to calibrating all stations!
# Computing the Model Visibilities with direct Fourier Transform...
# Producing clean visibilities from image with direct FT . . .
# Not Using Multiprocessing
# Scan 18/19 : [----------------------------  ]94%
# self_cal time: 1.709059 s
# /aux/vlb051a/anaconda3/envs/mrbeam/lib/python3.10/site-packages/ehtim/obsdata.py:509: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(datalist)

# %% [markdown]
# Refinement with the multiresolution support as presented in tutorial 5.

# %%
#-------------------------
# Third Round of Imaging: amplitude+closure-quantities + multiresolution support constraint
#-------------------------

print("Third Round: Multiscalar Imaging with visibility amplitudes and closure quantities ...")

#run gradient descent minimization
#stepsize automatically found
wtfcts, img, tau = handler.third_round(wtfcts, data_term, tau=tau, maxit=100)

img.display(cbar_unit=['Tb'], cfun=cfun, cbar_lims=cbar_lims)

#phase-calibration
obs_sc = eh.selfcal(obs_sc, img, method='phase', ttype=ttype)
handler.updateobs(obs_sc.copy())
# Out:
# Third Round: Multiscalar Imaging with visibility amplitudes and closure quantities ...
# 2022-08-05 11:15:48,555 INFO CountIterations      :: iteration = 1 / 5
# 2022-08-05 11:15:49,115 INFO Display              :: Data Fidelity--> 3.8903769993322888
# 2022-08-05 11:15:50,262 INFO CountIterations      :: iteration = 2 / 5
# 2022-08-05 11:15:50,781 INFO Display              :: Data Fidelity--> 3.8640113999358263
# 2022-08-05 11:15:51,806 INFO CountIterations      :: iteration = 3 / 5
# 2022-08-05 11:15:52,305 INFO Display              :: Data Fidelity--> 3.840087204532603
# 2022-08-05 11:15:53,379 INFO CountIterations      :: iteration = 4 / 5
# 2022-08-05 11:15:53,929 INFO Display              :: Data Fidelity--> 3.818011533755132
# 2022-08-05 11:15:55,024 INFO CountIterations      :: iteration = 5 / 5
# 2022-08-05 11:15:55,026 INFO CombineRules         :: Rule CountIterations(max_iterations=5) triggered.
# 2022-08-05 11:15:55,027 INFO Gradient_Descent     :: Stopping rule triggered.
# 2022-08-05 11:15:56,805 INFO CountIterations      :: iteration = 1 / 5
# 2022-08-05 11:15:57,305 INFO Display              :: Data Fidelity--> 3.777935585486161
# 2022-08-05 11:15:58,396 INFO CountIterations      :: iteration = 2 / 5
# 2022-08-05 11:15:58,868 INFO Display              :: Data Fidelity--> 3.7594568691130013
# 2022-08-05 11:15:59,975 INFO CountIterations      :: iteration = 3 / 5
# 2022-08-05 11:16:00,470 INFO Display              :: Data Fidelity--> 3.741800069333979
# 2022-08-05 11:16:01,478 INFO CountIterations      :: iteration = 4 / 5
# 2022-08-05 11:16:01,976 INFO Display              :: Data Fidelity--> 3.724848851991653
# 2022-08-05 11:16:03,116 INFO CountIterations      :: iteration = 5 / 5
# 2022-08-05 11:16:03,117 INFO CombineRules         :: Rule CountIterations(max_iterations=5) triggered.
# 2022-08-05 11:16:03,119 INFO Gradient_Descent     :: Stopping rule triggered.
# 2022-08-05 11:16:04,942 INFO CountIterations      :: iteration = 1 / 5
# 2022-08-05 11:16:05,476 INFO Display              :: Data Fidelity--> 3.6927120249999033
# 2022-08-05 11:16:06,584 INFO CountIterations      :: iteration = 2 / 5
# 2022-08-05 11:16:07,087 INFO Display              :: Data Fidelity--> 3.6773904719723434
# 2022-08-05 11:16:08,198 INFO CountIterations      :: iteration = 3 / 5
# 2022-08-05 11:16:08,675 INFO Display              :: Data Fidelity--> 3.6624952262788213
# 2022-08-05 11:16:09,724 INFO CountIterations      :: iteration = 4 / 5
# 2022-08-05 11:16:10,256 INFO Display              :: Data Fidelity--> 3.6479832027284003
# 2022-08-05 11:16:11,351 INFO CountIterations      :: iteration = 5 / 5
# 2022-08-05 11:16:11,352 INFO CombineRules         :: Rule CountIterations(max_iterations=5) triggered.
# 2022-08-05 11:16:11,352 INFO Gradient_Descent     :: Stopping rule triggered.
# 2022-08-05 11:16:13,234 INFO CountIterations      :: iteration = 1 / 5
# 2022-08-05 11:16:13,754 INFO Display              :: Data Fidelity--> 3.6199676953298843
# 2022-08-05 11:16:14,834 INFO CountIterations      :: iteration = 2 / 5
# 2022-08-05 11:16:15,382 INFO Display              :: Data Fidelity--> 3.606405942088565
# 2022-08-05 11:16:16,438 INFO CountIterations      :: iteration = 3 / 5
# 2022-08-05 11:16:16,961 INFO Display              :: Data Fidelity--> 3.5931092178191744
# 2022-08-05 11:16:18,043 INFO CountIterations      :: iteration = 4 / 5
# 2022-08-05 11:16:18,508 INFO Display              :: Data Fidelity--> 3.5800572497459378
# 2022-08-05 11:16:19,629 INFO CountIterations      :: iteration = 5 / 5
# 2022-08-05 11:16:19,630 INFO CombineRules         :: Rule CountIterations(max_iterations=5) triggered.
# 2022-08-05 11:16:19,630 INFO Gradient_Descent     :: Stopping rule triggered.
# 2022-08-05 11:16:21,366 INFO CountIterations      :: iteration = 1 / 100
# 2022-08-05 11:16:21,858 INFO Display              :: Data Fidelity--> 3.8903769993322888
# 2022-08-05 11:16:22,846 INFO CountIterations      :: iteration = 2 / 100
# 2022-08-05 11:16:23,298 INFO Display              :: Data Fidelity--> 3.8640113999358263
# 2022-08-05 11:16:24,285 INFO CountIterations      :: iteration = 3 / 100
# 2022-08-05 11:16:24,802 INFO Display              :: Data Fidelity--> 3.840087204532603
# 2022-08-05 11:16:25,871 INFO CountIterations      :: iteration = 4 / 100
# 2022-08-05 11:16:26,362 INFO Display              :: Data Fidelity--> 3.818011533755132
# 2022-08-05 11:16:27,361 INFO CountIterations      :: iteration = 5 / 100
# 2022-08-05 11:16:27,800 INFO Display              :: Data Fidelity--> 3.7973868223052225
# 2022-08-05 11:16:28,890 INFO CountIterations      :: iteration = 6 / 100
# 2022-08-05 11:16:29,352 INFO Display              :: Data Fidelity--> 3.777935585486161
# 2022-08-05 11:16:30,398 INFO CountIterations      :: iteration = 7 / 100
# 2022-08-05 11:16:30,819 INFO Display              :: Data Fidelity--> 3.7594568691130013
# 2022-08-05 11:16:31,790 INFO CountIterations      :: iteration = 8 / 100
# 2022-08-05 11:16:32,294 INFO Display              :: Data Fidelity--> 3.741800069333979
# 2022-08-05 11:16:33,293 INFO CountIterations      :: iteration = 9 / 100
# 2022-08-05 11:16:33,751 INFO Display              :: Data Fidelity--> 3.724848851991653
# 2022-08-05 11:16:34,773 INFO CountIterations      :: iteration = 10 / 100
# 2022-08-05 11:16:35,245 INFO Display              :: Data Fidelity--> 3.7085110322965873
# 2022-08-05 11:16:36,241 INFO CountIterations      :: iteration = 11 / 100
# 2022-08-05 11:16:36,744 INFO Display              :: Data Fidelity--> 3.6927120249999033
# 2022-08-05 11:16:37,823 INFO CountIterations      :: iteration = 12 / 100
# 2022-08-05 11:16:38,320 INFO Display              :: Data Fidelity--> 3.6773904719723434
# 2022-08-05 11:16:39,470 INFO CountIterations      :: iteration = 13 / 100
# 2022-08-05 11:16:39,941 INFO Display              :: Data Fidelity--> 3.6624952262788213
# 2022-08-05 11:16:40,895 INFO CountIterations      :: iteration = 14 / 100
# 2022-08-05 11:16:41,469 INFO Display              :: Data Fidelity--> 3.6479832027284003
# 2022-08-05 11:16:42,553 INFO CountIterations      :: iteration = 15 / 100
# 2022-08-05 11:16:43,030 INFO Display              :: Data Fidelity--> 3.6338177977940616
# 2022-08-05 11:16:44,140 INFO CountIterations      :: iteration = 16 / 100
# 2022-08-05 11:16:44,590 INFO Display              :: Data Fidelity--> 3.6199676953298843
# 2022-08-05 11:16:45,630 INFO CountIterations      :: iteration = 17 / 100
# 2022-08-05 11:16:46,114 INFO Display              :: Data Fidelity--> 3.606405942088565
# 2022-08-05 11:16:47,188 INFO CountIterations      :: iteration = 18 / 100
# 2022-08-05 11:16:47,707 INFO Display              :: Data Fidelity--> 3.5931092178191744
# 2022-08-05 11:16:48,733 INFO CountIterations      :: iteration = 19 / 100
# 2022-08-05 11:16:49,174 INFO Display              :: Data Fidelity--> 3.5800572497459378
# 2022-08-05 11:16:50,188 INFO CountIterations      :: iteration = 20 / 100
# 2022-08-05 11:16:50,643 INFO Display              :: Data Fidelity--> 3.5672323368965886
# 2022-08-05 11:16:51,664 INFO CountIterations      :: iteration = 21 / 100
# 2022-08-05 11:16:52,165 INFO Display              :: Data Fidelity--> 3.5546189597932303
# 2022-08-05 11:16:53,150 INFO CountIterations      :: iteration = 22 / 100
# 2022-08-05 11:16:53,676 INFO Display              :: Data Fidelity--> 3.5422034576344794
# 2022-08-05 11:16:54,835 INFO CountIterations      :: iteration = 23 / 100
# 2022-08-05 11:16:55,282 INFO Display              :: Data Fidelity--> 3.5299737595823046
# 2022-08-05 11:16:56,258 INFO CountIterations      :: iteration = 24 / 100
# 2022-08-05 11:16:56,770 INFO Display              :: Data Fidelity--> 3.517919159899618
# 2022-08-05 11:16:57,765 INFO CountIterations      :: iteration = 25 / 100
# 2022-08-05 11:16:58,215 INFO Display              :: Data Fidelity--> 3.5060301289354454
# 2022-08-05 11:16:59,253 INFO CountIterations      :: iteration = 26 / 100
# 2022-08-05 11:16:59,772 INFO Display              :: Data Fidelity--> 3.494298153619078
# 2022-08-05 11:17:00,734 INFO CountIterations      :: iteration = 27 / 100
# 2022-08-05 11:17:01,176 INFO Display              :: Data Fidelity--> 3.4827156023785655
# 2022-08-05 11:17:02,202 INFO CountIterations      :: iteration = 28 / 100
# 2022-08-05 11:17:02,723 INFO Display              :: Data Fidelity--> 3.471275610370926
# 2022-08-05 11:17:03,759 INFO CountIterations      :: iteration = 29 / 100
# 2022-08-05 11:17:04,194 INFO Display              :: Data Fidelity--> 3.459971981669101
# 2022-08-05 11:17:05,294 INFO CountIterations      :: iteration = 30 / 100
# 2022-08-05 11:17:05,755 INFO Display              :: Data Fidelity--> 3.4487991056545626
# 2022-08-05 11:17:06,730 INFO CountIterations      :: iteration = 31 / 100
# 2022-08-05 11:17:07,247 INFO Display              :: Data Fidelity--> 3.4377518853486233
# 2022-08-05 11:17:08,350 INFO CountIterations      :: iteration = 32 / 100
# 2022-08-05 11:17:08,823 INFO Display              :: Data Fidelity--> 3.426825675805105
# 2022-08-05 11:17:09,925 INFO CountIterations      :: iteration = 33 / 100
# 2022-08-05 11:17:10,408 INFO Display              :: Data Fidelity--> 3.4160162310082436
# 2022-08-05 11:17:11,458 INFO CountIterations      :: iteration = 34 / 100
# 2022-08-05 11:17:11,903 INFO Display              :: Data Fidelity--> 3.405319657977105
# 2022-08-05 11:17:12,952 INFO CountIterations      :: iteration = 35 / 100
# 2022-08-05 11:17:13,430 INFO Display              :: Data Fidelity--> 3.394732376993839
# 2022-08-05 11:17:14,468 INFO CountIterations      :: iteration = 36 / 100
# 2022-08-05 11:17:14,963 INFO Display              :: Data Fidelity--> 3.3842510870480322
# 2022-08-05 11:17:16,010 INFO CountIterations      :: iteration = 37 / 100
# 2022-08-05 11:17:16,533 INFO Display              :: Data Fidelity--> 3.3738727357361267
# 2022-08-05 11:17:17,651 INFO CountIterations      :: iteration = 38 / 100
# 2022-08-05 11:17:18,069 INFO Display              :: Data Fidelity--> 3.3635944929752215
# 2022-08-05 11:17:19,183 INFO CountIterations      :: iteration = 39 / 100
# 2022-08-05 11:17:19,650 INFO Display              :: Data Fidelity--> 3.3534137279898686
# 2022-08-05 11:17:20,678 INFO CountIterations      :: iteration = 40 / 100
# 2022-08-05 11:17:21,201 INFO Display              :: Data Fidelity--> 3.3433279891160548
# 2022-08-05 11:17:22,243 INFO CountIterations      :: iteration = 41 / 100
# 2022-08-05 11:17:22,684 INFO Display              :: Data Fidelity--> 3.333334986034993
# 2022-08-05 11:17:23,686 INFO CountIterations      :: iteration = 42 / 100
# 2022-08-05 11:17:24,145 INFO Display              :: Data Fidelity--> 3.3234325741068407
# 2022-08-05 11:17:25,173 INFO CountIterations      :: iteration = 43 / 100
# 2022-08-05 11:17:25,660 INFO Display              :: Data Fidelity--> 3.31361874052556
# 2022-08-05 11:17:26,793 INFO CountIterations      :: iteration = 44 / 100
# 2022-08-05 11:17:27,333 INFO Display              :: Data Fidelity--> 3.3038915920553427
# 2022-08-05 11:17:28,425 INFO CountIterations      :: iteration = 45 / 100
# 2022-08-05 11:17:28,904 INFO Display              :: Data Fidelity--> 3.2942493441439207
# 2022-08-05 11:17:29,977 INFO CountIterations      :: iteration = 46 / 100
# 2022-08-05 11:17:30,448 INFO Display              :: Data Fidelity--> 3.284690311237745
# 2022-08-05 11:17:31,537 INFO CountIterations      :: iteration = 47 / 100
# 2022-08-05 11:17:31,991 INFO Display              :: Data Fidelity--> 3.2752128981490642
# 2022-08-05 11:17:33,047 INFO CountIterations      :: iteration = 48 / 100
# 2022-08-05 11:17:33,540 INFO Display              :: Data Fidelity--> 3.2658155923432486
# 2022-08-05 11:17:34,580 INFO CountIterations      :: iteration = 49 / 100
# 2022-08-05 11:17:35,092 INFO Display              :: Data Fidelity--> 3.2564969570364286
# 2022-08-05 11:17:36,158 INFO CountIterations      :: iteration = 50 / 100
# 2022-08-05 11:17:36,651 INFO Display              :: Data Fidelity--> 3.247255625005324
# 2022-08-05 11:17:37,766 INFO CountIterations      :: iteration = 51 / 100
# 2022-08-05 11:17:38,263 INFO Display              :: Data Fidelity--> 3.238090293025255
# 2022-08-05 11:17:39,343 INFO CountIterations      :: iteration = 52 / 100
# 2022-08-05 11:17:39,863 INFO Display              :: Data Fidelity--> 3.228999716863548
# 2022-08-05 11:17:40,870 INFO CountIterations      :: iteration = 53 / 100
# 2022-08-05 11:17:41,400 INFO Display              :: Data Fidelity--> 3.2199827067648368
# 2022-08-05 11:17:42,365 INFO CountIterations      :: iteration = 54 / 100
# 2022-08-05 11:17:42,790 INFO Display              :: Data Fidelity--> 3.211038123372119
# 2022-08-05 11:17:43,667 INFO CountIterations      :: iteration = 55 / 100
# 2022-08-05 11:17:44,148 INFO Display              :: Data Fidelity--> 3.2021648740356072
# 2022-08-05 11:17:45,214 INFO CountIterations      :: iteration = 56 / 100
# 2022-08-05 11:17:45,774 INFO Display              :: Data Fidelity--> 3.193361909466704
# 2022-08-05 11:17:46,777 INFO CountIterations      :: iteration = 57 / 100
# 2022-08-05 11:17:47,290 INFO Display              :: Data Fidelity--> 3.184628220699313
# 2022-08-05 11:17:48,278 INFO CountIterations      :: iteration = 58 / 100
# 2022-08-05 11:17:48,771 INFO Display              :: Data Fidelity--> 3.175962836326407
# 2022-08-05 11:17:49,874 INFO CountIterations      :: iteration = 59 / 100
# 2022-08-05 11:17:50,311 INFO Display              :: Data Fidelity--> 3.1673648199819926
# 2022-08-05 11:17:51,307 INFO CountIterations      :: iteration = 60 / 100
# 2022-08-05 11:17:51,741 INFO Display              :: Data Fidelity--> 3.158833268044013
# 2022-08-05 11:17:52,714 INFO CountIterations      :: iteration = 61 / 100
# 2022-08-05 11:17:53,234 INFO Display              :: Data Fidelity--> 3.1503673075344047
# 2022-08-05 11:17:54,216 INFO CountIterations      :: iteration = 62 / 100
# 2022-08-05 11:17:54,696 INFO Display              :: Data Fidelity--> 3.141966094197474
# 2022-08-05 11:17:55,872 INFO CountIterations      :: iteration = 63 / 100
# 2022-08-05 11:17:56,403 INFO Display              :: Data Fidelity--> 3.1336288107377506
# 2022-08-05 11:17:57,470 INFO CountIterations      :: iteration = 64 / 100
# 2022-08-05 11:17:57,920 INFO Display              :: Data Fidelity--> 3.125354665202789
# 2022-08-05 11:17:58,927 INFO CountIterations      :: iteration = 65 / 100
# 2022-08-05 11:17:59,409 INFO Display              :: Data Fidelity--> 3.11714288949564
# 2022-08-05 11:18:00,434 INFO CountIterations      :: iteration = 66 / 100
# 2022-08-05 11:18:00,900 INFO Display              :: Data Fidelity--> 3.1089927380054103
# 2022-08-05 11:18:01,941 INFO CountIterations      :: iteration = 67 / 100
# 2022-08-05 11:18:02,397 INFO Display              :: Data Fidelity--> 3.1009034863443024
# 2022-08-05 11:18:03,419 INFO CountIterations      :: iteration = 68 / 100
# 2022-08-05 11:18:03,937 INFO Display              :: Data Fidelity--> 3.0928744301817646
# 2022-08-05 11:18:05,142 INFO CountIterations      :: iteration = 69 / 100
# 2022-08-05 11:18:05,692 INFO Display              :: Data Fidelity--> 3.084904884165784
# 2022-08-05 11:18:06,698 INFO CountIterations      :: iteration = 70 / 100
# 2022-08-05 11:18:07,247 INFO Display              :: Data Fidelity--> 3.0769941809246673
# 2022-08-05 11:18:08,297 INFO CountIterations      :: iteration = 71 / 100
# 2022-08-05 11:18:08,812 INFO Display              :: Data Fidelity--> 3.0691416701409224
# 2022-08-05 11:18:09,868 INFO CountIterations      :: iteration = 72 / 100
# 2022-08-05 11:18:10,325 INFO Display              :: Data Fidelity--> 3.0613467176918068
# 2022-08-05 11:18:11,383 INFO CountIterations      :: iteration = 73 / 100
# 2022-08-05 11:18:11,925 INFO Display              :: Data Fidelity--> 3.0536087048502023
# 2022-08-05 11:18:12,956 INFO CountIterations      :: iteration = 74 / 100
# 2022-08-05 11:18:13,444 INFO Display              :: Data Fidelity--> 3.045927027540791
# 2022-08-05 11:18:14,506 INFO CountIterations      :: iteration = 75 / 100
# 2022-08-05 11:18:14,981 INFO Display              :: Data Fidelity--> 3.0383010956466663
# 2022-08-05 11:18:16,064 INFO CountIterations      :: iteration = 76 / 100
# 2022-08-05 11:18:16,540 INFO Display              :: Data Fidelity--> 3.0307303323626007
# 2022-08-05 11:18:17,529 INFO CountIterations      :: iteration = 77 / 100
# 2022-08-05 11:18:18,027 INFO Display              :: Data Fidelity--> 3.02321417359059
# 2022-08-05 11:18:19,043 INFO CountIterations      :: iteration = 78 / 100
# 2022-08-05 11:18:19,546 INFO Display              :: Data Fidelity--> 3.015752067374731
# 2022-08-05 11:18:20,621 INFO CountIterations      :: iteration = 79 / 100
# 2022-08-05 11:18:21,133 INFO Display              :: Data Fidelity--> 3.0083434733717507
# 2022-08-05 11:18:22,188 INFO CountIterations      :: iteration = 80 / 100
# 2022-08-05 11:18:22,690 INFO Display              :: Data Fidelity--> 3.0009878623550623
# 2022-08-05 11:18:23,794 INFO CountIterations      :: iteration = 81 / 100
# 2022-08-05 11:18:24,338 INFO Display              :: Data Fidelity--> 2.9936847157487487
# 2022-08-05 11:18:25,390 INFO CountIterations      :: iteration = 82 / 100
# 2022-08-05 11:18:25,916 INFO Display              :: Data Fidelity--> 2.9864335251905985
# 2022-08-05 11:18:27,000 INFO CountIterations      :: iteration = 83 / 100
# 2022-08-05 11:18:27,538 INFO Display              :: Data Fidelity--> 2.9792337921202527
# 2022-08-05 11:18:28,557 INFO CountIterations      :: iteration = 84 / 100
# 2022-08-05 11:18:29,024 INFO Display              :: Data Fidelity--> 2.9720850273925112
# 2022-08-05 11:18:30,134 INFO CountIterations      :: iteration = 85 / 100
# 2022-08-05 11:18:30,639 INFO Display              :: Data Fidelity--> 2.9649867509118515
# 2022-08-05 11:18:31,660 INFO CountIterations      :: iteration = 86 / 100
# 2022-08-05 11:18:32,147 INFO Display              :: Data Fidelity--> 2.957938491288683
# 2022-08-05 11:18:33,086 INFO CountIterations      :: iteration = 87 / 100
# 2022-08-05 11:18:33,514 INFO Display              :: Data Fidelity--> 2.9509397855144988
# 2022-08-05 11:18:34,501 INFO CountIterations      :: iteration = 88 / 100
# 2022-08-05 11:18:34,987 INFO Display              :: Data Fidelity--> 2.9439901786545324
# 2022-08-05 11:18:36,051 INFO CountIterations      :: iteration = 89 / 100
# 2022-08-05 11:18:36,516 INFO Display              :: Data Fidelity--> 2.937089223557897
# 2022-08-05 11:18:37,565 INFO CountIterations      :: iteration = 90 / 100
# 2022-08-05 11:18:38,012 INFO Display              :: Data Fidelity--> 2.9302364805824928
# 2022-08-05 11:18:38,976 INFO CountIterations      :: iteration = 91 / 100
# 2022-08-05 11:18:39,408 INFO Display              :: Data Fidelity--> 2.9234315173349215
# 2022-08-05 11:18:40,548 INFO CountIterations      :: iteration = 92 / 100
# 2022-08-05 11:18:40,991 INFO Display              :: Data Fidelity--> 2.9166739084237348
# 2022-08-05 11:18:42,133 INFO CountIterations      :: iteration = 93 / 100
# 2022-08-05 11:18:42,720 INFO Display              :: Data Fidelity--> 2.9099632352251144
# 2022-08-05 11:18:43,712 INFO CountIterations      :: iteration = 94 / 100
# 2022-08-05 11:18:44,186 INFO Display              :: Data Fidelity--> 2.9032990856609486
# 2022-08-05 11:18:45,304 INFO CountIterations      :: iteration = 95 / 100
# 2022-08-05 11:18:45,781 INFO Display              :: Data Fidelity--> 2.896681053987476
# 2022-08-05 11:18:46,821 INFO CountIterations      :: iteration = 96 / 100
# 2022-08-05 11:18:47,329 INFO Display              :: Data Fidelity--> 2.890108740594264
# 2022-08-05 11:18:48,422 INFO CountIterations      :: iteration = 97 / 100
# 2022-08-05 11:18:48,940 INFO Display              :: Data Fidelity--> 2.8835817518136606
# 2022-08-05 11:18:49,877 INFO CountIterations      :: iteration = 98 / 100
# 2022-08-05 11:18:50,314 INFO Display              :: Data Fidelity--> 2.8770996997383604
# 2022-08-05 11:18:51,260 INFO CountIterations      :: iteration = 99 / 100
# 2022-08-05 11:18:51,864 INFO Display              :: Data Fidelity--> 2.8706622020485133
# 2022-08-05 11:18:52,911 INFO CountIterations      :: iteration = 100 / 100
# 2022-08-05 11:18:52,912 INFO CombineRules         :: Rule CountIterations(max_iterations=100) triggered.
# 2022-08-05 11:18:52,912 INFO Gradient_Descent     :: Stopping rule triggered.
# No stations specified in self cal: defaulting to calibrating all stations!
# Computing the Model Visibilities with direct Fourier Transform...
# Producing clean visibilities from image with direct FT . . .
# Not Using Multiprocessing
# Scan 18/19 : [----------------------------  ]94%
# self_cal time: 1.659229 s
# /aux/vlb051a/anaconda3/envs/mrbeam/lib/python3.10/site-packages/ehtim/obsdata.py:509: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(datalist)

# %% [markdown]
# Further refinement round with updated data term

# %%
#-------------------------
# Fourth Round of Imaging: visibilities+closure_quantities + multiresolution support contraint
#-------------------------

print("Round 4: Multiscalar Imaging with visibilities and closure quantities ...")

#data weights
data_term = {'vis'    : 1.0,    # visibilities
             'cphase' : 1.0,    # closure phases
             'logcamp': 1.0}    # log closure amplitudes

#run gradient descent minimization
#stepsize automatically found
coeff, img, tau = handler.fourth_round(wtfcts, data_term, tau=tau, maxit=100)

img.display(cbar_unit=['Tb'], cfun=cfun, cbar_lims=cbar_lims)

#phase+amplitude calibration
obs_sc = eh.selfcal(obs_sc, img, method='both', ttype=ttype)
handler.updateobs(obs_sc.copy())
# Out:
# Round 4: Multiscalar Imaging with visibilities and closure quantities ...
# 2022-08-05 11:26:50,047 INFO CountIterations      :: iteration = 1 / 5
# 2022-08-05 11:26:50,430 INFO Display              :: Data Fidelity--> 3.978559682752028
# 2022-08-05 11:26:51,352 INFO CountIterations      :: iteration = 2 / 5
# 2022-08-05 11:26:51,753 INFO Display              :: Data Fidelity--> 3.958859227503095
# 2022-08-05 11:26:52,672 INFO CountIterations      :: iteration = 3 / 5
# 2022-08-05 11:26:53,035 INFO Display              :: Data Fidelity--> 3.9397790115849056
# 2022-08-05 11:26:53,830 INFO CountIterations      :: iteration = 4 / 5
# 2022-08-05 11:26:54,314 INFO Display              :: Data Fidelity--> 3.921247977899392
# 2022-08-05 11:26:55,164 INFO CountIterations      :: iteration = 5 / 5
# 2022-08-05 11:26:55,165 INFO CombineRules         :: Rule CountIterations(max_iterations=5) triggered.
# 2022-08-05 11:26:55,166 INFO Gradient_Descent     :: Stopping rule triggered.
# 2022-08-05 11:26:56,488 INFO CountIterations      :: iteration = 1 / 5
# 2022-08-05 11:26:56,875 INFO Display              :: Data Fidelity--> 3.885616717070816
# 2022-08-05 11:26:57,758 INFO CountIterations      :: iteration = 2 / 5
# 2022-08-05 11:26:58,118 INFO Display              :: Data Fidelity--> 3.8684307762153765
# 2022-08-05 11:26:58,947 INFO CountIterations      :: iteration = 3 / 5
# 2022-08-05 11:26:59,382 INFO Display              :: Data Fidelity--> 3.8516187462807934
# 2022-08-05 11:27:00,285 INFO CountIterations      :: iteration = 4 / 5
# 2022-08-05 11:27:00,646 INFO Display              :: Data Fidelity--> 3.835152751886577
# 2022-08-05 11:27:01,520 INFO CountIterations      :: iteration = 5 / 5
# 2022-08-05 11:27:01,521 INFO CombineRules         :: Rule CountIterations(max_iterations=5) triggered.
# 2022-08-05 11:27:01,522 INFO Gradient_Descent     :: Stopping rule triggered.
# 2022-08-05 11:27:02,797 INFO CountIterations      :: iteration = 1 / 5
# 2022-08-05 11:27:03,166 INFO Display              :: Data Fidelity--> 3.803167151962804
# 2022-08-05 11:27:04,007 INFO CountIterations      :: iteration = 2 / 5
# 2022-08-05 11:27:04,372 INFO Display              :: Data Fidelity--> 3.787609550766459
# 2022-08-05 11:27:05,247 INFO CountIterations      :: iteration = 3 / 5
# 2022-08-05 11:27:05,611 INFO Display              :: Data Fidelity--> 3.7723209335941323
# 2022-08-05 11:27:06,453 INFO CountIterations      :: iteration = 4 / 5
# 2022-08-05 11:27:06,830 INFO Display              :: Data Fidelity--> 3.7572879494289584
# 2022-08-05 11:27:07,733 INFO CountIterations      :: iteration = 5 / 5
# 2022-08-05 11:27:07,734 INFO CombineRules         :: Rule CountIterations(max_iterations=5) triggered.
# 2022-08-05 11:27:07,735 INFO Gradient_Descent     :: Stopping rule triggered.
# 2022-08-05 11:27:09,105 INFO CountIterations      :: iteration = 1 / 5
# 2022-08-05 11:27:09,526 INFO Display              :: Data Fidelity--> 3.7279432791588842
# 2022-08-05 11:27:10,415 INFO CountIterations      :: iteration = 2 / 5
# 2022-08-05 11:27:10,768 INFO Display              :: Data Fidelity--> 3.7136119580591638
# 2022-08-05 11:27:11,621 INFO CountIterations      :: iteration = 3 / 5
# 2022-08-05 11:27:12,000 INFO Display              :: Data Fidelity--> 3.69949660860779
# 2022-08-05 11:27:12,907 INFO CountIterations      :: iteration = 4 / 5
# 2022-08-05 11:27:13,353 INFO Display              :: Data Fidelity--> 3.6855897571422265
# 2022-08-05 11:27:14,217 INFO CountIterations      :: iteration = 5 / 5
# 2022-08-05 11:27:14,218 INFO CombineRules         :: Rule CountIterations(max_iterations=5) triggered.
# 2022-08-05 11:27:14,219 INFO Gradient_Descent     :: Stopping rule triggered.
# 2022-08-05 11:27:15,587 INFO CountIterations      :: iteration = 1 / 100
# 2022-08-05 11:27:15,955 INFO Display              :: Data Fidelity--> 3.978559682752028
# 2022-08-05 11:27:16,899 INFO CountIterations      :: iteration = 2 / 100
# 2022-08-05 11:27:17,285 INFO Display              :: Data Fidelity--> 3.958859227503095
# 2022-08-05 11:27:18,142 INFO CountIterations      :: iteration = 3 / 100
# 2022-08-05 11:27:18,546 INFO Display              :: Data Fidelity--> 3.9397790115849056
# 2022-08-05 11:27:19,464 INFO CountIterations      :: iteration = 4 / 100
# 2022-08-05 11:27:19,851 INFO Display              :: Data Fidelity--> 3.921247977899392
# 2022-08-05 11:27:20,652 INFO CountIterations      :: iteration = 5 / 100
# 2022-08-05 11:27:21,077 INFO Display              :: Data Fidelity--> 3.9032094442965226
# 2022-08-05 11:27:21,928 INFO CountIterations      :: iteration = 6 / 100
# 2022-08-05 11:27:22,332 INFO Display              :: Data Fidelity--> 3.885616717070816
# 2022-08-05 11:27:23,212 INFO CountIterations      :: iteration = 7 / 100
# 2022-08-05 11:27:23,580 INFO Display              :: Data Fidelity--> 3.8684307762153765
# 2022-08-05 11:27:24,409 INFO CountIterations      :: iteration = 8 / 100
# 2022-08-05 11:27:24,773 INFO Display              :: Data Fidelity--> 3.8516187462807934
# 2022-08-05 11:27:25,650 INFO CountIterations      :: iteration = 9 / 100
# 2022-08-05 11:27:26,079 INFO Display              :: Data Fidelity--> 3.835152751886577
# 2022-08-05 11:27:26,914 INFO CountIterations      :: iteration = 10 / 100
# 2022-08-05 11:27:27,283 INFO Display              :: Data Fidelity--> 3.819009018828791
# 2022-08-05 11:27:28,115 INFO CountIterations      :: iteration = 11 / 100
# 2022-08-05 11:27:28,483 INFO Display              :: Data Fidelity--> 3.803167151962804
# 2022-08-05 11:27:29,400 INFO CountIterations      :: iteration = 12 / 100
# 2022-08-05 11:27:29,767 INFO Display              :: Data Fidelity--> 3.787609550766459
# 2022-08-05 11:27:30,616 INFO CountIterations      :: iteration = 13 / 100
# 2022-08-05 11:27:31,035 INFO Display              :: Data Fidelity--> 3.7723209335941323
# 2022-08-05 11:27:31,853 INFO CountIterations      :: iteration = 14 / 100
# 2022-08-05 11:27:32,223 INFO Display              :: Data Fidelity--> 3.7572879494289584
# 2022-08-05 11:27:33,132 INFO CountIterations      :: iteration = 15 / 100
# 2022-08-05 11:27:33,535 INFO Display              :: Data Fidelity--> 3.7424988600304645
# 2022-08-05 11:27:34,318 INFO CountIterations      :: iteration = 16 / 100
# 2022-08-05 11:27:34,678 INFO Display              :: Data Fidelity--> 3.7279432791588842
# 2022-08-05 11:27:35,473 INFO CountIterations      :: iteration = 17 / 100
# 2022-08-05 11:27:35,834 INFO Display              :: Data Fidelity--> 3.7136119580591638
# 2022-08-05 11:27:36,655 INFO CountIterations      :: iteration = 18 / 100
# 2022-08-05 11:27:37,085 INFO Display              :: Data Fidelity--> 3.69949660860779
# 2022-08-05 11:27:37,936 INFO CountIterations      :: iteration = 19 / 100
# 2022-08-05 11:27:38,315 INFO Display              :: Data Fidelity--> 3.6855897571422265
# 2022-08-05 11:27:39,230 INFO CountIterations      :: iteration = 20 / 100
# 2022-08-05 11:27:39,682 INFO Display              :: Data Fidelity--> 3.6718846233672595
# 2022-08-05 11:27:40,622 INFO CountIterations      :: iteration = 21 / 100
# 2022-08-05 11:27:41,105 INFO Display              :: Data Fidelity--> 3.658375019782636
# 2022-08-05 11:27:42,083 INFO CountIterations      :: iteration = 22 / 100
# 2022-08-05 11:27:42,507 INFO Display              :: Data Fidelity--> 3.645055267946071
# 2022-08-05 11:27:43,409 INFO CountIterations      :: iteration = 23 / 100
# 2022-08-05 11:27:43,856 INFO Display              :: Data Fidelity--> 3.6319201285709193
# 2022-08-05 11:27:44,732 INFO CountIterations      :: iteration = 24 / 100
# 2022-08-05 11:27:45,145 INFO Display              :: Data Fidelity--> 3.6189647430172247
# 2022-08-05 11:27:45,944 INFO CountIterations      :: iteration = 25 / 100
# 2022-08-05 11:27:46,308 INFO Display              :: Data Fidelity--> 3.606184584183085
# 2022-08-05 11:27:47,134 INFO CountIterations      :: iteration = 26 / 100
# 2022-08-05 11:27:47,491 INFO Display              :: Data Fidelity--> 3.5935754151660984
# 2022-08-05 11:27:48,300 INFO CountIterations      :: iteration = 27 / 100
# 2022-08-05 11:27:48,667 INFO Display              :: Data Fidelity--> 3.581133254362822
# 2022-08-05 11:27:49,488 INFO CountIterations      :: iteration = 28 / 100
# 2022-08-05 11:27:49,914 INFO Display              :: Data Fidelity--> 3.56885434590919
# 2022-08-05 11:27:50,857 INFO CountIterations      :: iteration = 29 / 100
# 2022-08-05 11:27:51,244 INFO Display              :: Data Fidelity--> 3.5567351345652565
# 2022-08-05 11:27:52,062 INFO CountIterations      :: iteration = 30 / 100
# 2022-08-05 11:27:52,428 INFO Display              :: Data Fidelity--> 3.544772244301525
# 2022-08-05 11:27:53,321 INFO CountIterations      :: iteration = 31 / 100
# 2022-08-05 11:27:53,720 INFO Display              :: Data Fidelity--> 3.5329624599783505
# 2022-08-05 11:27:54,572 INFO CountIterations      :: iteration = 32 / 100
# 2022-08-05 11:27:54,981 INFO Display              :: Data Fidelity--> 3.5213027116125293
# 2022-08-05 11:27:55,812 INFO CountIterations      :: iteration = 33 / 100
# 2022-08-05 11:27:56,190 INFO Display              :: Data Fidelity--> 3.509790060816411
# 2022-08-05 11:27:57,104 INFO CountIterations      :: iteration = 34 / 100
# 2022-08-05 11:27:57,595 INFO Display              :: Data Fidelity--> 3.498421689061847
# 2022-08-05 11:27:58,455 INFO CountIterations      :: iteration = 35 / 100
# 2022-08-05 11:27:58,975 INFO Display              :: Data Fidelity--> 3.4871948874835796
# 2022-08-05 11:27:59,821 INFO CountIterations      :: iteration = 36 / 100
# 2022-08-05 11:28:00,239 INFO Display              :: Data Fidelity--> 3.476107047983335
# 2022-08-05 11:28:01,067 INFO CountIterations      :: iteration = 37 / 100
# 2022-08-05 11:28:01,486 INFO Display              :: Data Fidelity--> 3.4651556554363365
# 2022-08-05 11:28:02,433 INFO CountIterations      :: iteration = 38 / 100
# 2022-08-05 11:28:02,875 INFO Display              :: Data Fidelity--> 3.4543382808346204
# 2022-08-05 11:28:03,824 INFO CountIterations      :: iteration = 39 / 100
# 2022-08-05 11:28:04,262 INFO Display              :: Data Fidelity--> 3.4436525752285068
# 2022-08-05 11:28:05,178 INFO CountIterations      :: iteration = 40 / 100
# 2022-08-05 11:28:05,539 INFO Display              :: Data Fidelity--> 3.4330962643511316
# 2022-08-05 11:28:06,407 INFO CountIterations      :: iteration = 41 / 100
# 2022-08-05 11:28:06,808 INFO Display              :: Data Fidelity--> 3.4226671438277148
# 2022-08-05 11:28:07,706 INFO CountIterations      :: iteration = 42 / 100
# 2022-08-05 11:28:08,112 INFO Display              :: Data Fidelity--> 3.4123630748891713
# 2022-08-05 11:28:09,025 INFO CountIterations      :: iteration = 43 / 100
# 2022-08-05 11:28:09,453 INFO Display              :: Data Fidelity--> 3.40218198052026
# 2022-08-05 11:28:10,284 INFO CountIterations      :: iteration = 44 / 100
# 2022-08-05 11:28:10,733 INFO Display              :: Data Fidelity--> 3.392121841984813
# 2022-08-05 11:28:11,574 INFO CountIterations      :: iteration = 45 / 100
# 2022-08-05 11:28:11,955 INFO Display              :: Data Fidelity--> 3.3821806956783655
# 2022-08-05 11:28:12,903 INFO CountIterations      :: iteration = 46 / 100
# 2022-08-05 11:28:13,314 INFO Display              :: Data Fidelity--> 3.3723566302665082
# 2022-08-05 11:28:14,342 INFO CountIterations      :: iteration = 47 / 100
# 2022-08-05 11:28:14,749 INFO Display              :: Data Fidelity--> 3.3626477840743245
# 2022-08-05 11:28:15,693 INFO CountIterations      :: iteration = 48 / 100
# 2022-08-05 11:28:16,081 INFO Display              :: Data Fidelity--> 3.353052342695234
# 2022-08-05 11:28:17,076 INFO CountIterations      :: iteration = 49 / 100
# 2022-08-05 11:28:17,457 INFO Display              :: Data Fidelity--> 3.3435685367946646
# 2022-08-05 11:28:18,382 INFO CountIterations      :: iteration = 50 / 100
# 2022-08-05 11:28:18,880 INFO Display              :: Data Fidelity--> 3.3341946400855074
# 2022-08-05 11:28:19,829 INFO CountIterations      :: iteration = 51 / 100
# 2022-08-05 11:28:20,297 INFO Display              :: Data Fidelity--> 3.324928967456694
# 2022-08-05 11:28:21,166 INFO CountIterations      :: iteration = 52 / 100
# 2022-08-05 11:28:21,533 INFO Display              :: Data Fidelity--> 3.3157698732384446
# 2022-08-05 11:28:22,332 INFO CountIterations      :: iteration = 53 / 100
# 2022-08-05 11:28:22,686 INFO Display              :: Data Fidelity--> 3.306715749588971
# 2022-08-05 11:28:23,565 INFO CountIterations      :: iteration = 54 / 100
# 2022-08-05 11:28:23,940 INFO Display              :: Data Fidelity--> 3.2977650249924255
# 2022-08-05 11:28:24,952 INFO CountIterations      :: iteration = 55 / 100
# 2022-08-05 11:28:25,358 INFO Display              :: Data Fidelity--> 3.2889161628544334
# 2022-08-05 11:28:26,293 INFO CountIterations      :: iteration = 56 / 100
# 2022-08-05 11:28:26,668 INFO Display              :: Data Fidelity--> 3.2801676601881766
# 2022-08-05 11:28:27,509 INFO CountIterations      :: iteration = 57 / 100
# 2022-08-05 11:28:27,892 INFO Display              :: Data Fidelity--> 3.271518046381577
# 2022-08-05 11:28:28,709 INFO CountIterations      :: iteration = 58 / 100
# 2022-08-05 11:28:29,080 INFO Display              :: Data Fidelity--> 3.262965882038097
# 2022-08-05 11:28:29,890 INFO CountIterations      :: iteration = 59 / 100
# 2022-08-05 11:28:30,247 INFO Display              :: Data Fidelity--> 3.254509757885879
# 2022-08-05 11:28:31,087 INFO CountIterations      :: iteration = 60 / 100
# 2022-08-05 11:28:31,466 INFO Display              :: Data Fidelity--> 3.246148293748124
# 2022-08-05 11:28:32,364 INFO CountIterations      :: iteration = 61 / 100
# 2022-08-05 11:28:32,768 INFO Display              :: Data Fidelity--> 3.237880137570386
# 2022-08-05 11:28:33,663 INFO CountIterations      :: iteration = 62 / 100
# 2022-08-05 11:28:34,044 INFO Display              :: Data Fidelity--> 3.229703964500391
# 2022-08-05 11:28:34,935 INFO CountIterations      :: iteration = 63 / 100
# 2022-08-05 11:28:35,392 INFO Display              :: Data Fidelity--> 3.221618476015921
# 2022-08-05 11:28:36,325 INFO CountIterations      :: iteration = 64 / 100
# 2022-08-05 11:28:36,776 INFO Display              :: Data Fidelity--> 3.2136223990970327
# 2022-08-05 11:28:37,672 INFO CountIterations      :: iteration = 65 / 100
# 2022-08-05 11:28:38,068 INFO Display              :: Data Fidelity--> 3.2057144854398922
# 2022-08-05 11:28:39,083 INFO CountIterations      :: iteration = 66 / 100
# 2022-08-05 11:28:39,568 INFO Display              :: Data Fidelity--> 3.197893510708853
# 2022-08-05 11:28:40,539 INFO CountIterations      :: iteration = 67 / 100
# 2022-08-05 11:28:41,059 INFO Display              :: Data Fidelity--> 3.1901582738240544
# 2022-08-05 11:28:42,066 INFO CountIterations      :: iteration = 68 / 100
# 2022-08-05 11:28:42,503 INFO Display              :: Data Fidelity--> 3.1825075962823095
# 2022-08-05 11:28:43,341 INFO CountIterations      :: iteration = 69 / 100
# 2022-08-05 11:28:43,753 INFO Display              :: Data Fidelity--> 3.1749403215089673
# 2022-08-05 11:28:44,567 INFO CountIterations      :: iteration = 70 / 100
# 2022-08-05 11:28:44,945 INFO Display              :: Data Fidelity--> 3.1674553142388793
# 2022-08-05 11:28:45,728 INFO CountIterations      :: iteration = 71 / 100
# 2022-08-05 11:28:46,105 INFO Display              :: Data Fidelity--> 3.1600514599242184
# 2022-08-05 11:28:46,947 INFO CountIterations      :: iteration = 72 / 100
# 2022-08-05 11:28:47,386 INFO Display              :: Data Fidelity--> 3.152727664167742
# 2022-08-05 11:28:48,288 INFO CountIterations      :: iteration = 73 / 100
# 2022-08-05 11:28:48,643 INFO Display              :: Data Fidelity--> 3.145482852180569
# 2022-08-05 11:28:49,469 INFO CountIterations      :: iteration = 74 / 100
# 2022-08-05 11:28:49,855 INFO Display              :: Data Fidelity--> 3.138315968261099
# 2022-08-05 11:28:50,648 INFO CountIterations      :: iteration = 75 / 100
# 2022-08-05 11:28:50,997 INFO Display              :: Data Fidelity--> 3.1312259752964393
# 2022-08-05 11:28:51,765 INFO CountIterations      :: iteration = 76 / 100
# 2022-08-05 11:28:52,115 INFO Display              :: Data Fidelity--> 3.1242118542826463
# 2022-08-05 11:28:52,884 INFO CountIterations      :: iteration = 77 / 100
# 2022-08-05 11:28:53,234 INFO Display              :: Data Fidelity--> 3.117272603864595
# 2022-08-05 11:28:54,048 INFO CountIterations      :: iteration = 78 / 100
# 2022-08-05 11:28:54,397 INFO Display              :: Data Fidelity--> 3.110407239892443
# 2022-08-05 11:28:55,383 INFO CountIterations      :: iteration = 79 / 100
# 2022-08-05 11:28:55,772 INFO Display              :: Data Fidelity--> 3.1036147949963095
# 2022-08-05 11:28:56,675 INFO CountIterations      :: iteration = 80 / 100
# 2022-08-05 11:28:57,028 INFO Display              :: Data Fidelity--> 3.0968943181754325
# 2022-08-05 11:28:58,035 INFO CountIterations      :: iteration = 81 / 100
# 2022-08-05 11:28:58,515 INFO Display              :: Data Fidelity--> 3.0902448744031457
# 2022-08-05 11:28:59,407 INFO CountIterations      :: iteration = 82 / 100
# 2022-08-05 11:28:59,816 INFO Display              :: Data Fidelity--> 3.0836655442457155
# 2022-08-05 11:29:00,620 INFO CountIterations      :: iteration = 83 / 100
# 2022-08-05 11:29:00,972 INFO Display              :: Data Fidelity--> 3.0771554234948386
# 2022-08-05 11:29:01,778 INFO CountIterations      :: iteration = 84 / 100
# 2022-08-05 11:29:02,156 INFO Display              :: Data Fidelity--> 3.0707136228128866
# 2022-08-05 11:29:03,026 INFO CountIterations      :: iteration = 85 / 100
# 2022-08-05 11:29:03,438 INFO Display              :: Data Fidelity--> 3.0643392673903547
# 2022-08-05 11:29:04,288 INFO CountIterations      :: iteration = 86 / 100
# 2022-08-05 11:29:04,637 INFO Display              :: Data Fidelity--> 3.058031496614677
# 2022-08-05 11:29:05,417 INFO CountIterations      :: iteration = 87 / 100
# 2022-08-05 11:29:05,769 INFO Display              :: Data Fidelity--> 3.0517894637507217
# 2022-08-05 11:29:06,539 INFO CountIterations      :: iteration = 88 / 100
# 2022-08-05 11:29:06,891 INFO Display              :: Data Fidelity--> 3.0456123356306772
# 2022-08-05 11:29:07,661 INFO CountIterations      :: iteration = 89 / 100
# 2022-08-05 11:29:08,014 INFO Display              :: Data Fidelity--> 3.039499292355206
# 2022-08-05 11:29:08,810 INFO CountIterations      :: iteration = 90 / 100
# 2022-08-05 11:29:09,233 INFO Display              :: Data Fidelity--> 3.033449527003115
# 2022-08-05 11:29:10,139 INFO CountIterations      :: iteration = 91 / 100
# 2022-08-05 11:29:10,552 INFO Display              :: Data Fidelity--> 3.0274622453508186
# 2022-08-05 11:29:11,394 INFO CountIterations      :: iteration = 92 / 100
# 2022-08-05 11:29:11,808 INFO Display              :: Data Fidelity--> 3.021536665600191
# 2022-08-05 11:29:12,688 INFO CountIterations      :: iteration = 93 / 100
# 2022-08-05 11:29:13,111 INFO Display              :: Data Fidelity--> 3.0156720181147483
# 2022-08-05 11:29:14,038 INFO CountIterations      :: iteration = 94 / 100
# 2022-08-05 11:29:14,390 INFO Display              :: Data Fidelity--> 3.00986754516415
# 2022-08-05 11:29:15,231 INFO CountIterations      :: iteration = 95 / 100
# 2022-08-05 11:29:15,581 INFO Display              :: Data Fidelity--> 3.0041225006757175
# 2022-08-05 11:29:16,467 INFO CountIterations      :: iteration = 96 / 100
# 2022-08-05 11:29:16,864 INFO Display              :: Data Fidelity--> 2.9984361499939247
# 2022-08-05 11:29:17,709 INFO CountIterations      :: iteration = 97 / 100
# 2022-08-05 11:29:18,059 INFO Display              :: Data Fidelity--> 2.9928077696462627
# 2022-08-05 11:29:18,838 INFO CountIterations      :: iteration = 98 / 100
# 2022-08-05 11:29:19,237 INFO Display              :: Data Fidelity--> 2.987236647116565
# 2022-08-05 11:29:20,167 INFO CountIterations      :: iteration = 99 / 100
# 2022-08-05 11:29:20,542 INFO Display              :: Data Fidelity--> 2.981722080623914
# 2022-08-05 11:29:21,405 INFO CountIterations      :: iteration = 100 / 100
# 2022-08-05 11:29:21,405 INFO CombineRules         :: Rule CountIterations(max_iterations=100) triggered.
# 2022-08-05 11:29:21,406 INFO Gradient_Descent     :: Stopping rule triggered.
# No stations specified in self cal: defaulting to calibrating all stations!
# Computing the Model Visibilities with direct Fourier Transform...
# Producing clean visibilities from image with direct FT . . .
# Not Using Multiprocessing
# Scan 18/19 : [----------------------------  ]94%
# self_cal time: 1.835784 s
# /aux/vlb051a/anaconda3/envs/mrbeam/lib/python3.10/site-packages/ehtim/obsdata.py:509: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(datalist)

# %% [markdown]
# Last refinement round with small stepsize gardient descent to self-calibrated dataset to increase fit to data. This last round doesn't change the image on a level visible by eye anymore.

# %%
#-------------------------
# Fifth Round of Imaging: visibilities
#-------------------------

print("Round 5: Single Scalar Imaging with visibilities ...")

#project solution to postive values
init = np.maximum(0, img.imarr()/rescaling)

#run gradient descent minimization
#stepsize automatically found
img = handler.fifth_round(init.copy(), data_term, tau=tau, maxit=1000)

img.display(cbar_unit=['Tb'], cfun=cfun, cbar_lims=cbar_lims)
# Out:
# 2022-08-05 11:33:06,322 INFO CountIterations      :: iteration = 1 / 5
# 2022-08-05 11:33:06,355 INFO Display              :: Data Fidelity--> 68.93874358503146
# 2022-08-05 11:33:06,402 INFO CountIterations      :: iteration = 2 / 5
# Round 5: Single Scalar Imaging with visibilities ...
# 2022-08-05 11:33:06,439 INFO Display              :: Data Fidelity--> 19913.865191915862
# 2022-08-05 11:33:06,489 INFO CountIterations      :: iteration = 3 / 5
# 2022-08-05 11:33:06,510 INFO Display              :: Data Fidelity--> 4427409.457071637
# 2022-08-05 11:33:06,554 INFO CountIterations      :: iteration = 4 / 5
# 2022-08-05 11:33:06,575 INFO Display              :: Data Fidelity--> 1004581341.2247492
# 2022-08-05 11:33:06,635 INFO CountIterations      :: iteration = 5 / 5
# 2022-08-05 11:33:06,637 INFO CombineRules         :: Rule CountIterations(max_iterations=5) triggered.
# 2022-08-05 11:33:06,637 INFO Gradient_Descent     :: Stopping rule triggered.
# 2022-08-05 11:33:06,729 INFO CountIterations      :: iteration = 1 / 5
# 2022-08-05 11:33:06,755 INFO Display              :: Data Fidelity--> 20.511626057201354
# 2022-08-05 11:33:06,814 INFO CountIterations      :: iteration = 2 / 5
# 2022-08-05 11:33:06,845 INFO Display              :: Data Fidelity--> 1848.4996954029773
# Stepsize to big, try to run with smaller stepsize
# 2022-08-05 11:33:06,909 INFO CountIterations      :: iteration = 3 / 5
# 2022-08-05 11:33:06,935 INFO Display              :: Data Fidelity--> 89103.3093108742
# 2022-08-05 11:33:06,978 INFO CountIterations      :: iteration = 4 / 5
# 2022-08-05 11:33:07,005 INFO Display              :: Data Fidelity--> 4385515.33018445
# 2022-08-05 11:33:07,048 INFO CountIterations      :: iteration = 5 / 5
# 2022-08-05 11:33:07,049 INFO CombineRules         :: Rule CountIterations(max_iterations=5) triggered.
# 2022-08-05 11:33:07,050 INFO Gradient_Descent     :: Stopping rule triggered.
# 2022-08-05 11:33:07,115 INFO CountIterations      :: iteration = 1 / 5
# 2022-08-05 11:33:07,154 INFO Display              :: Data Fidelity--> 7.026395294743744
# 2022-08-05 11:33:07,211 INFO CountIterations      :: iteration = 2 / 5
# 2022-08-05 11:33:07,242 INFO Display              :: Data Fidelity--> 165.89316515182855
# Stepsize to big, try to run with smaller stepsize
# 2022-08-05 11:33:07,299 INFO CountIterations      :: iteration = 3 / 5
# 2022-08-05 11:33:07,328 INFO Display              :: Data Fidelity--> 2146.0593208879513
# 2022-08-05 11:33:07,384 INFO CountIterations      :: iteration = 4 / 5
# 2022-08-05 11:33:07,405 INFO Display              :: Data Fidelity--> 19290.74629318532
# 2022-08-05 11:33:07,449 INFO CountIterations      :: iteration = 5 / 5
# 2022-08-05 11:33:07,451 INFO CombineRules         :: Rule CountIterations(max_iterations=5) triggered.
# 2022-08-05 11:33:07,452 INFO Gradient_Descent     :: Stopping rule triggered.
# 2022-08-05 11:33:07,540 INFO CountIterations      :: iteration = 1 / 5
# 2022-08-05 11:33:07,566 INFO Display              :: Data Fidelity--> 3.709698232857257
# 2022-08-05 11:33:07,610 INFO CountIterations      :: iteration = 2 / 5
# 2022-08-05 11:33:07,631 INFO Display              :: Data Fidelity--> 14.562984822676956
# Stepsize to big, try to run with smaller stepsize
# 2022-08-05 11:33:07,683 INFO CountIterations      :: iteration = 3 / 5
# 2022-08-05 11:33:07,708 INFO Display              :: Data Fidelity--> 106.65729883979616
# 2022-08-05 11:33:07,758 INFO CountIterations      :: iteration = 4 / 5
# 2022-08-05 11:33:07,783 INFO Display              :: Data Fidelity--> 287.11694726905375
# 2022-08-05 11:33:07,833 INFO CountIterations      :: iteration = 5 / 5
# 2022-08-05 11:33:07,835 INFO CombineRules         :: Rule CountIterations(max_iterations=5) triggered.
# 2022-08-05 11:33:07,835 INFO Gradient_Descent     :: Stopping rule triggered.
# 2022-08-05 11:33:07,915 INFO CountIterations      :: iteration = 1 / 5
# 2022-08-05 11:33:07,940 INFO Display              :: Data Fidelity--> 2.800736194577188
# 2022-08-05 11:33:07,990 INFO CountIterations      :: iteration = 2 / 5
# 2022-08-05 11:33:08,015 INFO Display              :: Data Fidelity--> 3.6999672750845853
# Stepsize to big, try to run with smaller stepsize
# 2022-08-05 11:33:08,065 INFO CountIterations      :: iteration = 3 / 5
# 2022-08-05 11:33:08,092 INFO Display              :: Data Fidelity--> 5.19664809513462
# 2022-08-05 11:33:08,142 INFO CountIterations      :: iteration = 4 / 5
# 2022-08-05 11:33:08,167 INFO Display              :: Data Fidelity--> 7.018163110487663
# 2022-08-05 11:33:08,216 INFO CountIterations      :: iteration = 5 / 5
# 2022-08-05 11:33:08,218 INFO CombineRules         :: Rule CountIterations(max_iterations=5) triggered.
# 2022-08-05 11:33:08,219 INFO Gradient_Descent     :: Stopping rule triggered.
# 2022-08-05 11:33:08,298 INFO CountIterations      :: iteration = 1 / 5
# 2022-08-05 11:33:08,323 INFO Display              :: Data Fidelity--> 2.633958731770299
# 2022-08-05 11:33:08,373 INFO CountIterations      :: iteration = 2 / 5
# 2022-08-05 11:33:08,398 INFO Display              :: Data Fidelity--> 2.581309143507868
# Stepsize to big, try to run with smaller stepsize
# 2022-08-05 11:33:08,447 INFO CountIterations      :: iteration = 3 / 5
# 2022-08-05 11:33:08,474 INFO Display              :: Data Fidelity--> 2.5424639265398867
# 2022-08-05 11:33:08,523 INFO CountIterations      :: iteration = 4 / 5
# 2022-08-05 11:33:08,560 INFO Display              :: Data Fidelity--> 2.5158957739219034
# 2022-08-05 11:33:08,615 INFO CountIterations      :: iteration = 5 / 5
# 2022-08-05 11:33:08,617 INFO CombineRules         :: Rule CountIterations(max_iterations=5) triggered.
# 2022-08-05 11:33:08,618 INFO Gradient_Descent     :: Stopping rule triggered.
# 2022-08-05 11:33:08,710 INFO CountIterations      :: iteration = 1 / 5
# 2022-08-05 11:33:08,737 INFO Display              :: Data Fidelity--> 2.4883583329173864
# 2022-08-05 11:33:08,794 INFO CountIterations      :: iteration = 2 / 5
# 2022-08-05 11:33:08,827 INFO Display              :: Data Fidelity--> 2.472035802876782
# 2022-08-05 11:33:08,885 INFO CountIterations      :: iteration = 3 / 5
# 2022-08-05 11:33:08,913 INFO Display              :: Data Fidelity--> 2.467458102544778
# 2022-08-05 11:33:08,962 INFO CountIterations      :: iteration = 4 / 5
# 2022-08-05 11:33:08,988 INFO Display              :: Data Fidelity--> 2.4378449941961375
# 2022-08-05 11:33:09,038 INFO CountIterations      :: iteration = 5 / 5
# 2022-08-05 11:33:09,039 INFO CombineRules         :: Rule CountIterations(max_iterations=5) triggered.
# 2022-08-05 11:33:09,040 INFO Gradient_Descent     :: Stopping rule triggered.
# 2022-08-05 11:33:09,118 INFO CountIterations      :: iteration = 1 / 5
# 2022-08-05 11:33:09,143 INFO Display              :: Data Fidelity--> 2.4017442332922263
# 2022-08-05 11:33:09,194 INFO CountIterations      :: iteration = 2 / 5
# 2022-08-05 11:33:09,219 INFO Display              :: Data Fidelity--> 2.396609181234675
# 2022-08-05 11:33:09,269 INFO CountIterations      :: iteration = 3 / 5
# 2022-08-05 11:33:09,310 INFO Display              :: Data Fidelity--> 2.3720434621053506
# 2022-08-05 11:33:09,360 INFO CountIterations      :: iteration = 4 / 5
# 2022-08-05 11:33:09,386 INFO Display              :: Data Fidelity--> 2.369372427067318
# 2022-08-05 11:33:09,436 INFO CountIterations      :: iteration = 5 / 5
# 2022-08-05 11:33:09,437 INFO CombineRules         :: Rule CountIterations(max_iterations=5) triggered.
# 2022-08-05 11:33:09,438 INFO Gradient_Descent     :: Stopping rule triggered.
# 2022-08-05 11:33:09,517 INFO CountIterations      :: iteration = 1 / 5
# 2022-08-05 11:33:09,542 INFO Display              :: Data Fidelity--> 2.3453720855358204
# 2022-08-05 11:33:09,592 INFO CountIterations      :: iteration = 2 / 5
# 2022-08-05 11:33:09,617 INFO Display              :: Data Fidelity--> 2.323695032399815
# 2022-08-05 11:33:09,667 INFO CountIterations      :: iteration = 3 / 5
# 2022-08-05 11:33:09,692 INFO Display              :: Data Fidelity--> 2.3235697348564903
# 2022-08-05 11:33:09,742 INFO CountIterations      :: iteration = 4 / 5
# 2022-08-05 11:33:09,767 INFO Display              :: Data Fidelity--> 2.3029567407987437
# 2022-08-05 11:33:09,817 INFO CountIterations      :: iteration = 5 / 5
# 2022-08-05 11:33:09,819 INFO CombineRules         :: Rule CountIterations(max_iterations=5) triggered.
# 2022-08-05 11:33:09,820 INFO Gradient_Descent     :: Stopping rule triggered.
# 2022-08-05 11:33:09,897 INFO CountIterations      :: iteration = 1 / 1000
# 2022-08-05 11:33:09,922 INFO Display              :: Data Fidelity--> 2.633958731770299
# 2022-08-05 11:33:09,971 INFO CountIterations      :: iteration = 2 / 1000
# 2022-08-05 11:33:09,996 INFO Display              :: Data Fidelity--> 2.581309143507868
# 2022-08-05 11:33:10,044 INFO CountIterations      :: iteration = 3 / 1000
# 2022-08-05 11:33:10,069 INFO Display              :: Data Fidelity--> 2.5424639265398867
# 2022-08-05 11:33:10,118 INFO CountIterations      :: iteration = 4 / 1000
# 2022-08-05 11:33:10,144 INFO Display              :: Data Fidelity--> 2.5158957739219034
# 2022-08-05 11:33:10,195 INFO CountIterations      :: iteration = 5 / 1000
# 2022-08-05 11:33:10,220 INFO Display              :: Data Fidelity--> 2.4953513410556822
# 2022-08-05 11:33:10,270 INFO CountIterations      :: iteration = 6 / 1000
# 2022-08-05 11:33:10,295 INFO Display              :: Data Fidelity--> 2.4883583329173864
# 2022-08-05 11:33:10,346 INFO CountIterations      :: iteration = 7 / 1000
# 2022-08-05 11:33:10,371 INFO Display              :: Data Fidelity--> 2.472035802876782
# 2022-08-05 11:33:10,421 INFO CountIterations      :: iteration = 8 / 1000
# 2022-08-05 11:33:10,447 INFO Display              :: Data Fidelity--> 2.467458102544778
# 2022-08-05 11:33:10,496 INFO CountIterations      :: iteration = 9 / 1000
# 2022-08-05 11:33:10,521 INFO Display              :: Data Fidelity--> 2.4378449941961375
# 2022-08-05 11:33:10,572 INFO CountIterations      :: iteration = 10 / 1000
# 2022-08-05 11:33:10,597 INFO Display              :: Data Fidelity--> 2.4300407172155545
# 2022-08-05 11:33:10,647 INFO CountIterations      :: iteration = 11 / 1000
# 2022-08-05 11:33:10,672 INFO Display              :: Data Fidelity--> 2.4017442332922263
# 2022-08-05 11:33:10,738 INFO CountIterations      :: iteration = 12 / 1000
# 2022-08-05 11:33:10,764 INFO Display              :: Data Fidelity--> 2.396609181234675
# 2022-08-05 11:33:10,813 INFO CountIterations      :: iteration = 13 / 1000
# 2022-08-05 11:33:10,836 INFO Display              :: Data Fidelity--> 2.3720434621053506
# 2022-08-05 11:33:10,880 INFO CountIterations      :: iteration = 14 / 1000
# 2022-08-05 11:33:10,901 INFO Display              :: Data Fidelity--> 2.369372427067318
# 2022-08-05 11:33:10,943 INFO CountIterations      :: iteration = 15 / 1000
# 2022-08-05 11:33:10,964 INFO Display              :: Data Fidelity--> 2.3465779443210515
# 2022-08-05 11:33:11,007 INFO CountIterations      :: iteration = 16 / 1000
# 2022-08-05 11:33:11,039 INFO Display              :: Data Fidelity--> 2.3453720855358204
# 2022-08-05 11:33:11,095 INFO CountIterations      :: iteration = 17 / 1000
# 2022-08-05 11:33:11,118 INFO Display              :: Data Fidelity--> 2.323695032399815
# 2022-08-05 11:33:11,167 INFO CountIterations      :: iteration = 18 / 1000
# 2022-08-05 11:33:11,192 INFO Display              :: Data Fidelity--> 2.3235697348564903
# 2022-08-05 11:33:11,241 INFO CountIterations      :: iteration = 19 / 1000
# 2022-08-05 11:33:11,265 INFO Display              :: Data Fidelity--> 2.3029567407987437
# 2022-08-05 11:33:11,314 INFO CountIterations      :: iteration = 20 / 1000
# 2022-08-05 11:33:11,338 INFO Display              :: Data Fidelity--> 2.3037465624777402
# 2022-08-05 11:33:11,387 INFO CountIterations      :: iteration = 21 / 1000
# 2022-08-05 11:33:11,412 INFO Display              :: Data Fidelity--> 2.28410255760334
# 2022-08-05 11:33:11,460 INFO CountIterations      :: iteration = 22 / 1000
# 2022-08-05 11:33:11,485 INFO Display              :: Data Fidelity--> 2.2856554747710227
# 2022-08-05 11:33:11,534 INFO CountIterations      :: iteration = 23 / 1000
# 2022-08-05 11:33:11,558 INFO Display              :: Data Fidelity--> 2.2668456873948664
# 2022-08-05 11:33:11,607 INFO CountIterations      :: iteration = 24 / 1000
# 2022-08-05 11:33:11,631 INFO Display              :: Data Fidelity--> 2.2690288160833023
# 2022-08-05 11:33:11,679 INFO CountIterations      :: iteration = 25 / 1000
# 2022-08-05 11:33:11,704 INFO Display              :: Data Fidelity--> 2.250938794270505
# 2022-08-05 11:33:11,753 INFO CountIterations      :: iteration = 26 / 1000
# 2022-08-05 11:33:11,777 INFO Display              :: Data Fidelity--> 2.2536487281805018
# 2022-08-05 11:33:11,831 INFO CountIterations      :: iteration = 27 / 1000
# 2022-08-05 11:33:11,855 INFO Display              :: Data Fidelity--> 2.2361868720151543
# 2022-08-05 11:33:11,904 INFO CountIterations      :: iteration = 28 / 1000
# 2022-08-05 11:33:11,929 INFO Display              :: Data Fidelity--> 2.2393432044052943
# 2022-08-05 11:33:11,978 INFO CountIterations      :: iteration = 29 / 1000
# 2022-08-05 11:33:12,002 INFO Display              :: Data Fidelity--> 2.2224326410816584
# 2022-08-05 11:33:12,051 INFO CountIterations      :: iteration = 30 / 1000
# 2022-08-05 11:33:12,076 INFO Display              :: Data Fidelity--> 2.2259712400644474
# 2022-08-05 11:33:12,123 INFO CountIterations      :: iteration = 31 / 1000
# 2022-08-05 11:33:12,146 INFO Display              :: Data Fidelity--> 2.209546396557214
# 2022-08-05 11:33:12,195 INFO CountIterations      :: iteration = 32 / 1000
# 2022-08-05 11:33:12,219 INFO Display              :: Data Fidelity--> 2.2134155298011797
# 2022-08-05 11:33:12,267 INFO CountIterations      :: iteration = 33 / 1000
# 2022-08-05 11:33:12,291 INFO Display              :: Data Fidelity--> 2.197420553205818
# 2022-08-05 11:33:12,339 INFO CountIterations      :: iteration = 34 / 1000
# 2022-08-05 11:33:12,362 INFO Display              :: Data Fidelity--> 2.2015782834293494
# 2022-08-05 11:33:12,406 INFO CountIterations      :: iteration = 35 / 1000
# 2022-08-05 11:33:12,427 INFO Display              :: Data Fidelity--> 2.1859655361614374
# 2022-08-05 11:33:12,471 INFO CountIterations      :: iteration = 36 / 1000
# 2022-08-05 11:33:12,492 INFO Display              :: Data Fidelity--> 2.190377669985721
# 2022-08-05 11:33:12,540 INFO CountIterations      :: iteration = 37 / 1000
# 2022-08-05 11:33:12,565 INFO Display              :: Data Fidelity--> 2.1751063327976126
# 2022-08-05 11:33:12,614 INFO CountIterations      :: iteration = 38 / 1000
# 2022-08-05 11:33:12,639 INFO Display              :: Data Fidelity--> 2.179744808061084
# 2022-08-05 11:33:12,688 INFO CountIterations      :: iteration = 39 / 1000
# 2022-08-05 11:33:12,713 INFO Display              :: Data Fidelity--> 2.1647797243035045
# 2022-08-05 11:33:12,762 INFO CountIterations      :: iteration = 40 / 1000
# 2022-08-05 11:33:12,787 INFO Display              :: Data Fidelity--> 2.1696213633045387
# 2022-08-05 11:33:12,836 INFO CountIterations      :: iteration = 41 / 1000
# 2022-08-05 11:33:12,861 INFO Display              :: Data Fidelity--> 2.1549321017698575
# 2022-08-05 11:33:12,905 INFO CountIterations      :: iteration = 42 / 1000
# 2022-08-05 11:33:12,927 INFO Display              :: Data Fidelity--> 2.159957642416807
# 2022-08-05 11:33:12,970 INFO CountIterations      :: iteration = 43 / 1000
# 2022-08-05 11:33:12,991 INFO Display              :: Data Fidelity--> 2.1455177301676795
# 2022-08-05 11:33:13,035 INFO CountIterations      :: iteration = 44 / 1000
# 2022-08-05 11:33:13,056 INFO Display              :: Data Fidelity--> 2.150711065242277
# 2022-08-05 11:33:13,120 INFO CountIterations      :: iteration = 45 / 1000
# 2022-08-05 11:33:13,148 INFO Display              :: Data Fidelity--> 2.1364973570920798
# 2022-08-05 11:33:13,198 INFO CountIterations      :: iteration = 46 / 1000
# 2022-08-05 11:33:13,224 INFO Display              :: Data Fidelity--> 2.141844932610566
# 2022-08-05 11:33:13,274 INFO CountIterations      :: iteration = 47 / 1000
# 2022-08-05 11:33:13,299 INFO Display              :: Data Fidelity--> 2.1278370927561308
# 2022-08-05 11:33:13,348 INFO CountIterations      :: iteration = 48 / 1000
# 2022-08-05 11:33:13,372 INFO Display              :: Data Fidelity--> 2.1333274296400058
# 2022-08-05 11:33:13,422 INFO CountIterations      :: iteration = 49 / 1000
# 2022-08-05 11:33:13,446 INFO Display              :: Data Fidelity--> 2.1195075048815983
# 2022-08-05 11:33:13,496 INFO CountIterations      :: iteration = 50 / 1000
# 2022-08-05 11:33:13,521 INFO Display              :: Data Fidelity--> 2.1251308168094885
# 2022-08-05 11:33:13,570 INFO CountIterations      :: iteration = 51 / 1000
# 2022-08-05 11:33:13,594 INFO Display              :: Data Fidelity--> 2.111482884174141
# 2022-08-05 11:33:13,642 INFO CountIterations      :: iteration = 52 / 1000
# 2022-08-05 11:33:13,668 INFO Display              :: Data Fidelity--> 2.1172307708712523
# 2022-08-05 11:33:13,717 INFO CountIterations      :: iteration = 53 / 1000
# 2022-08-05 11:33:13,742 INFO Display              :: Data Fidelity--> 2.103740645674829
# 2022-08-05 11:33:13,791 INFO CountIterations      :: iteration = 54 / 1000
# 2022-08-05 11:33:13,816 INFO Display              :: Data Fidelity--> 2.1096058457228595
# 2022-08-05 11:33:13,866 INFO CountIterations      :: iteration = 55 / 1000
# 2022-08-05 11:33:13,892 INFO Display              :: Data Fidelity--> 2.0962608388130715
# 2022-08-05 11:33:13,941 INFO CountIterations      :: iteration = 56 / 1000
# 2022-08-05 11:33:13,965 INFO Display              :: Data Fidelity--> 2.102237029688812
# 2022-08-05 11:33:14,014 INFO CountIterations      :: iteration = 57 / 1000
# 2022-08-05 11:33:14,040 INFO Display              :: Data Fidelity--> 2.0890257447999154
# 2022-08-05 11:33:14,090 INFO CountIterations      :: iteration = 58 / 1000
# 2022-08-05 11:33:14,115 INFO Display              :: Data Fidelity--> 2.095107380574479
# 2022-08-05 11:33:14,164 INFO CountIterations      :: iteration = 59 / 1000
# 2022-08-05 11:33:14,185 INFO Display              :: Data Fidelity--> 2.082019544480472
# 2022-08-05 11:33:14,239 INFO CountIterations      :: iteration = 60 / 1000
# 2022-08-05 11:33:14,268 INFO Display              :: Data Fidelity--> 2.0882017236865478
# 2022-08-05 11:33:14,322 INFO CountIterations      :: iteration = 61 / 1000
# 2022-08-05 11:33:14,347 INFO Display              :: Data Fidelity--> 2.0752280432545906
# 2022-08-05 11:33:14,396 INFO CountIterations      :: iteration = 62 / 1000
# 2022-08-05 11:33:14,422 INFO Display              :: Data Fidelity--> 2.08150640101709
# 2022-08-05 11:33:14,471 INFO CountIterations      :: iteration = 63 / 1000
# 2022-08-05 11:33:14,496 INFO Display              :: Data Fidelity--> 2.0686384423928397
# 2022-08-05 11:33:14,546 INFO CountIterations      :: iteration = 64 / 1000
# 2022-08-05 11:33:14,570 INFO Display              :: Data Fidelity--> 2.075009062147317
# 2022-08-05 11:33:14,619 INFO CountIterations      :: iteration = 65 / 1000
# 2022-08-05 11:33:14,642 INFO Display              :: Data Fidelity--> 2.0622391482137736
# 2022-08-05 11:33:14,689 INFO CountIterations      :: iteration = 66 / 1000
# 2022-08-05 11:33:14,709 INFO Display              :: Data Fidelity--> 2.0686984892904867
# 2022-08-05 11:33:14,775 INFO CountIterations      :: iteration = 67 / 1000
# 2022-08-05 11:33:14,807 INFO Display              :: Data Fidelity--> 2.0560196122652616
# 2022-08-05 11:33:14,864 INFO CountIterations      :: iteration = 68 / 1000
# 2022-08-05 11:33:14,898 INFO Display              :: Data Fidelity--> 2.0625644503624208
# 2022-08-05 11:33:14,945 INFO CountIterations      :: iteration = 69 / 1000
# 2022-08-05 11:33:14,965 INFO Display              :: Data Fidelity--> 2.0499701969838875
# 2022-08-05 11:33:15,014 INFO CountIterations      :: iteration = 70 / 1000
# 2022-08-05 11:33:15,035 INFO Display              :: Data Fidelity--> 2.056597575142962
# 2022-08-05 11:33:15,085 INFO CountIterations      :: iteration = 71 / 1000
# 2022-08-05 11:33:15,110 INFO Display              :: Data Fidelity--> 2.0440820623600784
# 2022-08-05 11:33:15,160 INFO CountIterations      :: iteration = 72 / 1000
# 2022-08-05 11:33:15,186 INFO Display              :: Data Fidelity--> 2.0507892505166905
# 2022-08-05 11:33:15,235 INFO CountIterations      :: iteration = 73 / 1000
# 2022-08-05 11:33:15,260 INFO Display              :: Data Fidelity--> 2.0383470699769055
# 2022-08-05 11:33:15,328 INFO CountIterations      :: iteration = 74 / 1000
# 2022-08-05 11:33:15,362 INFO Display              :: Data Fidelity--> 2.045131531532352
# 2022-08-05 11:33:15,417 INFO CountIterations      :: iteration = 75 / 1000
# 2022-08-05 11:33:15,442 INFO Display              :: Data Fidelity--> 2.0327577014645124
# 2022-08-05 11:33:15,491 INFO CountIterations      :: iteration = 76 / 1000
# 2022-08-05 11:33:15,517 INFO Display              :: Data Fidelity--> 2.039617065614688
# 2022-08-05 11:33:15,567 INFO CountIterations      :: iteration = 77 / 1000
# 2022-08-05 11:33:15,591 INFO Display              :: Data Fidelity--> 2.0273069889497446
# 2022-08-05 11:33:15,641 INFO CountIterations      :: iteration = 78 / 1000
# 2022-08-05 11:33:15,666 INFO Display              :: Data Fidelity--> 2.0342390277461155
# 2022-08-05 11:33:15,716 INFO CountIterations      :: iteration = 79 / 1000
# 2022-08-05 11:33:15,741 INFO Display              :: Data Fidelity--> 2.021988455519978
# 2022-08-05 11:33:15,791 INFO CountIterations      :: iteration = 80 / 1000
# 2022-08-05 11:33:15,816 INFO Display              :: Data Fidelity--> 2.0289910648243326
# 2022-08-05 11:33:15,866 INFO CountIterations      :: iteration = 81 / 1000
# 2022-08-05 11:33:15,891 INFO Display              :: Data Fidelity--> 2.016796064067819
# 2022-08-05 11:33:15,941 INFO CountIterations      :: iteration = 82 / 1000
# 2022-08-05 11:33:15,966 INFO Display              :: Data Fidelity--> 2.023867247716817
# 2022-08-05 11:33:16,016 INFO CountIterations      :: iteration = 83 / 1000
# 2022-08-05 11:33:16,041 INFO Display              :: Data Fidelity--> 2.0117241731736026
# 2022-08-05 11:33:16,090 INFO CountIterations      :: iteration = 84 / 1000
# 2022-08-05 11:33:16,115 INFO Display              :: Data Fidelity--> 2.0188620297926576
# 2022-08-05 11:33:16,163 INFO CountIterations      :: iteration = 85 / 1000
# 2022-08-05 11:33:16,187 INFO Display              :: Data Fidelity--> 2.006767498911418
# 2022-08-05 11:33:16,251 INFO CountIterations      :: iteration = 86 / 1000
# 2022-08-05 11:33:16,284 INFO Display              :: Data Fidelity--> 2.0139702109175226
# 2022-08-05 11:33:16,342 INFO CountIterations      :: iteration = 87 / 1000
# 2022-08-05 11:33:16,387 INFO Display              :: Data Fidelity--> 2.0019210816577058
# 2022-08-05 11:33:16,439 INFO CountIterations      :: iteration = 88 / 1000
# 2022-08-05 11:33:16,469 INFO Display              :: Data Fidelity--> 2.0091869060727365
# 2022-08-05 11:33:16,519 INFO CountIterations      :: iteration = 89 / 1000
# 2022-08-05 11:33:16,545 INFO Display              :: Data Fidelity--> 1.9971802571345296
# 2022-08-05 11:33:16,594 INFO CountIterations      :: iteration = 90 / 1000
# 2022-08-05 11:33:16,620 INFO Display              :: Data Fidelity--> 2.0045075178969136
# 2022-08-05 11:33:16,669 INFO CountIterations      :: iteration = 91 / 1000
# 2022-08-05 11:33:16,695 INFO Display              :: Data Fidelity--> 1.992540631048506
# 2022-08-05 11:33:16,744 INFO CountIterations      :: iteration = 92 / 1000
# 2022-08-05 11:33:16,770 INFO Display              :: Data Fidelity--> 1.999927712567027
# 2022-08-05 11:33:16,820 INFO CountIterations      :: iteration = 93 / 1000
# 2022-08-05 11:33:16,845 INFO Display              :: Data Fidelity--> 1.9879980567924127
# 2022-08-05 11:33:16,896 INFO CountIterations      :: iteration = 94 / 1000
# 2022-08-05 11:33:16,920 INFO Display              :: Data Fidelity--> 1.9954433985284163
# 2022-08-05 11:33:17,002 INFO CountIterations      :: iteration = 95 / 1000
# 2022-08-05 11:33:17,037 INFO Display              :: Data Fidelity--> 1.9835486157610671
# 2022-08-05 11:33:17,096 INFO CountIterations      :: iteration = 96 / 1000
# 2022-08-05 11:33:17,126 INFO Display              :: Data Fidelity--> 1.9910507076641248
# 2022-08-05 11:33:17,205 INFO CountIterations      :: iteration = 97 / 1000
# 2022-08-05 11:33:17,241 INFO Display              :: Data Fidelity--> 1.979188599906689
# 2022-08-05 11:33:17,301 INFO CountIterations      :: iteration = 98 / 1000
# 2022-08-05 11:33:17,326 INFO Display              :: Data Fidelity--> 1.9867459785581025
# 2022-08-05 11:33:17,376 INFO CountIterations      :: iteration = 99 / 1000
# 2022-08-05 11:33:17,400 INFO Display              :: Data Fidelity--> 1.9749144962177607
# 2022-08-05 11:33:17,450 INFO CountIterations      :: iteration = 100 / 1000
# 2022-08-05 11:33:17,478 INFO Display              :: Data Fidelity--> 1.9825257415609183
# 2022-08-05 11:33:17,531 INFO CountIterations      :: iteration = 101 / 1000
# 2022-08-05 11:33:17,556 INFO Display              :: Data Fidelity--> 1.9707229728559903
# 2022-08-05 11:33:17,607 INFO CountIterations      :: iteration = 102 / 1000
# 2022-08-05 11:33:17,633 INFO Display              :: Data Fidelity--> 1.9783867054142794
# 2022-08-05 11:33:17,683 INFO CountIterations      :: iteration = 103 / 1000
# 2022-08-05 11:33:17,709 INFO Display              :: Data Fidelity--> 1.9666108667237268
# 2022-08-05 11:33:17,758 INFO CountIterations      :: iteration = 104 / 1000
# 2022-08-05 11:33:17,781 INFO Display              :: Data Fidelity--> 1.9743257452221328
# 2022-08-05 11:33:17,830 INFO CountIterations      :: iteration = 105 / 1000
# 2022-08-05 11:33:17,854 INFO Display              :: Data Fidelity--> 1.962575172274923
# 2022-08-05 11:33:17,904 INFO CountIterations      :: iteration = 106 / 1000
# 2022-08-05 11:33:17,930 INFO Display              :: Data Fidelity--> 1.970339891596962
# 2022-08-05 11:33:17,981 INFO CountIterations      :: iteration = 107 / 1000
# 2022-08-05 11:33:18,005 INFO Display              :: Data Fidelity--> 1.9586130314036712
# 2022-08-05 11:33:18,054 INFO CountIterations      :: iteration = 108 / 1000
# 2022-08-05 11:33:18,078 INFO Display              :: Data Fidelity--> 1.96642632082632
# 2022-08-05 11:33:18,127 INFO CountIterations      :: iteration = 109 / 1000
# 2022-08-05 11:33:18,151 INFO Display              :: Data Fidelity--> 1.9547217242755481
# 2022-08-05 11:33:18,199 INFO CountIterations      :: iteration = 110 / 1000
# 2022-08-05 11:33:18,223 INFO Display              :: Data Fidelity--> 1.962582345934297
# 2022-08-05 11:33:18,272 INFO CountIterations      :: iteration = 111 / 1000
# 2022-08-05 11:33:18,296 INFO Display              :: Data Fidelity--> 1.9508986609825043
# 2022-08-05 11:33:18,344 INFO CountIterations      :: iteration = 112 / 1000
# 2022-08-05 11:33:18,368 INFO Display              :: Data Fidelity--> 1.9588054085277464
# 2022-08-05 11:33:18,416 INFO CountIterations      :: iteration = 113 / 1000
# 2022-08-05 11:33:18,439 INFO Display              :: Data Fidelity--> 1.9471413739216417
# 2022-08-05 11:33:18,490 INFO CountIterations      :: iteration = 114 / 1000
# 2022-08-05 11:33:18,514 INFO Display              :: Data Fidelity--> 1.9550930713324872
# 2022-08-05 11:33:18,565 INFO CountIterations      :: iteration = 115 / 1000
# 2022-08-05 11:33:18,589 INFO Display              :: Data Fidelity--> 1.9434475108108056
# 2022-08-05 11:33:18,638 INFO CountIterations      :: iteration = 116 / 1000
# 2022-08-05 11:33:18,662 INFO Display              :: Data Fidelity--> 1.9514430113401688
# 2022-08-05 11:33:18,712 INFO CountIterations      :: iteration = 117 / 1000
# 2022-08-05 11:33:18,737 INFO Display              :: Data Fidelity--> 1.9398148282682386
# 2022-08-05 11:33:18,794 INFO CountIterations      :: iteration = 118 / 1000
# 2022-08-05 11:33:18,825 INFO Display              :: Data Fidelity--> 1.9478530134960583
# 2022-08-05 11:33:18,869 INFO CountIterations      :: iteration = 119 / 1000
# 2022-08-05 11:33:18,890 INFO Display              :: Data Fidelity--> 1.9362411858915738
# 2022-08-05 11:33:18,939 INFO CountIterations      :: iteration = 120 / 1000
# 2022-08-05 11:33:18,963 INFO Display              :: Data Fidelity--> 1.9443209648670372
# 2022-08-05 11:33:19,012 INFO CountIterations      :: iteration = 121 / 1000
# 2022-08-05 11:33:19,035 INFO Display              :: Data Fidelity--> 1.9327245407808125
# 2022-08-05 11:33:19,078 INFO CountIterations      :: iteration = 122 / 1000
# 2022-08-05 11:33:19,100 INFO Display              :: Data Fidelity--> 1.9408448492392418
# 2022-08-05 11:33:19,164 INFO CountIterations      :: iteration = 123 / 1000
# 2022-08-05 11:33:19,193 INFO Display              :: Data Fidelity--> 1.9292629424596424
# 2022-08-05 11:33:19,247 INFO CountIterations      :: iteration = 124 / 1000
# 2022-08-05 11:33:19,268 INFO Display              :: Data Fidelity--> 1.9374227420996797
# 2022-08-05 11:33:19,311 INFO CountIterations      :: iteration = 125 / 1000
# 2022-08-05 11:33:19,332 INFO Display              :: Data Fidelity--> 1.9258545281511013
# 2022-08-05 11:33:19,396 INFO CountIterations      :: iteration = 126 / 1000
# 2022-08-05 11:33:19,422 INFO Display              :: Data Fidelity--> 1.934052805963043
# 2022-08-05 11:33:19,466 INFO CountIterations      :: iteration = 127 / 1000
# 2022-08-05 11:33:19,487 INFO Display              :: Data Fidelity--> 1.9224975183736894
# 2022-08-05 11:33:19,530 INFO CountIterations      :: iteration = 128 / 1000
# 2022-08-05 11:33:19,554 INFO Display              :: Data Fidelity--> 1.930733286009095
# 2022-08-05 11:33:19,602 INFO CountIterations      :: iteration = 129 / 1000
# 2022-08-05 11:33:19,627 INFO Display              :: Data Fidelity--> 1.9191902128256402
# 2022-08-05 11:33:19,677 INFO CountIterations      :: iteration = 130 / 1000
# 2022-08-05 11:33:19,702 INFO Display              :: Data Fidelity--> 1.9274625060018526
# 2022-08-05 11:33:19,751 INFO CountIterations      :: iteration = 131 / 1000
# 2022-08-05 11:33:19,775 INFO Display              :: Data Fidelity--> 1.915930986530796
# 2022-08-05 11:33:19,826 INFO CountIterations      :: iteration = 132 / 1000
# 2022-08-05 11:33:19,851 INFO Display              :: Data Fidelity--> 1.9242388644636312
# 2022-08-05 11:33:19,900 INFO CountIterations      :: iteration = 133 / 1000
# 2022-08-05 11:33:19,938 INFO Display              :: Data Fidelity--> 1.912718286220385
# 2022-08-05 11:33:19,996 INFO CountIterations      :: iteration = 134 / 1000
# 2022-08-05 11:33:20,018 INFO Display              :: Data Fidelity--> 1.9210608310814266
# 2022-08-05 11:33:20,064 INFO CountIterations      :: iteration = 135 / 1000
# 2022-08-05 11:33:20,089 INFO Display              :: Data Fidelity--> 1.9095506269318636
# 2022-08-05 11:33:20,139 INFO CountIterations      :: iteration = 136 / 1000
# 2022-08-05 11:33:20,163 INFO Display              :: Data Fidelity--> 1.917926943325086
# 2022-08-05 11:33:20,213 INFO CountIterations      :: iteration = 137 / 1000
# 2022-08-05 11:33:20,238 INFO Display              :: Data Fidelity--> 1.9064265888047167
# 2022-08-05 11:33:20,288 INFO CountIterations      :: iteration = 138 / 1000
# 2022-08-05 11:33:20,321 INFO Display              :: Data Fidelity--> 1.91483580326011
# 2022-08-05 11:33:20,387 INFO CountIterations      :: iteration = 139 / 1000
# 2022-08-05 11:33:20,420 INFO Display              :: Data Fidelity--> 1.903344814056059
# 2022-08-05 11:33:20,473 INFO CountIterations      :: iteration = 140 / 1000
# 2022-08-05 11:33:20,498 INFO Display              :: Data Fidelity--> 1.9117860745376194
# 2022-08-05 11:33:20,551 INFO CountIterations      :: iteration = 141 / 1000
# 2022-08-05 11:33:20,576 INFO Display              :: Data Fidelity--> 1.9003040041243862
# 2022-08-05 11:33:20,628 INFO CountIterations      :: iteration = 142 / 1000
# 2022-08-05 11:33:20,653 INFO Display              :: Data Fidelity--> 1.90877647955005
# 2022-08-05 11:33:20,758 INFO CountIterations      :: iteration = 143 / 1000
# 2022-08-05 11:33:20,794 INFO Display              :: Data Fidelity--> 1.897302916965097
# 2022-08-05 11:33:20,842 INFO CountIterations      :: iteration = 144 / 1000
# 2022-08-05 11:33:20,865 INFO Display              :: Data Fidelity--> 1.9058057967374344
# 2022-08-05 11:33:20,910 INFO CountIterations      :: iteration = 145 / 1000
# 2022-08-05 11:33:20,931 INFO Display              :: Data Fidelity--> 1.8943403644882502
# 2022-08-05 11:33:20,994 INFO CountIterations      :: iteration = 146 / 1000
# 2022-08-05 11:33:21,018 INFO Display              :: Data Fidelity--> 1.9028728580345824
# 2022-08-05 11:33:21,061 INFO CountIterations      :: iteration = 147 / 1000
# 2022-08-05 11:33:21,084 INFO Display              :: Data Fidelity--> 1.891415210128143
# 2022-08-05 11:33:21,127 INFO CountIterations      :: iteration = 148 / 1000
# 2022-08-05 11:33:21,147 INFO Display              :: Data Fidelity--> 1.8999765464486453
# 2022-08-05 11:33:21,190 INFO CountIterations      :: iteration = 149 / 1000
# 2022-08-05 11:33:21,215 INFO Display              :: Data Fidelity--> 1.8885263665340344
# 2022-08-05 11:33:21,264 INFO CountIterations      :: iteration = 150 / 1000
# 2022-08-05 11:33:21,289 INFO Display              :: Data Fidelity--> 1.8971157937576821
# 2022-08-05 11:33:21,338 INFO CountIterations      :: iteration = 151 / 1000
# 2022-08-05 11:33:21,363 INFO Display              :: Data Fidelity--> 1.8856727933755835
# 2022-08-05 11:33:21,413 INFO CountIterations      :: iteration = 152 / 1000
# 2022-08-05 11:33:21,438 INFO Display              :: Data Fidelity--> 1.8942895783228773
# 2022-08-05 11:33:21,486 INFO CountIterations      :: iteration = 153 / 1000
# 2022-08-05 11:33:21,509 INFO Display              :: Data Fidelity--> 1.8828534952544103
# 2022-08-05 11:33:21,556 INFO CountIterations      :: iteration = 154 / 1000
# 2022-08-05 11:33:21,580 INFO Display              :: Data Fidelity--> 1.891496923007205
# 2022-08-05 11:33:21,630 INFO CountIterations      :: iteration = 155 / 1000
# 2022-08-05 11:33:21,655 INFO Display              :: Data Fidelity--> 1.880067519714655
# 2022-08-05 11:33:21,793 INFO CountIterations      :: iteration = 156 / 1000
# 2022-08-05 11:33:21,820 INFO Display              :: Data Fidelity--> 1.8887368931916648
# 2022-08-05 11:33:21,893 INFO CountIterations      :: iteration = 157 / 1000
# 2022-08-05 11:33:21,921 INFO Display              :: Data Fidelity--> 1.877313955347033
# 2022-08-05 11:33:21,986 INFO CountIterations      :: iteration = 158 / 1000
# 2022-08-05 11:33:22,015 INFO Display              :: Data Fidelity--> 1.8860085948858398
# 2022-08-05 11:33:22,077 INFO CountIterations      :: iteration = 159 / 1000
# 2022-08-05 11:33:22,100 INFO Display              :: Data Fidelity--> 1.8745919299807214
# 2022-08-05 11:33:22,148 INFO CountIterations      :: iteration = 160 / 1000
# 2022-08-05 11:33:22,171 INFO Display              :: Data Fidelity--> 1.8833111729257814
# 2022-08-05 11:33:22,221 INFO CountIterations      :: iteration = 161 / 1000
# 2022-08-05 11:33:22,244 INFO Display              :: Data Fidelity--> 1.8719006089578496
# 2022-08-05 11:33:22,292 INFO CountIterations      :: iteration = 162 / 1000
# 2022-08-05 11:33:22,314 INFO Display              :: Data Fidelity--> 1.8806438092542503
# 2022-08-05 11:33:22,362 INFO CountIterations      :: iteration = 163 / 1000
# 2022-08-05 11:33:22,385 INFO Display              :: Data Fidelity--> 1.8692391934851265
# 2022-08-05 11:33:22,435 INFO CountIterations      :: iteration = 164 / 1000
# 2022-08-05 11:33:22,458 INFO Display              :: Data Fidelity--> 1.8780057212786108
# 2022-08-05 11:33:22,507 INFO CountIterations      :: iteration = 165 / 1000
# 2022-08-05 11:33:22,529 INFO Display              :: Data Fidelity--> 1.8666069190603818
# 2022-08-05 11:33:22,576 INFO CountIterations      :: iteration = 166 / 1000
# 2022-08-05 11:33:22,600 INFO Display              :: Data Fidelity--> 1.8753961603031408
# 2022-08-05 11:33:22,736 INFO CountIterations      :: iteration = 167 / 1000
# 2022-08-05 11:33:22,759 INFO Display              :: Data Fidelity--> 1.8640030539667611
# 2022-08-05 11:33:22,808 INFO CountIterations      :: iteration = 168 / 1000
# 2022-08-05 11:33:22,832 INFO Display              :: Data Fidelity--> 1.8728144100291568
# 2022-08-05 11:33:22,880 INFO CountIterations      :: iteration = 169 / 1000
# 2022-08-05 11:33:22,904 INFO Display              :: Data Fidelity--> 1.8614268978345743
# 2022-08-05 11:33:22,953 INFO CountIterations      :: iteration = 170 / 1000
# 2022-08-05 11:33:22,987 INFO Display              :: Data Fidelity--> 1.8702597851234934
# 2022-08-05 11:33:23,062 INFO CountIterations      :: iteration = 171 / 1000
# 2022-08-05 11:33:23,092 INFO Display              :: Data Fidelity--> 1.8588777802650136
# 2022-08-05 11:33:23,148 INFO CountIterations      :: iteration = 172 / 1000
# 2022-08-05 11:33:23,185 INFO Display              :: Data Fidelity--> 1.8677316298476385
# 2022-08-05 11:33:23,242 INFO CountIterations      :: iteration = 173 / 1000
# 2022-08-05 11:33:23,269 INFO Display              :: Data Fidelity--> 1.856355059512673
# 2022-08-05 11:33:23,323 INFO CountIterations      :: iteration = 174 / 1000
# 2022-08-05 11:33:23,352 INFO Display              :: Data Fidelity--> 1.865229316746936
# 2022-08-05 11:33:23,497 INFO CountIterations      :: iteration = 175 / 1000
# 2022-08-05 11:33:23,521 INFO Display              :: Data Fidelity--> 1.853858121225307
# 2022-08-05 11:33:23,570 INFO CountIterations      :: iteration = 176 / 1000
# 2022-08-05 11:33:23,594 INFO Display              :: Data Fidelity--> 1.8627522453966499
# 2022-08-05 11:33:23,642 INFO CountIterations      :: iteration = 177 / 1000
# 2022-08-05 11:33:23,666 INFO Display              :: Data Fidelity--> 1.8513863772372101
# 2022-08-05 11:33:23,715 INFO CountIterations      :: iteration = 178 / 1000
# 2022-08-05 11:33:23,739 INFO Display              :: Data Fidelity--> 1.8602998412017744
# 2022-08-05 11:33:23,785 INFO CountIterations      :: iteration = 179 / 1000
# 2022-08-05 11:33:23,808 INFO Display              :: Data Fidelity--> 1.8489392644134055
# 2022-08-05 11:33:23,855 INFO CountIterations      :: iteration = 180 / 1000
# 2022-08-05 11:33:23,877 INFO Display              :: Data Fidelity--> 1.8578715542474826
# 2022-08-05 11:33:23,925 INFO CountIterations      :: iteration = 181 / 1000
# 2022-08-05 11:33:23,949 INFO Display              :: Data Fidelity--> 1.8465162435432496
# 2022-08-05 11:33:23,997 INFO CountIterations      :: iteration = 182 / 1000
# 2022-08-05 11:33:24,032 INFO Display              :: Data Fidelity--> 1.8554668581995368
# 2022-08-05 11:33:24,087 INFO CountIterations      :: iteration = 183 / 1000
# 2022-08-05 11:33:24,117 INFO Display              :: Data Fidelity--> 1.844116798279601
# 2022-08-05 11:33:24,160 INFO CountIterations      :: iteration = 184 / 1000
# 2022-08-05 11:33:24,184 INFO Display              :: Data Fidelity--> 1.8530852492497172
# 2022-08-05 11:33:24,232 INFO CountIterations      :: iteration = 185 / 1000
# 2022-08-05 11:33:24,255 INFO Display              :: Data Fidelity--> 1.8417404341239483
# 2022-08-05 11:33:24,303 INFO CountIterations      :: iteration = 186 / 1000
# 2022-08-05 11:33:24,327 INFO Display              :: Data Fidelity--> 1.850726245107986
# 2022-08-05 11:33:24,374 INFO CountIterations      :: iteration = 187 / 1000
# 2022-08-05 11:33:24,398 INFO Display              :: Data Fidelity--> 1.8393866774526244
# 2022-08-05 11:33:24,446 INFO CountIterations      :: iteration = 188 / 1000
# 2022-08-05 11:33:24,470 INFO Display              :: Data Fidelity--> 1.8483893840351189
# 2022-08-05 11:33:24,519 INFO CountIterations      :: iteration = 189 / 1000
# 2022-08-05 11:33:24,554 INFO Display              :: Data Fidelity--> 1.8370550745849434
# 2022-08-05 11:33:24,609 INFO CountIterations      :: iteration = 190 / 1000
# 2022-08-05 11:33:24,642 INFO Display              :: Data Fidelity--> 1.8460742239175258
# 2022-08-05 11:33:24,685 INFO CountIterations      :: iteration = 191 / 1000
# 2022-08-05 11:33:24,705 INFO Display              :: Data Fidelity--> 1.8347451908890116
# 2022-08-05 11:33:24,758 INFO CountIterations      :: iteration = 192 / 1000
# 2022-08-05 11:33:24,789 INFO Display              :: Data Fidelity--> 1.843780341379714
# 2022-08-05 11:33:24,837 INFO CountIterations      :: iteration = 193 / 1000
# 2022-08-05 11:33:24,861 INFO Display              :: Data Fidelity--> 1.8324566099256803
# 2022-08-05 11:33:24,910 INFO CountIterations      :: iteration = 194 / 1000
# 2022-08-05 11:33:24,934 INFO Display              :: Data Fidelity--> 1.8415073309355163
# 2022-08-05 11:33:24,982 INFO CountIterations      :: iteration = 195 / 1000
# 2022-08-05 11:33:25,006 INFO Display              :: Data Fidelity--> 1.8301889326280776
# 2022-08-05 11:33:25,055 INFO CountIterations      :: iteration = 196 / 1000
# 2022-08-05 11:33:25,079 INFO Display              :: Data Fidelity--> 1.8392548041733834
# 2022-08-05 11:33:25,127 INFO CountIterations      :: iteration = 197 / 1000
# 2022-08-05 11:33:25,152 INFO Display              :: Data Fidelity--> 1.827941776514709
# 2022-08-05 11:33:25,200 INFO CountIterations      :: iteration = 198 / 1000
# 2022-08-05 11:33:25,248 INFO Display              :: Data Fidelity--> 1.837022388977045
# 2022-08-05 11:33:25,318 INFO CountIterations      :: iteration = 199 / 1000
# 2022-08-05 11:33:25,356 INFO Display              :: Data Fidelity--> 1.825714774936126
# 2022-08-05 11:33:25,416 INFO CountIterations      :: iteration = 200 / 1000
# 2022-08-05 11:33:25,455 INFO Display              :: Data Fidelity--> 1.8348097287782446
# 2022-08-05 11:33:25,503 INFO CountIterations      :: iteration = 201 / 1000
# 2022-08-05 11:33:25,527 INFO Display              :: Data Fidelity--> 1.8235075763524011
# 2022-08-05 11:33:25,575 INFO CountIterations      :: iteration = 202 / 1000
# 2022-08-05 11:33:25,599 INFO Display              :: Data Fidelity--> 1.832616481841213
# 2022-08-05 11:33:25,648 INFO CountIterations      :: iteration = 203 / 1000
# 2022-08-05 11:33:25,672 INFO Display              :: Data Fidelity--> 1.8213198436409876
# 2022-08-05 11:33:25,742 INFO CountIterations      :: iteration = 204 / 1000
# 2022-08-05 11:33:25,777 INFO Display              :: Data Fidelity--> 1.8304423205770168
# 2022-08-05 11:33:25,840 INFO CountIterations      :: iteration = 205 / 1000
# 2022-08-05 11:33:25,880 INFO Display              :: Data Fidelity--> 1.8191512534332759
# 2022-08-05 11:33:25,936 INFO CountIterations      :: iteration = 206 / 1000
# 2022-08-05 11:33:25,960 INFO Display              :: Data Fidelity--> 1.8282869308864318
# 2022-08-05 11:33:26,008 INFO CountIterations      :: iteration = 207 / 1000
# 2022-08-05 11:33:26,032 INFO Display              :: Data Fidelity--> 1.817001495479262
# 2022-08-05 11:33:26,080 INFO CountIterations      :: iteration = 208 / 1000
# 2022-08-05 11:33:26,104 INFO Display              :: Data Fidelity--> 1.8261500115315243
# 2022-08-05 11:33:26,150 INFO CountIterations      :: iteration = 209 / 1000
# 2022-08-05 11:33:26,172 INFO Display              :: Data Fidelity--> 1.8148702720386756
# 2022-08-05 11:33:26,218 INFO CountIterations      :: iteration = 210 / 1000
# 2022-08-05 11:33:26,240 INFO Display              :: Data Fidelity--> 1.8240312735327617
# 2022-08-05 11:33:26,286 INFO CountIterations      :: iteration = 211 / 1000
# 2022-08-05 11:33:26,307 INFO Display              :: Data Fidelity--> 1.8127572972971584
# 2022-08-05 11:33:26,353 INFO CountIterations      :: iteration = 212 / 1000
# 2022-08-05 11:33:26,376 INFO Display              :: Data Fidelity--> 1.8219304395916802
# 2022-08-05 11:33:26,424 INFO CountIterations      :: iteration = 213 / 1000
# 2022-08-05 11:33:26,447 INFO Display              :: Data Fidelity--> 1.8106622968078092
# 2022-08-05 11:33:26,504 INFO CountIterations      :: iteration = 214 / 1000
# 2022-08-05 11:33:26,530 INFO Display              :: Data Fidelity--> 1.8198472435389959
# 2022-08-05 11:33:26,585 INFO CountIterations      :: iteration = 215 / 1000
# 2022-08-05 11:33:26,605 INFO Display              :: Data Fidelity--> 1.8085850069557134
# 2022-08-05 11:33:26,648 INFO CountIterations      :: iteration = 216 / 1000
# 2022-08-05 11:33:26,668 INFO Display              :: Data Fidelity--> 1.8177814298045745
# 2022-08-05 11:33:26,710 INFO CountIterations      :: iteration = 217 / 1000
# 2022-08-05 11:33:26,734 INFO Display              :: Data Fidelity--> 1.8065251744452424
# 2022-08-05 11:33:26,783 INFO CountIterations      :: iteration = 218 / 1000
# 2022-08-05 11:33:26,807 INFO Display              :: Data Fidelity--> 1.8157327529118195
# 2022-08-05 11:33:26,854 INFO CountIterations      :: iteration = 219 / 1000
# 2022-08-05 11:33:26,877 INFO Display              :: Data Fidelity--> 1.804482555809396
# 2022-08-05 11:33:26,924 INFO CountIterations      :: iteration = 220 / 1000
# 2022-08-05 11:33:26,948 INFO Display              :: Data Fidelity--> 1.8137009769919819
# 2022-08-05 11:33:26,995 INFO CountIterations      :: iteration = 221 / 1000
# 2022-08-05 11:33:27,019 INFO Display              :: Data Fidelity--> 1.8024569169391067
# 2022-08-05 11:33:27,067 INFO CountIterations      :: iteration = 222 / 1000
# 2022-08-05 11:33:27,091 INFO Display              :: Data Fidelity--> 1.811685875320154
# 2022-08-05 11:33:27,137 INFO CountIterations      :: iteration = 223 / 1000
# 2022-08-05 11:33:27,159 INFO Display              :: Data Fidelity--> 1.8004480326341055
# 2022-08-05 11:33:27,208 INFO CountIterations      :: iteration = 224 / 1000
# 2022-08-05 11:33:27,231 INFO Display              :: Data Fidelity--> 1.8096872298716509
# 2022-08-05 11:33:27,279 INFO CountIterations      :: iteration = 225 / 1000
# 2022-08-05 11:33:27,302 INFO Display              :: Data Fidelity--> 1.7984556861713394
# 2022-08-05 11:33:27,349 INFO CountIterations      :: iteration = 226 / 1000
# 2022-08-05 11:33:27,372 INFO Display              :: Data Fidelity--> 1.807704830895767
# 2022-08-05 11:33:27,420 INFO CountIterations      :: iteration = 227 / 1000
# 2022-08-05 11:33:27,443 INFO Display              :: Data Fidelity--> 1.7964796688930633
# 2022-08-05 11:33:27,490 INFO CountIterations      :: iteration = 228 / 1000
# 2022-08-05 11:33:27,513 INFO Display              :: Data Fidelity--> 1.8057384765103819
# 2022-08-05 11:33:27,561 INFO CountIterations      :: iteration = 229 / 1000
# 2022-08-05 11:33:27,584 INFO Display              :: Data Fidelity--> 1.7945197798128396
# 2022-08-05 11:33:27,632 INFO CountIterations      :: iteration = 230 / 1000
# 2022-08-05 11:33:27,655 INFO Display              :: Data Fidelity--> 1.8037879723125283
# 2022-08-05 11:33:27,703 INFO CountIterations      :: iteration = 231 / 1000
# 2022-08-05 11:33:27,726 INFO Display              :: Data Fidelity--> 1.792575825237286
# 2022-08-05 11:33:27,769 INFO CountIterations      :: iteration = 232 / 1000
# 2022-08-05 11:33:27,793 INFO Display              :: Data Fidelity--> 1.8018531310056913
# 2022-08-05 11:33:27,841 INFO CountIterations      :: iteration = 233 / 1000
# 2022-08-05 11:33:27,865 INFO Display              :: Data Fidelity--> 1.7906476184056506
# 2022-08-05 11:33:27,912 INFO CountIterations      :: iteration = 234 / 1000
# 2022-08-05 11:33:27,936 INFO Display              :: Data Fidelity--> 1.7999337720454074
# 2022-08-05 11:33:27,984 INFO CountIterations      :: iteration = 235 / 1000
# 2022-08-05 11:33:28,008 INFO Display              :: Data Fidelity--> 1.7887349791446452
# 2022-08-05 11:33:28,056 INFO CountIterations      :: iteration = 236 / 1000
# 2022-08-05 11:33:28,080 INFO Display              :: Data Fidelity--> 1.7980297212982563
# 2022-08-05 11:33:28,128 INFO CountIterations      :: iteration = 237 / 1000
# 2022-08-05 11:33:28,151 INFO Display              :: Data Fidelity--> 1.7868377335381977
# 2022-08-05 11:33:28,199 INFO CountIterations      :: iteration = 238 / 1000
# 2022-08-05 11:33:28,223 INFO Display              :: Data Fidelity--> 1.7961408107172967
# 2022-08-05 11:33:28,271 INFO CountIterations      :: iteration = 239 / 1000
# 2022-08-05 11:33:28,295 INFO Display              :: Data Fidelity--> 1.7849557136121101
# 2022-08-05 11:33:28,343 INFO CountIterations      :: iteration = 240 / 1000
# 2022-08-05 11:33:28,366 INFO Display              :: Data Fidelity--> 1.7942668780314743
# 2022-08-05 11:33:28,415 INFO CountIterations      :: iteration = 241 / 1000
# 2022-08-05 11:33:28,439 INFO Display              :: Data Fidelity--> 1.7830887570323803
# 2022-08-05 11:33:28,485 INFO CountIterations      :: iteration = 242 / 1000
# ...
# 2022-08-05 11:34:19,117 INFO Display              :: Data Fidelity--> 1.5715992696619687
# 2022-08-05 11:34:19,165 INFO CountIterations      :: iteration = 905 / 1000
# 2022-08-05 11:34:19,189 INFO Display              :: Data Fidelity--> 1.563014122169548
# 2022-08-05 11:34:19,252 INFO CountIterations      :: iteration = 906 / 1000
# 2022-08-05 11:34:19,279 INFO Display              :: Data Fidelity--> 1.5714004995403303
# 2022-08-05 11:34:19,345 INFO CountIterations      :: iteration = 907 / 1000
# 2022-08-05 11:34:19,372 INFO Display              :: Data Fidelity--> 1.5628204359502782
# 2022-08-05 11:34:19,444 INFO CountIterations      :: iteration = 908 / 1000
# 2022-08-05 11:34:19,473 INFO Display              :: Data Fidelity--> 1.5712024649598972
# 2022-08-05 11:34:19,524 INFO CountIterations      :: iteration = 909 / 1000
# 2022-08-05 11:34:19,550 INFO Display              :: Data Fidelity--> 1.5626274729033147
# 2022-08-05 11:34:19,599 INFO CountIterations      :: iteration = 910 / 1000
# 2022-08-05 11:34:19,624 INFO Display              :: Data Fidelity--> 1.57100515987206
# 2022-08-05 11:34:19,672 INFO CountIterations      :: iteration = 911 / 1000
# 2022-08-05 11:34:19,696 INFO Display              :: Data Fidelity--> 1.5624352270321884
# 2022-08-05 11:34:19,747 INFO CountIterations      :: iteration = 912 / 1000
# 2022-08-05 11:34:19,772 INFO Display              :: Data Fidelity--> 1.570808578293809
# 2022-08-05 11:34:19,842 INFO CountIterations      :: iteration = 913 / 1000
# 2022-08-05 11:34:19,871 INFO Display              :: Data Fidelity--> 1.562243692405704
# 2022-08-05 11:34:19,940 INFO CountIterations      :: iteration = 914 / 1000
# 2022-08-05 11:34:19,970 INFO Display              :: Data Fidelity--> 1.5706127143073607
# 2022-08-05 11:34:20,040 INFO CountIterations      :: iteration = 915 / 1000
# 2022-08-05 11:34:20,069 INFO Display              :: Data Fidelity--> 1.5620528631573452
# 2022-08-05 11:34:20,118 INFO CountIterations      :: iteration = 916 / 1000
# 2022-08-05 11:34:20,141 INFO Display              :: Data Fidelity--> 1.570417562058711
# 2022-08-05 11:34:20,207 INFO CountIterations      :: iteration = 917 / 1000
# 2022-08-05 11:34:20,236 INFO Display              :: Data Fidelity--> 1.561862733483951
# 2022-08-05 11:34:20,305 INFO CountIterations      :: iteration = 918 / 1000
# 2022-08-05 11:34:20,334 INFO Display              :: Data Fidelity--> 1.5702231157572026
# 2022-08-05 11:34:20,404 INFO CountIterations      :: iteration = 919 / 1000
# 2022-08-05 11:34:20,433 INFO Display              :: Data Fidelity--> 1.5616732976456544
# 2022-08-05 11:34:20,503 INFO CountIterations      :: iteration = 920 / 1000
# 2022-08-05 11:34:20,534 INFO Display              :: Data Fidelity--> 1.5700293696748546
# 2022-08-05 11:34:20,628 INFO CountIterations      :: iteration = 921 / 1000
# 2022-08-05 11:34:20,657 INFO Display              :: Data Fidelity--> 1.5614845499647583
# 2022-08-05 11:34:20,727 INFO CountIterations      :: iteration = 922 / 1000
# 2022-08-05 11:34:20,756 INFO Display              :: Data Fidelity--> 1.569836318145465
# 2022-08-05 11:34:20,826 INFO CountIterations      :: iteration = 923 / 1000
# 2022-08-05 11:34:20,855 INFO Display              :: Data Fidelity--> 1.5612964848249344
# 2022-08-05 11:34:20,925 INFO CountIterations      :: iteration = 924 / 1000
# 2022-08-05 11:34:20,954 INFO Display              :: Data Fidelity--> 1.56964395556387
# 2022-08-05 11:34:21,025 INFO CountIterations      :: iteration = 925 / 1000
# 2022-08-05 11:34:21,054 INFO Display              :: Data Fidelity--> 1.5611090966707386
# 2022-08-05 11:34:21,110 INFO CountIterations      :: iteration = 926 / 1000
# 2022-08-05 11:34:21,135 INFO Display              :: Data Fidelity--> 1.569452276385486
# 2022-08-05 11:34:21,206 INFO CountIterations      :: iteration = 927 / 1000
# 2022-08-05 11:34:21,235 INFO Display              :: Data Fidelity--> 1.5609223800069656
# 2022-08-05 11:34:21,303 INFO CountIterations      :: iteration = 928 / 1000
# 2022-08-05 11:34:21,328 INFO Display              :: Data Fidelity--> 1.5692612751255053
# 2022-08-05 11:34:21,398 INFO CountIterations      :: iteration = 929 / 1000
# 2022-08-05 11:34:21,427 INFO Display              :: Data Fidelity--> 1.5607363293976988
# 2022-08-05 11:34:21,511 INFO CountIterations      :: iteration = 930 / 1000
# 2022-08-05 11:34:21,588 INFO Display              :: Data Fidelity--> 1.569070946357993
# 2022-08-05 11:34:21,636 INFO CountIterations      :: iteration = 931 / 1000
# 2022-08-05 11:34:21,661 INFO Display              :: Data Fidelity--> 1.5605509394657675
# 2022-08-05 11:34:21,709 INFO CountIterations      :: iteration = 932 / 1000
# 2022-08-05 11:34:21,733 INFO Display              :: Data Fidelity--> 1.5688812847152938
# 2022-08-05 11:34:21,782 INFO CountIterations      :: iteration = 933 / 1000
# 2022-08-05 11:34:21,807 INFO Display              :: Data Fidelity--> 1.5603662048916194
# 2022-08-05 11:34:21,854 INFO CountIterations      :: iteration = 934 / 1000
# 2022-08-05 11:34:21,879 INFO Display              :: Data Fidelity--> 1.5686922848874343
# 2022-08-05 11:34:21,944 INFO CountIterations      :: iteration = 935 / 1000
# 2022-08-05 11:34:21,968 INFO Display              :: Data Fidelity--> 1.5601821204136535
# 2022-08-05 11:34:22,039 INFO CountIterations      :: iteration = 936 / 1000
# 2022-08-05 11:34:22,069 INFO Display              :: Data Fidelity--> 1.5685039416217057
# 2022-08-05 11:34:22,117 INFO CountIterations      :: iteration = 937 / 1000
# 2022-08-05 11:34:22,141 INFO Display              :: Data Fidelity--> 1.5599986808264357
# 2022-08-05 11:34:22,189 INFO CountIterations      :: iteration = 938 / 1000
# 2022-08-05 11:34:22,215 INFO Display              :: Data Fidelity--> 1.5683162497212124
# 2022-08-05 11:34:22,265 INFO CountIterations      :: iteration = 939 / 1000
# 2022-08-05 11:34:22,290 INFO Display              :: Data Fidelity--> 1.5598158809807277
# 2022-08-05 11:34:22,340 INFO CountIterations      :: iteration = 940 / 1000
# 2022-08-05 11:34:22,365 INFO Display              :: Data Fidelity--> 1.5681292040449142
# 2022-08-05 11:34:22,416 INFO CountIterations      :: iteration = 941 / 1000
# 2022-08-05 11:34:22,445 INFO Display              :: Data Fidelity--> 1.5596337157825841
# 2022-08-05 11:34:22,495 INFO CountIterations      :: iteration = 942 / 1000
# 2022-08-05 11:34:22,521 INFO Display              :: Data Fidelity--> 1.5679427995069712
# 2022-08-05 11:34:22,572 INFO CountIterations      :: iteration = 943 / 1000
# 2022-08-05 11:34:22,596 INFO Display              :: Data Fidelity--> 1.559452180192618
# 2022-08-05 11:34:22,656 INFO CountIterations      :: iteration = 944 / 1000
# 2022-08-05 11:34:22,736 INFO Display              :: Data Fidelity--> 1.5677570310755589
# 2022-08-05 11:34:22,802 INFO CountIterations      :: iteration = 945 / 1000
# 2022-08-05 11:34:22,827 INFO Display              :: Data Fidelity--> 1.5592712692257251
# 2022-08-05 11:34:22,875 INFO CountIterations      :: iteration = 946 / 1000
# 2022-08-05 11:34:22,899 INFO Display              :: Data Fidelity--> 1.567571893772764
# 2022-08-05 11:34:22,946 INFO CountIterations      :: iteration = 947 / 1000
# 2022-08-05 11:34:22,969 INFO Display              :: Data Fidelity--> 1.559090977950107
# 2022-08-05 11:34:23,017 INFO CountIterations      :: iteration = 948 / 1000
# 2022-08-05 11:34:23,041 INFO Display              :: Data Fidelity--> 1.567387382673855
# 2022-08-05 11:34:23,088 INFO CountIterations      :: iteration = 949 / 1000
# 2022-08-05 11:34:23,112 INFO Display              :: Data Fidelity--> 1.5589113014865568
# 2022-08-05 11:34:23,159 INFO CountIterations      :: iteration = 950 / 1000
# 2022-08-05 11:34:23,182 INFO Display              :: Data Fidelity--> 1.567203492906207
# 2022-08-05 11:34:23,229 INFO CountIterations      :: iteration = 951 / 1000
# 2022-08-05 11:34:23,253 INFO Display              :: Data Fidelity--> 1.5587322350082096
# 2022-08-05 11:34:23,301 INFO CountIterations      :: iteration = 952 / 1000
# 2022-08-05 11:34:23,325 INFO Display              :: Data Fidelity--> 1.5670202196493532
# 2022-08-05 11:34:23,374 INFO CountIterations      :: iteration = 953 / 1000
# 2022-08-05 11:34:23,398 INFO Display              :: Data Fidelity--> 1.5585537737398285
# 2022-08-05 11:34:23,450 INFO CountIterations      :: iteration = 954 / 1000
# 2022-08-05 11:34:23,474 INFO Display              :: Data Fidelity--> 1.5668375581341656
# 2022-08-05 11:34:23,521 INFO CountIterations      :: iteration = 955 / 1000
# 2022-08-05 11:34:23,560 INFO Display              :: Data Fidelity--> 1.558375912957012
# 2022-08-05 11:34:23,614 INFO CountIterations      :: iteration = 956 / 1000
# 2022-08-05 11:34:23,646 INFO Display              :: Data Fidelity--> 1.5666555036418162
# 2022-08-05 11:34:23,699 INFO CountIterations      :: iteration = 957 / 1000
# 2022-08-05 11:34:23,721 INFO Display              :: Data Fidelity--> 1.5581986479856635
# 2022-08-05 11:34:23,766 INFO CountIterations      :: iteration = 958 / 1000
# 2022-08-05 11:34:23,790 INFO Display              :: Data Fidelity--> 1.5664740515037734
# 2022-08-05 11:34:23,837 INFO CountIterations      :: iteration = 959 / 1000
# 2022-08-05 11:34:23,873 INFO Display              :: Data Fidelity--> 1.5580219742014942
# 2022-08-05 11:34:23,928 INFO CountIterations      :: iteration = 960 / 1000
# 2022-08-05 11:34:23,960 INFO Display              :: Data Fidelity--> 1.566293197100824
# 2022-08-05 11:34:24,015 INFO CountIterations      :: iteration = 961 / 1000
# 2022-08-05 11:34:24,039 INFO Display              :: Data Fidelity--> 1.5578458870293586
# 2022-08-05 11:34:24,084 INFO CountIterations      :: iteration = 962 / 1000
# 2022-08-05 11:34:24,106 INFO Display              :: Data Fidelity--> 1.5661129358628314
# 2022-08-05 11:34:24,152 INFO CountIterations      :: iteration = 963 / 1000
# 2022-08-05 11:34:24,175 INFO Display              :: Data Fidelity--> 1.5576703819427904
# 2022-08-05 11:34:24,221 INFO CountIterations      :: iteration = 964 / 1000
# 2022-08-05 11:34:24,245 INFO Display              :: Data Fidelity--> 1.5659332632678702
# 2022-08-05 11:34:24,292 INFO CountIterations      :: iteration = 965 / 1000
# 2022-08-05 11:34:24,315 INFO Display              :: Data Fidelity--> 1.5574954544632482
# 2022-08-05 11:34:24,373 INFO CountIterations      :: iteration = 966 / 1000
# 2022-08-05 11:34:24,400 INFO Display              :: Data Fidelity--> 1.5657541748417563
# 2022-08-05 11:34:24,448 INFO CountIterations      :: iteration = 967 / 1000
# 2022-08-05 11:34:24,481 INFO Display              :: Data Fidelity--> 1.557321100159794
# 2022-08-05 11:34:24,535 INFO CountIterations      :: iteration = 968 / 1000
# 2022-08-05 11:34:24,566 INFO Display              :: Data Fidelity--> 1.5655756661575189
# 2022-08-05 11:34:24,607 INFO CountIterations      :: iteration = 969 / 1000
# 2022-08-05 11:34:24,630 INFO Display              :: Data Fidelity--> 1.5571473146482466
# 2022-08-05 11:34:24,676 INFO CountIterations      :: iteration = 970 / 1000
# 2022-08-05 11:34:24,699 INFO Display              :: Data Fidelity--> 1.565397732834759
# 2022-08-05 11:34:24,746 INFO CountIterations      :: iteration = 971 / 1000
# 2022-08-05 11:34:24,769 INFO Display              :: Data Fidelity--> 1.5569740935907816
# 2022-08-05 11:34:24,816 INFO CountIterations      :: iteration = 972 / 1000
# 2022-08-05 11:34:24,838 INFO Display              :: Data Fidelity--> 1.5652203705394632
# 2022-08-05 11:34:24,883 INFO CountIterations      :: iteration = 973 / 1000
# 2022-08-05 11:34:24,906 INFO Display              :: Data Fidelity--> 1.5568014326955446
# 2022-08-05 11:34:24,952 INFO CountIterations      :: iteration = 974 / 1000
# 2022-08-05 11:34:24,975 INFO Display              :: Data Fidelity--> 1.5650435749826865
# 2022-08-05 11:34:25,055 INFO CountIterations      :: iteration = 975 / 1000
# 2022-08-05 11:34:25,078 INFO Display              :: Data Fidelity--> 1.556629327715921
# 2022-08-05 11:34:25,127 INFO CountIterations      :: iteration = 976 / 1000
# 2022-08-05 11:34:25,151 INFO Display              :: Data Fidelity--> 1.5648673419211359
# 2022-08-05 11:34:25,200 INFO CountIterations      :: iteration = 977 / 1000
# 2022-08-05 11:34:25,224 INFO Display              :: Data Fidelity--> 1.5564577744499104
# 2022-08-05 11:34:25,284 INFO CountIterations      :: iteration = 978 / 1000
# 2022-08-05 11:34:25,319 INFO Display              :: Data Fidelity--> 1.5646916671554312
# 2022-08-05 11:34:25,368 INFO CountIterations      :: iteration = 979 / 1000
# 2022-08-05 11:34:25,400 INFO Display              :: Data Fidelity--> 1.556286768739861
# 2022-08-05 11:34:25,455 INFO CountIterations      :: iteration = 980 / 1000
# 2022-08-05 11:34:25,488 INFO Display              :: Data Fidelity--> 1.5645165465305597
# 2022-08-05 11:34:25,543 INFO CountIterations      :: iteration = 981 / 1000
# 2022-08-05 11:34:25,576 INFO Display              :: Data Fidelity--> 1.5561163064717403
# 2022-08-05 11:34:25,630 INFO CountIterations      :: iteration = 982 / 1000
# 2022-08-05 11:34:25,658 INFO Display              :: Data Fidelity--> 1.564341975934657
# 2022-08-05 11:34:25,713 INFO CountIterations      :: iteration = 983 / 1000
# 2022-08-05 11:34:25,743 INFO Display              :: Data Fidelity--> 1.5559463835747782
# 2022-08-05 11:34:25,790 INFO CountIterations      :: iteration = 984 / 1000
# 2022-08-05 11:34:25,814 INFO Display              :: Data Fidelity--> 1.5641679512991518
# 2022-08-05 11:34:25,862 INFO CountIterations      :: iteration = 985 / 1000
# 2022-08-05 11:34:25,886 INFO Display              :: Data Fidelity--> 1.5557769960207621
# 2022-08-05 11:34:25,933 INFO CountIterations      :: iteration = 986 / 1000
# 2022-08-05 11:34:25,957 INFO Display              :: Data Fidelity--> 1.563994468597636
# 2022-08-05 11:34:26,005 INFO CountIterations      :: iteration = 987 / 1000
# 2022-08-05 11:34:26,029 INFO Display              :: Data Fidelity--> 1.5556081398240507
# 2022-08-05 11:34:26,077 INFO CountIterations      :: iteration = 988 / 1000
# 2022-08-05 11:34:26,101 INFO Display              :: Data Fidelity--> 1.5638215238460615
# 2022-08-05 11:34:26,149 INFO CountIterations      :: iteration = 989 / 1000
# 2022-08-05 11:34:26,173 INFO Display              :: Data Fidelity--> 1.5554398110401995
# 2022-08-05 11:34:26,220 INFO CountIterations      :: iteration = 990 / 1000
# 2022-08-05 11:34:26,257 INFO Display              :: Data Fidelity--> 1.5636491131013843
# 2022-08-05 11:34:26,305 INFO CountIterations      :: iteration = 991 / 1000
# 2022-08-05 11:34:26,328 INFO Display              :: Data Fidelity--> 1.5552720057661218
# 2022-08-05 11:34:26,376 INFO CountIterations      :: iteration = 992 / 1000
# 2022-08-05 11:34:26,399 INFO Display              :: Data Fidelity--> 1.5634772324617185
# 2022-08-05 11:34:26,451 INFO CountIterations      :: iteration = 993 / 1000
# 2022-08-05 11:34:26,482 INFO Display              :: Data Fidelity--> 1.5551047201397952
# 2022-08-05 11:34:26,555 INFO CountIterations      :: iteration = 994 / 1000
# 2022-08-05 11:34:26,586 INFO Display              :: Data Fidelity--> 1.5633058780660105
# 2022-08-05 11:34:26,636 INFO CountIterations      :: iteration = 995 / 1000
# 2022-08-05 11:34:26,658 INFO Display              :: Data Fidelity--> 1.5549379503390766
# 2022-08-05 11:34:26,706 INFO CountIterations      :: iteration = 996 / 1000
# 2022-08-05 11:34:26,751 INFO Display              :: Data Fidelity--> 1.563135046092702
# 2022-08-05 11:34:26,804 INFO CountIterations      :: iteration = 997 / 1000
# 2022-08-05 11:34:26,828 INFO Display              :: Data Fidelity--> 1.5547716925814818
# 2022-08-05 11:34:26,876 INFO CountIterations      :: iteration = 998 / 1000
# 2022-08-05 11:34:26,899 INFO Display              :: Data Fidelity--> 1.5629647327601437
# 2022-08-05 11:34:26,960 INFO CountIterations      :: iteration = 999 / 1000
# 2022-08-05 11:34:26,993 INFO Display              :: Data Fidelity--> 1.554605943124391
# 2022-08-05 11:34:27,040 INFO CountIterations      :: iteration = 1000 / 1000
# 2022-08-05 11:34:27,041 INFO CombineRules         :: Rule CountIterations(max_iterations=1000) triggered.
# 2022-08-05 11:34:27,042 INFO Gradient_Descent     :: Stopping rule triggered.
