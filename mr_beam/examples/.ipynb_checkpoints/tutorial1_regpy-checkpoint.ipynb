# %% [markdown]
# MrBeam is composed of various software packages:
# -> ehtim (for the general handling of VLBI data)
# -> regpy (tool for inverse problems)
# -> WISE (tool for a wavelet based analysis of images)
# -> MSI (multiscale operator handling)
# -> imagingbase (containing the new VLBI imaging capabilities)
#
# In this tutorial we will present some of the key features of regpy: we show how we can invert the Volterra operator with regpy.

# %%
#Load basic modules and setup logger
import numpy as np
import logging
import matplotlib.pyplot as plt

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s %(levelname)s %(name)-20s :: %(message)s'
)

# %% [markdown]
# First we define the forward operator (i.e. the Volterra operator). We have to define a proper domain and codomain first, in this case we just use a uniform grid.

# %%
from regpy.discrs import UniformGrid
from regpy.operators.volterra import Volterra

grid = UniformGrid(np.linspace(0, 2*np.pi, 200))
op = Volterra(grid, exponent=3)

# %% [markdown]
# Now we can create synthetic data and add noise. The discretization implementation has some helper functions (coords, randn, ones, ...) for this purpose.

# %%
exact_solution = np.sin(op.domain.coords[0])
exact_data = op(exact_solution)
noise = 0.03 * op.domain.randn()
data = exact_data + noise
init = op.domain.ones()

# %% [markdown]
# We are equipping the operator "op: domain --> codomain" with a Hilbert space structure. The inner product and the respective Gram matrices will be inserted in the inversion procedure automatically. Here we are using a L2 codomain and a smooth domain (Sobolev with index 2).

# %%
from regpy.solvers import HilbertSpaceSetting
from regpy.hilbert import L2, Sobolev
setting = HilbertSpaceSetting(op=op, Hdomain=Sobolev(index=2), Hcodomain=L2)

# %% [markdown]
# Now we are defining the regularization technique: an irgnm_cg inversion.

# %%
from regpy.solvers.irgnm import IrgnmCG
solver = IrgnmCG(setting, data, regpar=1, regpar_step=0.9, init=init.copy())

# %% [markdown]
# We specify a stopping rule: stopping by maximal number of iterations or by the discrepancy principle.

# %%
import regpy.stoprules as rules
stoprule = (
    rules.CountIterations(max_iterations=100) +
    rules.Discrepancy(
        setting.Hcodomain.norm, data,
        noiselevel=setting.Hcodomain.norm(noise),
        tau=1.1
    )
)

# %% [markdown]
# Run the inversion procedure with this stopping rule and display the result.

# %%
reco, reco_data = solver.run(stoprule)

plt.plot(grid.coords[0], exact_solution.T, label='exact solution')
plt.plot(grid.coords[0], reco, label='reco')
plt.plot(grid.coords[0], exact_data, label='exact data')
plt.plot(grid.coords[0], data, label='data')
plt.plot(grid.coords[0], reco_data, label='reco data')
plt.legend()
plt.show()
# Out:
# 2022-07-28 16:37:00,417 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,431 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,432 INFO CountIterations      :: iteration = 1 / 100
# 2022-07-28 16:37:00,434 INFO Discrepancy          :: relative discrepancy = 37.16401299782148, tolerance = 1.1
# 2022-07-28 16:37:00,436 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,447 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,448 INFO CountIterations      :: iteration = 2 / 100
# 2022-07-28 16:37:00,449 INFO Discrepancy          :: relative discrepancy = 19.338983447495423, tolerance = 1.1
# 2022-07-28 16:37:00,449 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,463 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,464 INFO CountIterations      :: iteration = 3 / 100
# 2022-07-28 16:37:00,465 INFO Discrepancy          :: relative discrepancy = 23.948542295199772, tolerance = 1.1
# 2022-07-28 16:37:00,466 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,480 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,481 INFO CountIterations      :: iteration = 4 / 100
# 2022-07-28 16:37:00,482 INFO Discrepancy          :: relative discrepancy = 23.19245784728127, tolerance = 1.1
# 2022-07-28 16:37:00,482 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,496 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,497 INFO CountIterations      :: iteration = 5 / 100
# 2022-07-28 16:37:00,498 INFO Discrepancy          :: relative discrepancy = 29.088627742423192, tolerance = 1.1
# 2022-07-28 16:37:00,499 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,510 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,512 INFO CountIterations      :: iteration = 6 / 100
# 2022-07-28 16:37:00,513 INFO Discrepancy          :: relative discrepancy = 32.6359896636141, tolerance = 1.1
# 2022-07-28 16:37:00,514 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,527 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,528 INFO CountIterations      :: iteration = 7 / 100
# 2022-07-28 16:37:00,529 INFO Discrepancy          :: relative discrepancy = 28.681539914792726, tolerance = 1.1
# 2022-07-28 16:37:00,530 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,544 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,545 INFO CountIterations      :: iteration = 8 / 100
# 2022-07-28 16:37:00,546 INFO Discrepancy          :: relative discrepancy = 31.644173777912375, tolerance = 1.1
# 2022-07-28 16:37:00,547 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,561 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,562 INFO CountIterations      :: iteration = 9 / 100
# 2022-07-28 16:37:00,563 INFO Discrepancy          :: relative discrepancy = 29.525925443606997, tolerance = 1.1
# 2022-07-28 16:37:00,564 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,578 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,579 INFO CountIterations      :: iteration = 10 / 100
# 2022-07-28 16:37:00,580 INFO Discrepancy          :: relative discrepancy = 31.792045585254762, tolerance = 1.1
# 2022-07-28 16:37:00,581 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,597 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,598 INFO CountIterations      :: iteration = 11 / 100
# 2022-07-28 16:37:00,599 INFO Discrepancy          :: relative discrepancy = 29.505771561548467, tolerance = 1.1
# 2022-07-28 16:37:00,600 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,614 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,615 INFO CountIterations      :: iteration = 12 / 100
# 2022-07-28 16:37:00,616 INFO Discrepancy          :: relative discrepancy = 30.57916211414333, tolerance = 1.1
# 2022-07-28 16:37:00,616 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,634 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,635 INFO CountIterations      :: iteration = 13 / 100
# 2022-07-28 16:37:00,636 INFO Discrepancy          :: relative discrepancy = 28.337262232051522, tolerance = 1.1
# 2022-07-28 16:37:00,638 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,651 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,652 INFO CountIterations      :: iteration = 14 / 100
# 2022-07-28 16:37:00,653 INFO Discrepancy          :: relative discrepancy = 27.75675591147205, tolerance = 1.1
# 2022-07-28 16:37:00,657 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,673 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,674 INFO CountIterations      :: iteration = 15 / 100
# 2022-07-28 16:37:00,676 INFO Discrepancy          :: relative discrepancy = 23.139707764300912, tolerance = 1.1
# 2022-07-28 16:37:00,677 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,689 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,690 INFO CountIterations      :: iteration = 16 / 100
# 2022-07-28 16:37:00,693 INFO Discrepancy          :: relative discrepancy = 22.718723676982485, tolerance = 1.1
# 2022-07-28 16:37:00,694 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,710 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,711 INFO CountIterations      :: iteration = 17 / 100
# 2022-07-28 16:37:00,712 INFO Discrepancy          :: relative discrepancy = 19.701803533524625, tolerance = 1.1
# 2022-07-28 16:37:00,713 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,729 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,730 INFO CountIterations      :: iteration = 18 / 100
# 2022-07-28 16:37:00,731 INFO Discrepancy          :: relative discrepancy = 18.39366933699412, tolerance = 1.1
# 2022-07-28 16:37:00,731 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,747 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,748 INFO CountIterations      :: iteration = 19 / 100
# 2022-07-28 16:37:00,749 INFO Discrepancy          :: relative discrepancy = 13.879693953671142, tolerance = 1.1
# 2022-07-28 16:37:00,750 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,768 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,769 INFO CountIterations      :: iteration = 20 / 100
# 2022-07-28 16:37:00,770 INFO Discrepancy          :: relative discrepancy = 10.200195760615706, tolerance = 1.1
# 2022-07-28 16:37:00,772 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,791 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,793 INFO CountIterations      :: iteration = 21 / 100
# 2022-07-28 16:37:00,794 INFO Discrepancy          :: relative discrepancy = 9.567004041251279, tolerance = 1.1
# 2022-07-28 16:37:00,795 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,813 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,814 INFO CountIterations      :: iteration = 22 / 100
# 2022-07-28 16:37:00,814 INFO Discrepancy          :: relative discrepancy = 9.492972551875935, tolerance = 1.1
# 2022-07-28 16:37:00,815 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,830 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,831 INFO CountIterations      :: iteration = 23 / 100
# 2022-07-28 16:37:00,832 INFO Discrepancy          :: relative discrepancy = 10.516560426048164, tolerance = 1.1
# 2022-07-28 16:37:00,833 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,849 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,850 INFO CountIterations      :: iteration = 24 / 100
# 2022-07-28 16:37:00,851 INFO Discrepancy          :: relative discrepancy = 9.49773560514953, tolerance = 1.1
# 2022-07-28 16:37:00,852 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,869 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,869 INFO CountIterations      :: iteration = 25 / 100
# 2022-07-28 16:37:00,871 INFO Discrepancy          :: relative discrepancy = 10.92920839453853, tolerance = 1.1
# 2022-07-28 16:37:00,873 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,888 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,891 INFO CountIterations      :: iteration = 26 / 100
# 2022-07-28 16:37:00,892 INFO Discrepancy          :: relative discrepancy = 10.080509512034949, tolerance = 1.1
# 2022-07-28 16:37:00,894 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,910 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,911 INFO CountIterations      :: iteration = 27 / 100
# 2022-07-28 16:37:00,912 INFO Discrepancy          :: relative discrepancy = 11.651675780933543, tolerance = 1.1
# 2022-07-28 16:37:00,913 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,933 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,934 INFO CountIterations      :: iteration = 28 / 100
# 2022-07-28 16:37:00,934 INFO Discrepancy          :: relative discrepancy = 8.50197141569702, tolerance = 1.1
# 2022-07-28 16:37:00,935 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,950 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,950 INFO CountIterations      :: iteration = 29 / 100
# 2022-07-28 16:37:00,951 INFO Discrepancy          :: relative discrepancy = 10.011046276543693, tolerance = 1.1
# 2022-07-28 16:37:00,952 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,967 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,967 INFO CountIterations      :: iteration = 30 / 100
# 2022-07-28 16:37:00,968 INFO Discrepancy          :: relative discrepancy = 7.595958712398525, tolerance = 1.1
# 2022-07-28 16:37:00,969 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:00,985 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:00,986 INFO CountIterations      :: iteration = 31 / 100
# 2022-07-28 16:37:00,986 INFO Discrepancy          :: relative discrepancy = 8.675850770498128, tolerance = 1.1
# 2022-07-28 16:37:00,989 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,004 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,007 INFO CountIterations      :: iteration = 32 / 100
# 2022-07-28 16:37:01,008 INFO Discrepancy          :: relative discrepancy = 6.673103522531176, tolerance = 1.1
# 2022-07-28 16:37:01,008 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,025 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,026 INFO CountIterations      :: iteration = 33 / 100
# 2022-07-28 16:37:01,027 INFO Discrepancy          :: relative discrepancy = 7.225139804263913, tolerance = 1.1
# 2022-07-28 16:37:01,027 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,045 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,046 INFO CountIterations      :: iteration = 34 / 100
# 2022-07-28 16:37:01,047 INFO Discrepancy          :: relative discrepancy = 5.6806608543021975, tolerance = 1.1
# 2022-07-28 16:37:01,048 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,064 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,065 INFO CountIterations      :: iteration = 35 / 100
# 2022-07-28 16:37:01,065 INFO Discrepancy          :: relative discrepancy = 5.920740324607068, tolerance = 1.1
# 2022-07-28 16:37:01,066 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,084 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,085 INFO CountIterations      :: iteration = 36 / 100
# 2022-07-28 16:37:01,085 INFO Discrepancy          :: relative discrepancy = 4.76418484569589, tolerance = 1.1
# 2022-07-28 16:37:01,086 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,102 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,103 INFO CountIterations      :: iteration = 37 / 100
# 2022-07-28 16:37:01,107 INFO Discrepancy          :: relative discrepancy = 4.834101519986459, tolerance = 1.1
# 2022-07-28 16:37:01,108 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,127 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,128 INFO CountIterations      :: iteration = 38 / 100
# 2022-07-28 16:37:01,128 INFO Discrepancy          :: relative discrepancy = 3.9443284695352054, tolerance = 1.1
# 2022-07-28 16:37:01,129 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,149 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,150 INFO CountIterations      :: iteration = 39 / 100
# 2022-07-28 16:37:01,150 INFO Discrepancy          :: relative discrepancy = 4.117410777461287, tolerance = 1.1
# 2022-07-28 16:37:01,151 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,174 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,175 INFO CountIterations      :: iteration = 40 / 100
# 2022-07-28 16:37:01,176 INFO Discrepancy          :: relative discrepancy = 3.3664956243198327, tolerance = 1.1
# 2022-07-28 16:37:01,176 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,196 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,197 INFO CountIterations      :: iteration = 41 / 100
# 2022-07-28 16:37:01,198 INFO Discrepancy          :: relative discrepancy = 3.5838342937082093, tolerance = 1.1
# 2022-07-28 16:37:01,198 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,217 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,218 INFO CountIterations      :: iteration = 42 / 100
# 2022-07-28 16:37:01,218 INFO Discrepancy          :: relative discrepancy = 2.922064576357646, tolerance = 1.1
# 2022-07-28 16:37:01,219 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,238 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,239 INFO CountIterations      :: iteration = 43 / 100
# 2022-07-28 16:37:01,240 INFO Discrepancy          :: relative discrepancy = 3.1701227712101256, tolerance = 1.1
# 2022-07-28 16:37:01,241 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,261 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,262 INFO CountIterations      :: iteration = 44 / 100
# 2022-07-28 16:37:01,263 INFO Discrepancy          :: relative discrepancy = 2.5675017054924583, tolerance = 1.1
# 2022-07-28 16:37:01,263 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,283 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,283 INFO CountIterations      :: iteration = 45 / 100
# 2022-07-28 16:37:01,284 INFO Discrepancy          :: relative discrepancy = 2.8004658041576858, tolerance = 1.1
# 2022-07-28 16:37:01,285 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,305 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,306 INFO CountIterations      :: iteration = 46 / 100
# 2022-07-28 16:37:01,307 INFO Discrepancy          :: relative discrepancy = 2.254684794561834, tolerance = 1.1
# 2022-07-28 16:37:01,308 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,329 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,330 INFO CountIterations      :: iteration = 47 / 100
# 2022-07-28 16:37:01,331 INFO Discrepancy          :: relative discrepancy = 2.461474478797929, tolerance = 1.1
# 2022-07-28 16:37:01,332 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,352 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,353 INFO CountIterations      :: iteration = 48 / 100
# 2022-07-28 16:37:01,355 INFO Discrepancy          :: relative discrepancy = 1.977794262827623, tolerance = 1.1
# 2022-07-28 16:37:01,356 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,378 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,379 INFO CountIterations      :: iteration = 49 / 100
# 2022-07-28 16:37:01,380 INFO Discrepancy          :: relative discrepancy = 2.1513068564669413, tolerance = 1.1
# 2022-07-28 16:37:01,381 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,405 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,407 INFO CountIterations      :: iteration = 50 / 100
# 2022-07-28 16:37:01,408 INFO Discrepancy          :: relative discrepancy = 1.7366430645550932, tolerance = 1.1
# 2022-07-28 16:37:01,408 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,433 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,433 INFO CountIterations      :: iteration = 51 / 100
# 2022-07-28 16:37:01,434 INFO Discrepancy          :: relative discrepancy = 1.8771997181642206, tolerance = 1.1
# 2022-07-28 16:37:01,435 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,461 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,462 INFO CountIterations      :: iteration = 52 / 100
# 2022-07-28 16:37:01,462 INFO Discrepancy          :: relative discrepancy = 1.5344091844854888, tolerance = 1.1
# 2022-07-28 16:37:01,463 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,488 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,489 INFO CountIterations      :: iteration = 53 / 100
# 2022-07-28 16:37:01,490 INFO Discrepancy          :: relative discrepancy = 1.6447783023171458, tolerance = 1.1
# 2022-07-28 16:37:01,491 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,515 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,516 INFO CountIterations      :: iteration = 54 / 100
# 2022-07-28 16:37:01,517 INFO Discrepancy          :: relative discrepancy = 1.3722356592227338, tolerance = 1.1
# 2022-07-28 16:37:01,517 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,545 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,545 INFO CountIterations      :: iteration = 55 / 100
# 2022-07-28 16:37:01,546 INFO Discrepancy          :: relative discrepancy = 1.4570151751889242, tolerance = 1.1
# 2022-07-28 16:37:01,547 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,580 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,581 INFO CountIterations      :: iteration = 56 / 100
# 2022-07-28 16:37:01,581 INFO Discrepancy          :: relative discrepancy = 1.248227413785032, tolerance = 1.1
# 2022-07-28 16:37:01,582 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,611 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,612 INFO CountIterations      :: iteration = 57 / 100
# 2022-07-28 16:37:01,612 INFO Discrepancy          :: relative discrepancy = 1.312492600335754, tolerance = 1.1
# 2022-07-28 16:37:01,613 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,642 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,643 INFO CountIterations      :: iteration = 58 / 100
# 2022-07-28 16:37:01,643 INFO Discrepancy          :: relative discrepancy = 1.1572654721115794, tolerance = 1.1
# 2022-07-28 16:37:01,644 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,673 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,673 INFO CountIterations      :: iteration = 59 / 100
# 2022-07-28 16:37:01,674 INFO Discrepancy          :: relative discrepancy = 1.2060006172388118, tolerance = 1.1
# 2022-07-28 16:37:01,675 INFO IrgnmCG              :: Running Tikhonov solver.
# 2022-07-28 16:37:01,700 INFO TikhonovCG           :: Solver converged.
# 2022-07-28 16:37:01,701 INFO CountIterations      :: iteration = 60 / 100
# 2022-07-28 16:37:01,702 INFO Discrepancy          :: relative discrepancy = 1.0925794845125942, tolerance = 1.1
# 2022-07-28 16:37:01,703 INFO CombineRules         :: Rule Discrepancy(noiselevel=0.07059389707477463, tau=1.1) triggered.
# 2022-07-28 16:37:01,705 INFO IrgnmCG              :: Stopping rule triggered.

# %% [markdown]
# IRGNM_CG is gradient based solver. However, not all data fidelity terms and penalty terms possess a uniquely defined gradient (e.g. total variation, L1, ...). Therefore, we provide a framework for convex optimization of general objective functionals in imagingbase. Here we present TV regularization:

# %%
from imagingbase.regpy_functionals import TV, HilbertNorm

data_fidelity_operator = op - data
data_fidelity = HilbertNorm(setting.Hcodomain) * data_fidelity_operator
"""The penalty term: 1/2 * ||f||_{TV}^2"""
penalty = TV(setting.Hdomain.discr, Hdomain=setting.Hdomain)

# %% [markdown]
# This also demonstrates another property of regpy: operators can be added, multiplied with constant factors and combined with functionals or other operators. The respective gradients and derivatives by the chain rule are handled by regpy internally. This makes it most easy to work with operator combinations or operators/functionals on product spaces.
#
# We do the minimization by the proximal-point based FISTA algorithm. The proximal point algorithm of the TV penalty term is computed by the Chambolle-Pock algorithm.

# %%
from imagingbase.solvers.fista import FISTA

"""Parameters for the inner computation of the proximal operator with the Chambolle algorithm"""
proximal_pars = {
        'stepsize' : 0.001,
        'maxiter' : 100
        }

tau = 0.01
alpha = 0.01

solver = FISTA(setting, data_fidelity, penalty, init.copy(), tau = tau, regpar = alpha, proximal_pars=proximal_pars)

# %% [markdown]
# As above we define a stopping rule, run the minimization and display the result:

# %%
stoprule = (
    # Method is slow, so need to use large number of iterations
    rules.CountIterations(max_iterations=100000) +
    rules.Discrepancy(
        setting.Hcodomain.norm, data,
        noiselevel=setting.Hcodomain.norm(noise),
        tau=1.3
    )
)

reco, reco_data = solver.run(stoprule)

plt.plot(grid.coords[0], exact_solution.T, label='exact solution')
plt.plot(grid.coords[0], reco, label='reco')
plt.plot(grid.coords[0], exact_data, label='exact data')
plt.plot(grid.coords[0], data, label='data')
plt.plot(grid.coords[0], reco_data, label='reco data')
plt.legend()
plt.show()
# Out:
# 2022-07-27 16:19:09,723 INFO CountIterations      :: iteration = 1 / 100000
# 2022-07-27 16:19:09,724 INFO Discrepancy          :: relative discrepancy = 26.73596402229035, tolerance = 1.3
# 2022-07-27 16:19:09,759 INFO CountIterations      :: iteration = 2 / 100000
# 2022-07-27 16:19:09,761 INFO Discrepancy          :: relative discrepancy = 25.23751930140216, tolerance = 1.3
# 2022-07-27 16:19:09,803 INFO CountIterations      :: iteration = 3 / 100000
# 2022-07-27 16:19:09,805 INFO Discrepancy          :: relative discrepancy = 23.898604451961173, tolerance = 1.3
# 2022-07-27 16:19:09,840 INFO CountIterations      :: iteration = 4 / 100000
# 2022-07-27 16:19:09,841 INFO Discrepancy          :: relative discrepancy = 22.760396735425378, tolerance = 1.3
# 2022-07-27 16:19:09,878 INFO CountIterations      :: iteration = 5 / 100000
# 2022-07-27 16:19:09,879 INFO Discrepancy          :: relative discrepancy = 21.801075292512316, tolerance = 1.3
# 2022-07-27 16:19:09,910 INFO CountIterations      :: iteration = 6 / 100000
# 2022-07-27 16:19:09,912 INFO Discrepancy          :: relative discrepancy = 20.978471218914585, tolerance = 1.3
# 2022-07-27 16:19:09,943 INFO CountIterations      :: iteration = 7 / 100000
# 2022-07-27 16:19:09,944 INFO Discrepancy          :: relative discrepancy = 20.252349930602445, tolerance = 1.3
# 2022-07-27 16:19:09,980 INFO CountIterations      :: iteration = 8 / 100000
# 2022-07-27 16:19:09,981 INFO Discrepancy          :: relative discrepancy = 19.59500825358414, tolerance = 1.3
# 2022-07-27 16:19:10,015 INFO CountIterations      :: iteration = 9 / 100000
# 2022-07-27 16:19:10,016 INFO Discrepancy          :: relative discrepancy = 18.993323767597126, tolerance = 1.3
# 2022-07-27 16:19:10,051 INFO CountIterations      :: iteration = 10 / 100000
# 2022-07-27 16:19:10,052 INFO Discrepancy          :: relative discrepancy = 18.44592430399766, tolerance = 1.3
# 2022-07-27 16:19:10,086 INFO CountIterations      :: iteration = 11 / 100000
# 2022-07-27 16:19:10,087 INFO Discrepancy          :: relative discrepancy = 17.957008737941518, tolerance = 1.3
# 2022-07-27 16:19:10,121 INFO CountIterations      :: iteration = 12 / 100000
# 2022-07-27 16:19:10,122 INFO Discrepancy          :: relative discrepancy = 17.530267407598863, tolerance = 1.3
# 2022-07-27 16:19:10,156 INFO CountIterations      :: iteration = 13 / 100000
# 2022-07-27 16:19:10,156 INFO Discrepancy          :: relative discrepancy = 17.164469065840805, tolerance = 1.3
# 2022-07-27 16:19:10,190 INFO CountIterations      :: iteration = 14 / 100000
# 2022-07-27 16:19:10,191 INFO Discrepancy          :: relative discrepancy = 16.8528817389261, tolerance = 1.3
# 2022-07-27 16:19:10,225 INFO CountIterations      :: iteration = 15 / 100000
# 2022-07-27 16:19:10,225 INFO Discrepancy          :: relative discrepancy = 16.58625514567371, tolerance = 1.3
# 2022-07-27 16:19:10,257 INFO CountIterations      :: iteration = 16 / 100000
# 2022-07-27 16:19:10,258 INFO Discrepancy          :: relative discrepancy = 16.356111008225174, tolerance = 1.3
# 2022-07-27 16:19:10,291 INFO CountIterations      :: iteration = 17 / 100000
# 2022-07-27 16:19:10,291 INFO Discrepancy          :: relative discrepancy = 16.156009948033784, tolerance = 1.3
# 2022-07-27 16:19:10,325 INFO CountIterations      :: iteration = 18 / 100000
# 2022-07-27 16:19:10,326 INFO Discrepancy          :: relative discrepancy = 15.981513781090504, tolerance = 1.3
# 2022-07-27 16:19:10,359 INFO CountIterations      :: iteration = 19 / 100000
# 2022-07-27 16:19:10,360 INFO Discrepancy          :: relative discrepancy = 15.829256124766552, tolerance = 1.3
# 2022-07-27 16:19:10,395 INFO CountIterations      :: iteration = 20 / 100000
# 2022-07-27 16:19:10,396 INFO Discrepancy          :: relative discrepancy = 15.696324219074807, tolerance = 1.3
# 2022-07-27 16:19:10,432 INFO CountIterations      :: iteration = 21 / 100000
# 2022-07-27 16:19:10,434 INFO Discrepancy          :: relative discrepancy = 15.57975934662222, tolerance = 1.3
# 2022-07-27 16:19:10,471 INFO CountIterations      :: iteration = 22 / 100000
# 2022-07-27 16:19:10,472 INFO Discrepancy          :: relative discrepancy = 15.477225967396192, tolerance = 1.3
# 2022-07-27 16:19:10,510 INFO CountIterations      :: iteration = 23 / 100000
# 2022-07-27 16:19:10,511 INFO Discrepancy          :: relative discrepancy = 15.386530324918573, tolerance = 1.3
# 2022-07-27 16:19:10,544 INFO CountIterations      :: iteration = 24 / 100000
# 2022-07-27 16:19:10,545 INFO Discrepancy          :: relative discrepancy = 15.30605881138943, tolerance = 1.3
# 2022-07-27 16:19:10,581 INFO CountIterations      :: iteration = 25 / 100000
# 2022-07-27 16:19:10,582 INFO Discrepancy          :: relative discrepancy = 15.23431522676675, tolerance = 1.3
# 2022-07-27 16:19:10,619 INFO CountIterations      :: iteration = 26 / 100000
# 2022-07-27 16:19:10,620 INFO Discrepancy          :: relative discrepancy = 15.1701191504688, tolerance = 1.3
# 2022-07-27 16:19:10,653 INFO CountIterations      :: iteration = 27 / 100000
# 2022-07-27 16:19:10,654 INFO Discrepancy          :: relative discrepancy = 15.112470133678727, tolerance = 1.3
# 2022-07-27 16:19:10,686 INFO CountIterations      :: iteration = 28 / 100000
# 2022-07-27 16:19:10,687 INFO Discrepancy          :: relative discrepancy = 15.060443179649495, tolerance = 1.3
# 2022-07-27 16:19:10,728 INFO CountIterations      :: iteration = 29 / 100000
# 2022-07-27 16:19:10,729 INFO Discrepancy          :: relative discrepancy = 15.013337409077305, tolerance = 1.3
# 2022-07-27 16:19:10,775 INFO CountIterations      :: iteration = 30 / 100000
# 2022-07-27 16:19:10,776 INFO Discrepancy          :: relative discrepancy = 14.970309426558776, tolerance = 1.3
# 2022-07-27 16:19:10,810 INFO CountIterations      :: iteration = 31 / 100000
# 2022-07-27 16:19:10,810 INFO Discrepancy          :: relative discrepancy = 14.930759583592158, tolerance = 1.3
# 2022-07-27 16:19:10,853 INFO CountIterations      :: iteration = 32 / 100000
# 2022-07-27 16:19:10,854 INFO Discrepancy          :: relative discrepancy = 14.894374030168967, tolerance = 1.3
# 2022-07-27 16:19:10,884 INFO CountIterations      :: iteration = 33 / 100000
# 2022-07-27 16:19:10,885 INFO Discrepancy          :: relative discrepancy = 14.860786208273982, tolerance = 1.3
# 2022-07-27 16:19:10,915 INFO CountIterations      :: iteration = 34 / 100000
# 2022-07-27 16:19:10,917 INFO Discrepancy          :: relative discrepancy = 14.8296930380435, tolerance = 1.3
# 2022-07-27 16:19:10,957 INFO CountIterations      :: iteration = 35 / 100000
# 2022-07-27 16:19:10,958 INFO Discrepancy          :: relative discrepancy = 14.80081694041298, tolerance = 1.3
# 2022-07-27 16:19:10,996 INFO CountIterations      :: iteration = 36 / 100000
# 2022-07-27 16:19:10,996 INFO Discrepancy          :: relative discrepancy = 14.773951780797898, tolerance = 1.3
# 2022-07-27 16:19:11,029 INFO CountIterations      :: iteration = 37 / 100000
# 2022-07-27 16:19:11,030 INFO Discrepancy          :: relative discrepancy = 14.748925523291124, tolerance = 1.3
# 2022-07-27 16:19:11,064 INFO CountIterations      :: iteration = 38 / 100000
# 2022-07-27 16:19:11,065 INFO Discrepancy          :: relative discrepancy = 14.725544918549518, tolerance = 1.3
# 2022-07-27 16:19:11,098 INFO CountIterations      :: iteration = 39 / 100000
# 2022-07-27 16:19:11,099 INFO Discrepancy          :: relative discrepancy = 14.703694699387052, tolerance = 1.3
# 2022-07-27 16:19:11,130 INFO CountIterations      :: iteration = 40 / 100000
# 2022-07-27 16:19:11,131 INFO Discrepancy          :: relative discrepancy = 14.683210421234559, tolerance = 1.3
# 2022-07-27 16:19:11,166 INFO CountIterations      :: iteration = 41 / 100000
# 2022-07-27 16:19:11,168 INFO Discrepancy          :: relative discrepancy = 14.663994712740658, tolerance = 1.3
# 2022-07-27 16:19:11,201 INFO CountIterations      :: iteration = 42 / 100000
# 2022-07-27 16:19:11,202 INFO Discrepancy          :: relative discrepancy = 14.645936800232189, tolerance = 1.3
# 2022-07-27 16:19:11,238 INFO CountIterations      :: iteration = 43 / 100000
# 2022-07-27 16:19:11,239 INFO Discrepancy          :: relative discrepancy = 14.628922925667645, tolerance = 1.3
# 2022-07-27 16:19:11,277 INFO CountIterations      :: iteration = 44 / 100000
# 2022-07-27 16:19:11,278 INFO Discrepancy          :: relative discrepancy = 14.61286998636738, tolerance = 1.3
# 2022-07-27 16:19:11,312 INFO CountIterations      :: iteration = 45 / 100000
# 2022-07-27 16:19:11,313 INFO Discrepancy          :: relative discrepancy = 14.597695124758797, tolerance = 1.3
# 2022-07-27 16:19:11,358 INFO CountIterations      :: iteration = 46 / 100000
# 2022-07-27 16:19:11,359 INFO Discrepancy          :: relative discrepancy = 14.583310533822699, tolerance = 1.3
# 2022-07-27 16:19:11,396 INFO CountIterations      :: iteration = 47 / 100000
# 2022-07-27 16:19:11,397 INFO Discrepancy          :: relative discrepancy = 14.569666841121084, tolerance = 1.3
# 2022-07-27 16:19:11,430 INFO CountIterations      :: iteration = 48 / 100000
# 2022-07-27 16:19:11,431 INFO Discrepancy          :: relative discrepancy = 14.556707806611062, tolerance = 1.3
# 2022-07-27 16:19:11,467 INFO CountIterations      :: iteration = 49 / 100000
# 2022-07-27 16:19:11,468 INFO Discrepancy          :: relative discrepancy = 14.544393534783582, tolerance = 1.3
# 2022-07-27 16:19:11,509 INFO CountIterations      :: iteration = 50 / 100000
# 2022-07-27 16:19:11,509 INFO Discrepancy          :: relative discrepancy = 14.532672574711162, tolerance = 1.3
# 2022-07-27 16:19:11,543 INFO CountIterations      :: iteration = 51 / 100000
# 2022-07-27 16:19:11,544 INFO Discrepancy          :: relative discrepancy = 14.521509554659021, tolerance = 1.3
# 2022-07-27 16:19:11,579 INFO CountIterations      :: iteration = 52 / 100000
# 2022-07-27 16:19:11,580 INFO Discrepancy          :: relative discrepancy = 14.510874704189042, tolerance = 1.3
# 2022-07-27 16:19:11,612 INFO CountIterations      :: iteration = 53 / 100000
# 2022-07-27 16:19:11,613 INFO Discrepancy          :: relative discrepancy = 14.500725109237509, tolerance = 1.3
# 2022-07-27 16:19:11,646 INFO CountIterations      :: iteration = 54 / 100000
# 2022-07-27 16:19:11,647 INFO Discrepancy          :: relative discrepancy = 14.491029075477382, tolerance = 1.3
# 2022-07-27 16:19:11,677 INFO CountIterations      :: iteration = 55 / 100000
# 2022-07-27 16:19:11,678 INFO Discrepancy          :: relative discrepancy = 14.481764056679337, tolerance = 1.3
# 2022-07-27 16:19:11,706 INFO CountIterations      :: iteration = 56 / 100000
# 2022-07-27 16:19:11,707 INFO Discrepancy          :: relative discrepancy = 14.472925329676643, tolerance = 1.3
# 2022-07-27 16:19:11,735 INFO CountIterations      :: iteration = 57 / 100000
# 2022-07-27 16:19:11,736 INFO Discrepancy          :: relative discrepancy = 14.464476320355432, tolerance = 1.3
# 2022-07-27 16:19:11,762 INFO CountIterations      :: iteration = 58 / 100000
# 2022-07-27 16:19:11,763 INFO Discrepancy          :: relative discrepancy = 14.456391734599833, tolerance = 1.3
# 2022-07-27 16:19:11,791 INFO CountIterations      :: iteration = 59 / 100000
# 2022-07-27 16:19:11,792 INFO Discrepancy          :: relative discrepancy = 14.44865305856416, tolerance = 1.3
# 2022-07-27 16:19:11,821 INFO CountIterations      :: iteration = 60 / 100000
# 2022-07-27 16:19:11,822 INFO Discrepancy          :: relative discrepancy = 14.441233339215968, tolerance = 1.3
# 2022-07-27 16:19:11,851 INFO CountIterations      :: iteration = 61 / 100000
# 2022-07-27 16:19:11,852 INFO Discrepancy          :: relative discrepancy = 14.434120436065552, tolerance = 1.3
# 2022-07-27 16:19:11,881 INFO CountIterations      :: iteration = 62 / 100000
# 2022-07-27 16:19:11,882 INFO Discrepancy          :: relative discrepancy = 14.427283397272298, tolerance = 1.3
# 2022-07-27 16:19:11,912 INFO CountIterations      :: iteration = 63 / 100000
# 2022-07-27 16:19:11,913 INFO Discrepancy          :: relative discrepancy = 14.42071891934577, tolerance = 1.3
# 2022-07-27 16:19:11,942 INFO CountIterations      :: iteration = 64 / 100000
# 2022-07-27 16:19:11,943 INFO Discrepancy          :: relative discrepancy = 14.414415241076714, tolerance = 1.3
# 2022-07-27 16:19:11,972 INFO CountIterations      :: iteration = 65 / 100000
# 2022-07-27 16:19:11,973 INFO Discrepancy          :: relative discrepancy = 14.408346727753502, tolerance = 1.3
# 2022-07-27 16:19:12,004 INFO CountIterations      :: iteration = 66 / 100000
# 2022-07-27 16:19:12,005 INFO Discrepancy          :: relative discrepancy = 14.402509333530302, tolerance = 1.3
# 2022-07-27 16:19:12,032 INFO CountIterations      :: iteration = 67 / 100000
# 2022-07-27 16:19:12,033 INFO Discrepancy          :: relative discrepancy = 14.39686014266939, tolerance = 1.3
# 2022-07-27 16:19:12,059 INFO CountIterations      :: iteration = 68 / 100000
# 2022-07-27 16:19:12,060 INFO Discrepancy          :: relative discrepancy = 14.39143595483293, tolerance = 1.3
# 2022-07-27 16:19:12,089 INFO CountIterations      :: iteration = 69 / 100000
# 2022-07-27 16:19:12,090 INFO Discrepancy          :: relative discrepancy = 14.386210294427956, tolerance = 1.3
# 2022-07-27 16:19:12,120 INFO CountIterations      :: iteration = 70 / 100000
# 2022-07-27 16:19:12,120 INFO Discrepancy          :: relative discrepancy = 14.38117689228428, tolerance = 1.3
# 2022-07-27 16:19:12,150 INFO CountIterations      :: iteration = 71 / 100000
# 2022-07-27 16:19:12,151 INFO Discrepancy          :: relative discrepancy = 14.376314750034753, tolerance = 1.3
# 2022-07-27 16:19:12,179 INFO CountIterations      :: iteration = 72 / 100000
# 2022-07-27 16:19:12,180 INFO Discrepancy          :: relative discrepancy = 14.371627771979169, tolerance = 1.3
# 2022-07-27 16:19:12,208 INFO CountIterations      :: iteration = 73 / 100000
# 2022-07-27 16:19:12,209 INFO Discrepancy          :: relative discrepancy = 14.367108179205848, tolerance = 1.3
# 2022-07-27 16:19:12,237 INFO CountIterations      :: iteration = 74 / 100000
# 2022-07-27 16:19:12,238 INFO Discrepancy          :: relative discrepancy = 14.362742362577816, tolerance = 1.3
# 2022-07-27 16:19:12,266 INFO CountIterations      :: iteration = 75 / 100000
# 2022-07-27 16:19:12,267 INFO Discrepancy          :: relative discrepancy = 14.35852811226122, tolerance = 1.3
# 2022-07-27 16:19:12,296 INFO CountIterations      :: iteration = 76 / 100000
# 2022-07-27 16:19:12,296 INFO Discrepancy          :: relative discrepancy = 14.35447127850015, tolerance = 1.3
# 2022-07-27 16:19:12,327 INFO CountIterations      :: iteration = 77 / 100000
# 2022-07-27 16:19:12,328 INFO Discrepancy          :: relative discrepancy = 14.350554278101708, tolerance = 1.3
# 2022-07-27 16:19:12,358 INFO CountIterations      :: iteration = 78 / 100000
# 2022-07-27 16:19:12,360 INFO Discrepancy          :: relative discrepancy = 14.346779178718645, tolerance = 1.3
# 2022-07-27 16:19:12,388 INFO CountIterations      :: iteration = 79 / 100000
# 2022-07-27 16:19:12,390 INFO Discrepancy          :: relative discrepancy = 14.343117393639933, tolerance = 1.3
# 2022-07-27 16:19:12,417 INFO CountIterations      :: iteration = 80 / 100000
# 2022-07-27 16:19:12,418 INFO Discrepancy          :: relative discrepancy = 14.339563023037083, tolerance = 1.3
# 2022-07-27 16:19:12,451 INFO CountIterations      :: iteration = 81 / 100000
# 2022-07-27 16:19:12,452 INFO Discrepancy          :: relative discrepancy = 14.336107124017886, tolerance = 1.3
# 2022-07-27 16:19:12,486 INFO CountIterations      :: iteration = 82 / 100000
# 2022-07-27 16:19:12,486 INFO Discrepancy          :: relative discrepancy = 14.332741101373324, tolerance = 1.3
# 2022-07-27 16:19:12,518 INFO CountIterations      :: iteration = 83 / 100000
# 2022-07-27 16:19:12,519 INFO Discrepancy          :: relative discrepancy = 14.329473318090017, tolerance = 1.3
# 2022-07-27 16:19:12,555 INFO CountIterations      :: iteration = 84 / 100000
# 2022-07-27 16:19:12,556 INFO Discrepancy          :: relative discrepancy = 14.326290477411973, tolerance = 1.3
# 2022-07-27 16:19:12,588 INFO CountIterations      :: iteration = 85 / 100000
# 2022-07-27 16:19:12,589 INFO Discrepancy          :: relative discrepancy = 14.323185841017045, tolerance = 1.3
# 2022-07-27 16:19:12,623 INFO CountIterations      :: iteration = 86 / 100000
# 2022-07-27 16:19:12,624 INFO Discrepancy          :: relative discrepancy = 14.320175583753883, tolerance = 1.3
# 2022-07-27 16:19:12,655 INFO CountIterations      :: iteration = 87 / 100000
# 2022-07-27 16:19:12,656 INFO Discrepancy          :: relative discrepancy = 14.317264498633307, tolerance = 1.3
# 2022-07-27 16:19:12,688 INFO CountIterations      :: iteration = 88 / 100000
# 2022-07-27 16:19:12,689 INFO Discrepancy          :: relative discrepancy = 14.314441786251862, tolerance = 1.3
# 2022-07-27 16:19:12,722 INFO CountIterations      :: iteration = 89 / 100000
# 2022-07-27 16:19:12,723 INFO Discrepancy          :: relative discrepancy = 14.311711569244958, tolerance = 1.3
# 2022-07-27 16:19:12,757 INFO CountIterations      :: iteration = 90 / 100000
# 2022-07-27 16:19:12,757 INFO Discrepancy          :: relative discrepancy = 14.309049370070625, tolerance = 1.3
# 2022-07-27 16:19:12,789 INFO CountIterations      :: iteration = 91 / 100000
# 2022-07-27 16:19:12,790 INFO Discrepancy          :: relative discrepancy = 14.306471532138666, tolerance = 1.3
# 2022-07-27 16:19:12,828 INFO CountIterations      :: iteration = 92 / 100000
# 2022-07-27 16:19:12,828 INFO Discrepancy          :: relative discrepancy = 14.303965774665551, tolerance = 1.3
# 2022-07-27 16:19:12,859 INFO CountIterations      :: iteration = 93 / 100000
# 2022-07-27 16:19:12,860 INFO Discrepancy          :: relative discrepancy = 14.301535888753747, tolerance = 1.3
# 2022-07-27 16:19:12,893 INFO CountIterations      :: iteration = 94 / 100000
# 2022-07-27 16:19:12,895 INFO Discrepancy          :: relative discrepancy = 14.29916600052254, tolerance = 1.3
# 2022-07-27 16:19:12,925 INFO CountIterations      :: iteration = 95 / 100000
# 2022-07-27 16:19:12,926 INFO Discrepancy          :: relative discrepancy = 14.296850558011108, tolerance = 1.3
# 2022-07-27 16:19:12,957 INFO CountIterations      :: iteration = 96 / 100000
# 2022-07-27 16:19:12,958 INFO Discrepancy          :: relative discrepancy = 14.294602212660932, tolerance = 1.3
# 2022-07-27 16:19:12,990 INFO CountIterations      :: iteration = 97 / 100000
# 2022-07-27 16:19:12,991 INFO Discrepancy          :: relative discrepancy = 14.29239947908568, tolerance = 1.3
# 2022-07-27 16:19:13,020 INFO CountIterations      :: iteration = 98 / 100000
# 2022-07-27 16:19:13,022 INFO Discrepancy          :: relative discrepancy = 14.290262498602948, tolerance = 1.3
# 2022-07-27 16:19:13,050 INFO CountIterations      :: iteration = 99 / 100000
# 2022-07-27 16:19:13,051 INFO Discrepancy          :: relative discrepancy = 14.288194841700502, tolerance = 1.3
# 2022-07-27 16:19:13,079 INFO CountIterations      :: iteration = 100 / 100000
# 2022-07-27 16:19:13,081 INFO Discrepancy          :: relative discrepancy = 14.286174712269709, tolerance = 1.3
# 2022-07-27 16:19:13,110 INFO CountIterations      :: iteration = 101 / 100000
# 2022-07-27 16:19:13,111 INFO Discrepancy          :: relative discrepancy = 14.284203768473631, tolerance = 1.3
# 2022-07-27 16:19:13,140 INFO CountIterations      :: iteration = 102 / 100000
# 2022-07-27 16:19:13,141 INFO Discrepancy          :: relative discrepancy = 14.282268813015689, tolerance = 1.3
# 2022-07-27 16:19:13,173 INFO CountIterations      :: iteration = 103 / 100000
# 2022-07-27 16:19:13,174 INFO Discrepancy          :: relative discrepancy = 14.280386377112515, tolerance = 1.3
# 2022-07-27 16:19:13,207 INFO CountIterations      :: iteration = 104 / 100000
# 2022-07-27 16:19:13,208 INFO Discrepancy          :: relative discrepancy = 14.278557577426762, tolerance = 1.3
# 2022-07-27 16:19:13,238 INFO CountIterations      :: iteration = 105 / 100000
# 2022-07-27 16:19:13,238 INFO Discrepancy          :: relative discrepancy = 14.276761195202107, tolerance = 1.3
# 2022-07-27 16:19:13,269 INFO CountIterations      :: iteration = 106 / 100000
# 2022-07-27 16:19:13,269 INFO Discrepancy          :: relative discrepancy = 14.275016015747731, tolerance = 1.3
# 2022-07-27 16:19:13,301 INFO CountIterations      :: iteration = 107 / 100000
# 2022-07-27 16:19:13,302 INFO Discrepancy          :: relative discrepancy = 14.273309056676464, tolerance = 1.3
# 2022-07-27 16:19:13,329 INFO CountIterations      :: iteration = 108 / 100000
# 2022-07-27 16:19:13,330 INFO Discrepancy          :: relative discrepancy = 14.271628741499994, tolerance = 1.3
# 2022-07-27 16:19:13,358 INFO CountIterations      :: iteration = 109 / 100000
# 2022-07-27 16:19:13,359 INFO Discrepancy          :: relative discrepancy = 14.269980649327445, tolerance = 1.3
# 2022-07-27 16:19:13,391 INFO CountIterations      :: iteration = 110 / 100000
# 2022-07-27 16:19:13,392 INFO Discrepancy          :: relative discrepancy = 14.268378025105672, tolerance = 1.3
# 2022-07-27 16:19:13,422 INFO CountIterations      :: iteration = 111 / 100000
# 2022-07-27 16:19:13,424 INFO Discrepancy          :: relative discrepancy = 14.26682597273706, tolerance = 1.3
# 2022-07-27 16:19:13,453 INFO CountIterations      :: iteration = 112 / 100000
# 2022-07-27 16:19:13,454 INFO Discrepancy          :: relative discrepancy = 14.265312763203903, tolerance = 1.3
# 2022-07-27 16:19:13,484 INFO CountIterations      :: iteration = 113 / 100000
# 2022-07-27 16:19:13,485 INFO Discrepancy          :: relative discrepancy = 14.263834324059125, tolerance = 1.3
# 2022-07-27 16:19:13,514 INFO CountIterations      :: iteration = 114 / 100000
# 2022-07-27 16:19:13,515 INFO Discrepancy          :: relative discrepancy = 14.262385235038126, tolerance = 1.3
# 2022-07-27 16:19:13,542 INFO CountIterations      :: iteration = 115 / 100000
# 2022-07-27 16:19:13,543 INFO Discrepancy          :: relative discrepancy = 14.260961569985088, tolerance = 1.3
# 2022-07-27 16:19:13,571 INFO CountIterations      :: iteration = 116 / 100000
# 2022-07-27 16:19:13,573 INFO Discrepancy          :: relative discrepancy = 14.259580019932079, tolerance = 1.3
# 2022-07-27 16:19:13,600 INFO CountIterations      :: iteration = 117 / 100000
# 2022-07-27 16:19:13,601 INFO Discrepancy          :: relative discrepancy = 14.258234849529813, tolerance = 1.3
# 2022-07-27 16:19:13,627 INFO CountIterations      :: iteration = 118 / 100000
# 2022-07-27 16:19:13,629 INFO Discrepancy          :: relative discrepancy = 14.256916376384632, tolerance = 1.3
# 2022-07-27 16:19:13,657 INFO CountIterations      :: iteration = 119 / 100000
# 2022-07-27 16:19:13,658 INFO Discrepancy          :: relative discrepancy = 14.255636101770358, tolerance = 1.3
# 2022-07-27 16:19:13,690 INFO CountIterations      :: iteration = 120 / 100000
# 2022-07-27 16:19:13,691 INFO Discrepancy          :: relative discrepancy = 14.254364914058238, tolerance = 1.3
# 2022-07-27 16:19:13,722 INFO CountIterations      :: iteration = 121 / 100000
# 2022-07-27 16:19:13,723 INFO Discrepancy          :: relative discrepancy = 14.253125154106774, tolerance = 1.3
# 2022-07-27 16:19:13,753 INFO CountIterations      :: iteration = 122 / 100000
# 2022-07-27 16:19:13,754 INFO Discrepancy          :: relative discrepancy = 14.251910727704187, tolerance = 1.3
# 2022-07-27 16:19:13,785 INFO CountIterations      :: iteration = 123 / 100000
# 2022-07-27 16:19:13,786 INFO Discrepancy          :: relative discrepancy = 14.25075195901627, tolerance = 1.3
# 2022-07-27 16:19:13,814 INFO CountIterations      :: iteration = 124 / 100000
# 2022-07-27 16:19:13,814 INFO Discrepancy          :: relative discrepancy = 14.24961330621708, tolerance = 1.3
# 2022-07-27 16:19:13,844 INFO CountIterations      :: iteration = 125 / 100000
# 2022-07-27 16:19:13,845 INFO Discrepancy          :: relative discrepancy = 14.248484710381778, tolerance = 1.3
# 2022-07-27 16:19:13,873 INFO CountIterations      :: iteration = 126 / 100000
# 2022-07-27 16:19:13,874 INFO Discrepancy          :: relative discrepancy = 14.247351015846471, tolerance = 1.3
# 2022-07-27 16:19:13,905 INFO CountIterations      :: iteration = 127 / 100000
# 2022-07-27 16:19:13,906 INFO Discrepancy          :: relative discrepancy = 14.246256813387268, tolerance = 1.3
# 2022-07-27 16:19:13,934 INFO CountIterations      :: iteration = 128 / 100000
# 2022-07-27 16:19:13,935 INFO Discrepancy          :: relative discrepancy = 14.245167746031592, tolerance = 1.3
# 2022-07-27 16:19:13,963 INFO CountIterations      :: iteration = 129 / 100000
# 2022-07-27 16:19:13,964 INFO Discrepancy          :: relative discrepancy = 14.2441126897533, tolerance = 1.3
# 2022-07-27 16:19:13,992 INFO CountIterations      :: iteration = 130 / 100000
# 2022-07-27 16:19:13,993 INFO Discrepancy          :: relative discrepancy = 14.243051144051915, tolerance = 1.3
# 2022-07-27 16:19:14,022 INFO CountIterations      :: iteration = 131 / 100000
# 2022-07-27 16:19:14,023 INFO Discrepancy          :: relative discrepancy = 14.24202475109607, tolerance = 1.3
# 2022-07-27 16:19:14,054 INFO CountIterations      :: iteration = 132 / 100000
# 2022-07-27 16:19:14,055 INFO Discrepancy          :: relative discrepancy = 14.24102609561332, tolerance = 1.3
# 2022-07-27 16:19:14,083 INFO CountIterations      :: iteration = 133 / 100000
# 2022-07-27 16:19:14,084 INFO Discrepancy          :: relative discrepancy = 14.240066429196396, tolerance = 1.3
# 2022-07-27 16:19:14,111 INFO CountIterations      :: iteration = 134 / 100000
# 2022-07-27 16:19:14,113 INFO Discrepancy          :: relative discrepancy = 14.239130023680858, tolerance = 1.3
# 2022-07-27 16:19:14,143 INFO CountIterations      :: iteration = 135 / 100000
# 2022-07-27 16:19:14,144 INFO Discrepancy          :: relative discrepancy = 14.238217651122099, tolerance = 1.3
# 2022-07-27 16:19:14,172 INFO CountIterations      :: iteration = 136 / 100000
# 2022-07-27 16:19:14,173 INFO Discrepancy          :: relative discrepancy = 14.237324957683493, tolerance = 1.3
# 2022-07-27 16:19:14,202 INFO CountIterations      :: iteration = 137 / 100000
# 2022-07-27 16:19:14,203 INFO Discrepancy          :: relative discrepancy = 14.23643480400799, tolerance = 1.3
# 2022-07-27 16:19:14,229 INFO CountIterations      :: iteration = 138 / 100000
# 2022-07-27 16:19:14,231 INFO Discrepancy          :: relative discrepancy = 14.235560714146168, tolerance = 1.3
# 2022-07-27 16:19:14,265 INFO CountIterations      :: iteration = 139 / 100000
# 2022-07-27 16:19:14,266 INFO Discrepancy          :: relative discrepancy = 14.234685407895615, tolerance = 1.3
# 2022-07-27 16:19:14,298 INFO CountIterations      :: iteration = 140 / 100000
# 2022-07-27 16:19:14,299 INFO Discrepancy          :: relative discrepancy = 14.233846063036266, tolerance = 1.3
# 2022-07-27 16:19:14,331 INFO CountIterations      :: iteration = 141 / 100000
# 2022-07-27 16:19:14,332 INFO Discrepancy          :: relative discrepancy = 14.23301767316932, tolerance = 1.3
# 2022-07-27 16:19:14,367 INFO CountIterations      :: iteration = 142 / 100000
# 2022-07-27 16:19:14,367 INFO Discrepancy          :: relative discrepancy = 14.232204095134389, tolerance = 1.3
# 2022-07-27 16:19:14,403 INFO CountIterations      :: iteration = 143 / 100000
# 2022-07-27 16:19:14,404 INFO Discrepancy          :: relative discrepancy = 14.231389975297224, tolerance = 1.3
# 2022-07-27 16:19:14,440 INFO CountIterations      :: iteration = 144 / 100000
# 2022-07-27 16:19:14,441 INFO Discrepancy          :: relative discrepancy = 14.230583420721512, tolerance = 1.3
# 2022-07-27 16:19:14,477 INFO CountIterations      :: iteration = 145 / 100000
# 2022-07-27 16:19:14,479 INFO Discrepancy          :: relative discrepancy = 14.229804415948111, tolerance = 1.3
# 2022-07-27 16:19:14,517 INFO CountIterations      :: iteration = 146 / 100000
# 2022-07-27 16:19:14,518 INFO Discrepancy          :: relative discrepancy = 14.22902814134056, tolerance = 1.3
# 2022-07-27 16:19:14,553 INFO CountIterations      :: iteration = 147 / 100000
# 2022-07-27 16:19:14,554 INFO Discrepancy          :: relative discrepancy = 14.228280823388367, tolerance = 1.3
# 2022-07-27 16:19:14,589 INFO CountIterations      :: iteration = 148 / 100000
# 2022-07-27 16:19:14,590 INFO Discrepancy          :: relative discrepancy = 14.227539864928456, tolerance = 1.3
# 2022-07-27 16:19:14,626 INFO CountIterations      :: iteration = 149 / 100000
# 2022-07-27 16:19:14,626 INFO Discrepancy          :: relative discrepancy = 14.226817645916489, tolerance = 1.3
# 2022-07-27 16:19:14,663 INFO CountIterations      :: iteration = 150 / 100000
# 2022-07-27 16:19:14,665 INFO Discrepancy          :: relative discrepancy = 14.226125047994346, tolerance = 1.3
# 2022-07-27 16:19:14,705 INFO CountIterations      :: iteration = 151 / 100000
# 2022-07-27 16:19:14,706 INFO Discrepancy          :: relative discrepancy = 14.225452435233748, tolerance = 1.3
# 2022-07-27 16:19:14,740 INFO CountIterations      :: iteration = 152 / 100000
# 2022-07-27 16:19:14,740 INFO Discrepancy          :: relative discrepancy = 14.224794457325352, tolerance = 1.3
# 2022-07-27 16:19:14,776 INFO CountIterations      :: iteration = 153 / 100000
# 2022-07-27 16:19:14,777 INFO Discrepancy          :: relative discrepancy = 14.224155722114883, tolerance = 1.3
# 2022-07-27 16:19:14,811 INFO CountIterations      :: iteration = 154 / 100000
# 2022-07-27 16:19:14,812 INFO Discrepancy          :: relative discrepancy = 14.223521275151711, tolerance = 1.3
# 2022-07-27 16:19:14,847 INFO CountIterations      :: iteration = 155 / 100000
# 2022-07-27 16:19:14,848 INFO Discrepancy          :: relative discrepancy = 14.222893683026543, tolerance = 1.3
# 2022-07-27 16:19:14,881 INFO CountIterations      :: iteration = 156 / 100000
# 2022-07-27 16:19:14,882 INFO Discrepancy          :: relative discrepancy = 14.222282116940757, tolerance = 1.3
# 2022-07-27 16:19:14,917 INFO CountIterations      :: iteration = 157 / 100000
# 2022-07-27 16:19:14,918 INFO Discrepancy          :: relative discrepancy = 14.22166293204718, tolerance = 1.3
# 2022-07-27 16:19:14,951 INFO CountIterations      :: iteration = 158 / 100000
# 2022-07-27 16:19:14,952 INFO Discrepancy          :: relative discrepancy = 14.221084863320625, tolerance = 1.3
# 2022-07-27 16:19:14,987 INFO CountIterations      :: iteration = 159 / 100000
# 2022-07-27 16:19:14,987 INFO Discrepancy          :: relative discrepancy = 14.220530674800413, tolerance = 1.3
# 2022-07-27 16:19:15,021 INFO CountIterations      :: iteration = 160 / 100000
# 2022-07-27 16:19:15,022 INFO Discrepancy          :: relative discrepancy = 14.219979165417422, tolerance = 1.3
# 2022-07-27 16:19:15,056 INFO CountIterations      :: iteration = 161 / 100000
# 2022-07-27 16:19:15,057 INFO Discrepancy          :: relative discrepancy = 14.219413059136556, tolerance = 1.3
# 2022-07-27 16:19:15,088 INFO CountIterations      :: iteration = 162 / 100000
# 2022-07-27 16:19:15,089 INFO Discrepancy          :: relative discrepancy = 14.218857781105223, tolerance = 1.3
# 2022-07-27 16:19:15,120 INFO CountIterations      :: iteration = 163 / 100000
# 2022-07-27 16:19:15,121 INFO Discrepancy          :: relative discrepancy = 14.218301328142365, tolerance = 1.3
# 2022-07-27 16:19:15,153 INFO CountIterations      :: iteration = 164 / 100000
# 2022-07-27 16:19:15,153 INFO Discrepancy          :: relative discrepancy = 14.217744692953973, tolerance = 1.3
# 2022-07-27 16:19:15,185 INFO CountIterations      :: iteration = 165 / 100000
# 2022-07-27 16:19:15,186 INFO Discrepancy          :: relative discrepancy = 14.217165547789387, tolerance = 1.3
# 2022-07-27 16:19:15,217 INFO CountIterations      :: iteration = 166 / 100000
# 2022-07-27 16:19:15,218 INFO Discrepancy          :: relative discrepancy = 14.216598961476734, tolerance = 1.3
# 2022-07-27 16:19:15,247 INFO CountIterations      :: iteration = 167 / 100000
# 2022-07-27 16:19:15,249 INFO Discrepancy          :: relative discrepancy = 14.216037422629023, tolerance = 1.3
# 2022-07-27 16:19:15,279 INFO CountIterations      :: iteration = 168 / 100000
# 2022-07-27 16:19:15,280 INFO Discrepancy          :: relative discrepancy = 14.215493398250358, tolerance = 1.3
# 2022-07-27 16:19:15,308 INFO CountIterations      :: iteration = 169 / 100000
# 2022-07-27 16:19:15,308 INFO Discrepancy          :: relative discrepancy = 14.214966884149007, tolerance = 1.3
# 2022-07-27 16:19:15,338 INFO CountIterations      :: iteration = 170 / 100000
# 2022-07-27 16:19:15,339 INFO Discrepancy          :: relative discrepancy = 14.214466504564442, tolerance = 1.3
# 2022-07-27 16:19:15,370 INFO CountIterations      :: iteration = 171 / 100000
# 2022-07-27 16:19:15,371 INFO Discrepancy          :: relative discrepancy = 14.213963260236115, tolerance = 1.3
# 2022-07-27 16:19:15,401 INFO CountIterations      :: iteration = 172 / 100000
# 2022-07-27 16:19:15,401 INFO Discrepancy          :: relative discrepancy = 14.213483184755402, tolerance = 1.3
# 2022-07-27 16:19:15,431 INFO CountIterations      :: iteration = 173 / 100000
# 2022-07-27 16:19:15,433 INFO Discrepancy          :: relative discrepancy = 14.213003158960458, tolerance = 1.3
# 2022-07-27 16:19:15,465 INFO CountIterations      :: iteration = 174 / 100000
# 2022-07-27 16:19:15,466 INFO Discrepancy          :: relative discrepancy = 14.21252778175382, tolerance = 1.3
# 2022-07-27 16:19:15,492 INFO CountIterations      :: iteration = 175 / 100000
# 2022-07-27 16:19:15,493 INFO Discrepancy          :: relative discrepancy = 14.21206842196744, tolerance = 1.3
# 2022-07-27 16:19:15,521 INFO CountIterations      :: iteration = 176 / 100000
# 2022-07-27 16:19:15,523 INFO Discrepancy          :: relative discrepancy = 14.211629631463754, tolerance = 1.3
# 2022-07-27 16:19:15,552 INFO CountIterations      :: iteration = 177 / 100000
# 2022-07-27 16:19:15,553 INFO Discrepancy          :: relative discrepancy = 14.211204290088615, tolerance = 1.3
# 2022-07-27 16:19:15,583 INFO CountIterations      :: iteration = 178 / 100000
# 2022-07-27 16:19:15,584 INFO Discrepancy          :: relative discrepancy = 14.210764580797907, tolerance = 1.3
# 2022-07-27 16:19:15,614 INFO CountIterations      :: iteration = 179 / 100000
# 2022-07-27 16:19:15,614 INFO Discrepancy          :: relative discrepancy = 14.210342028814987, tolerance = 1.3
# 2022-07-27 16:19:15,643 INFO CountIterations      :: iteration = 180 / 100000
# 2022-07-27 16:19:15,643 INFO Discrepancy          :: relative discrepancy = 14.209913850212937, tolerance = 1.3
# 2022-07-27 16:19:15,671 INFO CountIterations      :: iteration = 181 / 100000
# 2022-07-27 16:19:15,672 INFO Discrepancy          :: relative discrepancy = 14.209491110225363, tolerance = 1.3
# 2022-07-27 16:19:15,701 INFO CountIterations      :: iteration = 182 / 100000
# 2022-07-27 16:19:15,702 INFO Discrepancy          :: relative discrepancy = 14.209078644176477, tolerance = 1.3
# 2022-07-27 16:19:15,732 INFO CountIterations      :: iteration = 183 / 100000
# 2022-07-27 16:19:15,733 INFO Discrepancy          :: relative discrepancy = 14.208655917352562, tolerance = 1.3
# 2022-07-27 16:19:15,760 INFO CountIterations      :: iteration = 184 / 100000
# 2022-07-27 16:19:15,762 INFO Discrepancy          :: relative discrepancy = 14.208232471794275, tolerance = 1.3
# 2022-07-27 16:19:15,789 INFO CountIterations      :: iteration = 185 / 100000
# 2022-07-27 16:19:15,790 INFO Discrepancy          :: relative discrepancy = 14.207810768471084, tolerance = 1.3
# 2022-07-27 16:19:15,819 INFO CountIterations      :: iteration = 186 / 100000
# 2022-07-27 16:19:15,819 INFO Discrepancy          :: relative discrepancy = 14.207390634939179, tolerance = 1.3
# 2022-07-27 16:19:15,857 INFO CountIterations      :: iteration = 187 / 100000
# 2022-07-27 16:19:15,858 INFO Discrepancy          :: relative discrepancy = 14.206974770549035, tolerance = 1.3
# 2022-07-27 16:19:15,886 INFO CountIterations      :: iteration = 188 / 100000
# 2022-07-27 16:19:15,888 INFO Discrepancy          :: relative discrepancy = 14.20659284625528, tolerance = 1.3
# 2022-07-27 16:19:15,918 INFO CountIterations      :: iteration = 189 / 100000
# 2022-07-27 16:19:15,919 INFO Discrepancy          :: relative discrepancy = 14.206228037764882, tolerance = 1.3
# 2022-07-27 16:19:15,951 INFO CountIterations      :: iteration = 190 / 100000
# 2022-07-27 16:19:15,952 INFO Discrepancy          :: relative discrepancy = 14.205884064154024, tolerance = 1.3
# 2022-07-27 16:19:15,983 INFO CountIterations      :: iteration = 191 / 100000
# 2022-07-27 16:19:15,984 INFO Discrepancy          :: relative discrepancy = 14.20553346727413, tolerance = 1.3
# 2022-07-27 16:19:16,018 INFO CountIterations      :: iteration = 192 / 100000
# 2022-07-27 16:19:16,020 INFO Discrepancy          :: relative discrepancy = 14.205180630116889, tolerance = 1.3
# 2022-07-27 16:19:16,049 INFO CountIterations      :: iteration = 193 / 100000
# 2022-07-27 16:19:16,050 INFO Discrepancy          :: relative discrepancy = 14.204826687559157, tolerance = 1.3
# 2022-07-27 16:19:16,081 INFO CountIterations      :: iteration = 194 / 100000
# 2022-07-27 16:19:16,082 INFO Discrepancy          :: relative discrepancy = 14.204455451938742, tolerance = 1.3
# 2022-07-27 16:19:16,111 INFO CountIterations      :: iteration = 195 / 100000
# 2022-07-27 16:19:16,112 INFO Discrepancy          :: relative discrepancy = 14.204076252045756, tolerance = 1.3
# 2022-07-27 16:19:16,147 INFO CountIterations      :: iteration = 196 / 100000
# 2022-07-27 16:19:16,148 INFO Discrepancy          :: relative discrepancy = 14.203699517785633, tolerance = 1.3
# 2022-07-27 16:19:16,177 INFO CountIterations      :: iteration = 197 / 100000
# 2022-07-27 16:19:16,178 INFO Discrepancy          :: relative discrepancy = 14.20331955986092, tolerance = 1.3
# 2022-07-27 16:19:16,205 INFO CountIterations      :: iteration = 198 / 100000
# 2022-07-27 16:19:16,206 INFO Discrepancy          :: relative discrepancy = 14.202958421532003, tolerance = 1.3
# 2022-07-27 16:19:16,239 INFO CountIterations      :: iteration = 199 / 100000
# 2022-07-27 16:19:16,240 INFO Discrepancy          :: relative discrepancy = 14.20259157385531, tolerance = 1.3
# 2022-07-27 16:19:16,275 INFO CountIterations      :: iteration = 200 / 100000
# 2022-07-27 16:19:16,276 INFO Discrepancy          :: relative discrepancy = 14.202209445095367, tolerance = 1.3
# 2022-07-27 16:19:16,306 INFO CountIterations      :: iteration = 201 / 100000
# 2022-07-27 16:19:16,307 INFO Discrepancy          :: relative discrepancy = 14.201838504611347, tolerance = 1.3
# 2022-07-27 16:19:16,340 INFO CountIterations      :: iteration = 202 / 100000
# 2022-07-27 16:19:16,341 INFO Discrepancy          :: relative discrepancy = 14.201482903691549, tolerance = 1.3
# 2022-07-27 16:19:16,372 INFO CountIterations      :: iteration = 203 / 100000
# 2022-07-27 16:19:16,373 INFO Discrepancy          :: relative discrepancy = 14.20113170682472, tolerance = 1.3
# 2022-07-27 16:19:16,405 INFO CountIterations      :: iteration = 204 / 100000
# 2022-07-27 16:19:16,406 INFO Discrepancy          :: relative discrepancy = 14.200787819189022, tolerance = 1.3
# 2022-07-27 16:19:16,438 INFO CountIterations      :: iteration = 205 / 100000
# 2022-07-27 16:19:16,439 INFO Discrepancy          :: relative discrepancy = 14.200454222060984, tolerance = 1.3
# 2022-07-27 16:19:16,472 INFO CountIterations      :: iteration = 206 / 100000
# 2022-07-27 16:19:16,473 INFO Discrepancy          :: relative discrepancy = 14.200142650513294, tolerance = 1.3
# 2022-07-27 16:19:16,504 INFO CountIterations      :: iteration = 207 / 100000
# 2022-07-27 16:19:16,505 INFO Discrepancy          :: relative discrepancy = 14.199851981082642, tolerance = 1.3
# 2022-07-27 16:19:16,536 INFO CountIterations      :: iteration = 208 / 100000
# 2022-07-27 16:19:16,537 INFO Discrepancy          :: relative discrepancy = 14.199574519854478, tolerance = 1.3
# 2022-07-27 16:19:16,566 INFO CountIterations      :: iteration = 209 / 100000
# 2022-07-27 16:19:16,567 INFO Discrepancy          :: relative discrepancy = 14.199301349082383, tolerance = 1.3
# 2022-07-27 16:19:16,595 INFO CountIterations      :: iteration = 210 / 100000
# 2022-07-27 16:19:16,595 INFO Discrepancy          :: relative discrepancy = 14.199027222152464, tolerance = 1.3
# 2022-07-27 16:19:16,625 INFO CountIterations      :: iteration = 211 / 100000
# 2022-07-27 16:19:16,625 INFO Discrepancy          :: relative discrepancy = 14.19873690699055, tolerance = 1.3
# 2022-07-27 16:19:16,656 INFO CountIterations      :: iteration = 212 / 100000
# 2022-07-27 16:19:16,656 INFO Discrepancy          :: relative discrepancy = 14.198461152427765, tolerance = 1.3
# 2022-07-27 16:19:16,687 INFO CountIterations      :: iteration = 213 / 100000
# 2022-07-27 16:19:16,688 INFO Discrepancy          :: relative discrepancy = 14.198197684721926, tolerance = 1.3
# 2022-07-27 16:19:16,723 INFO CountIterations      :: iteration = 214 / 100000
# 2022-07-27 16:19:16,723 INFO Discrepancy          :: relative discrepancy = 14.197914072916717, tolerance = 1.3
# 2022-07-27 16:19:16,757 INFO CountIterations      :: iteration = 215 / 100000
# 2022-07-27 16:19:16,758 INFO Discrepancy          :: relative discrepancy = 14.197640024428734, tolerance = 1.3
# 2022-07-27 16:19:16,794 INFO CountIterations      :: iteration = 216 / 100000
# 2022-07-27 16:19:16,795 INFO Discrepancy          :: relative discrepancy = 14.197375911737746, tolerance = 1.3
# 2022-07-27 16:19:16,832 INFO CountIterations      :: iteration = 217 / 100000
# 2022-07-27 16:19:16,833 INFO Discrepancy          :: relative discrepancy = 14.197123068561618, tolerance = 1.3
# 2022-07-27 16:19:16,867 INFO CountIterations      :: iteration = 218 / 100000
# 2022-07-27 16:19:16,868 INFO Discrepancy          :: relative discrepancy = 14.196859070083557, tolerance = 1.3
# 2022-07-27 16:19:16,903 INFO CountIterations      :: iteration = 219 / 100000
# 2022-07-27 16:19:16,904 INFO Discrepancy          :: relative discrepancy = 14.196604196933949, tolerance = 1.3
# 2022-07-27 16:19:16,938 INFO CountIterations      :: iteration = 220 / 100000
# 2022-07-27 16:19:16,940 INFO Discrepancy          :: relative discrepancy = 14.196364116111303, tolerance = 1.3
# 2022-07-27 16:19:16,972 INFO CountIterations      :: iteration = 221 / 100000
# 2022-07-27 16:19:16,973 INFO Discrepancy          :: relative discrepancy = 14.196119538749775, tolerance = 1.3
# 2022-07-27 16:19:17,006 INFO CountIterations      :: iteration = 222 / 100000
# 2022-07-27 16:19:17,007 INFO Discrepancy          :: relative discrepancy = 14.195884733901291, tolerance = 1.3
# 2022-07-27 16:19:17,037 INFO CountIterations      :: iteration = 223 / 100000
# 2022-07-27 16:19:17,038 INFO Discrepancy          :: relative discrepancy = 14.195660964872557, tolerance = 1.3
# 2022-07-27 16:19:17,068 INFO CountIterations      :: iteration = 224 / 100000
# 2022-07-27 16:19:17,069 INFO Discrepancy          :: relative discrepancy = 14.19543069629078, tolerance = 1.3
# 2022-07-27 16:19:17,104 INFO CountIterations      :: iteration = 225 / 100000
# 2022-07-27 16:19:17,105 INFO Discrepancy          :: relative discrepancy = 14.195194251837318, tolerance = 1.3
# 2022-07-27 16:19:17,137 INFO CountIterations      :: iteration = 226 / 100000
# 2022-07-27 16:19:17,138 INFO Discrepancy          :: relative discrepancy = 14.194969809132703, tolerance = 1.3
# 2022-07-27 16:19:17,168 INFO CountIterations      :: iteration = 227 / 100000
# 2022-07-27 16:19:17,169 INFO Discrepancy          :: relative discrepancy = 14.19475252475203, tolerance = 1.3
# 2022-07-27 16:19:17,201 INFO CountIterations      :: iteration = 228 / 100000
# 2022-07-27 16:19:17,202 INFO Discrepancy          :: relative discrepancy = 14.194544318742748, tolerance = 1.3
# 2022-07-27 16:19:17,231 INFO CountIterations      :: iteration = 229 / 100000
# 2022-07-27 16:19:17,232 INFO Discrepancy          :: relative discrepancy = 14.194340355375035, tolerance = 1.3
# 2022-07-27 16:19:17,261 INFO CountIterations      :: iteration = 230 / 100000
# 2022-07-27 16:19:17,263 INFO Discrepancy          :: relative discrepancy = 14.194132838317492, tolerance = 1.3
# 2022-07-27 16:19:17,298 INFO CountIterations      :: iteration = 231 / 100000
# 2022-07-27 16:19:17,299 INFO Discrepancy          :: relative discrepancy = 14.1939271617234, tolerance = 1.3
# 2022-07-27 16:19:17,331 INFO CountIterations      :: iteration = 232 / 100000
# 2022-07-27 16:19:17,331 INFO Discrepancy          :: relative discrepancy = 14.193705198181402, tolerance = 1.3
# 2022-07-27 16:19:17,361 INFO CountIterations      :: iteration = 233 / 100000
# 2022-07-27 16:19:17,362 INFO Discrepancy          :: relative discrepancy = 14.193486215563423, tolerance = 1.3
# 2022-07-27 16:19:17,391 INFO CountIterations      :: iteration = 234 / 100000
# 2022-07-27 16:19:17,392 INFO Discrepancy          :: relative discrepancy = 14.193269128411961, tolerance = 1.3
# 2022-07-27 16:19:17,424 INFO CountIterations      :: iteration = 235 / 100000
# 2022-07-27 16:19:17,425 INFO Discrepancy          :: relative discrepancy = 14.193047871489112, tolerance = 1.3
# 2022-07-27 16:19:17,458 INFO CountIterations      :: iteration = 236 / 100000
# 2022-07-27 16:19:17,459 INFO Discrepancy          :: relative discrepancy = 14.192848092902263, tolerance = 1.3
# 2022-07-27 16:19:17,493 INFO CountIterations      :: iteration = 237 / 100000
# 2022-07-27 16:19:17,495 INFO Discrepancy          :: relative discrepancy = 14.192668483499931, tolerance = 1.3
# 2022-07-27 16:19:17,524 INFO CountIterations      :: iteration = 238 / 100000
# 2022-07-27 16:19:17,526 INFO Discrepancy          :: relative discrepancy = 14.19248285384166, tolerance = 1.3
# 2022-07-27 16:19:17,557 INFO CountIterations      :: iteration = 239 / 100000
# 2022-07-27 16:19:17,558 INFO Discrepancy          :: relative discrepancy = 14.19230086367876, tolerance = 1.3
# 2022-07-27 16:19:17,590 INFO CountIterations      :: iteration = 240 / 100000
# 2022-07-27 16:19:17,590 INFO Discrepancy          :: relative discrepancy = 14.192114243524445, tolerance = 1.3
# 2022-07-27 16:19:17,620 INFO CountIterations      :: iteration = 241 / 100000
# 2022-07-27 16:19:17,620 INFO Discrepancy          :: relative discrepancy = 14.191929400816546, tolerance = 1.3
# 2022-07-27 16:19:17,653 INFO CountIterations      :: iteration = 242 / 100000
# 2022-07-27 16:19:17,654 INFO Discrepancy          :: relative discrepancy = 14.191740022553953, tolerance = 1.3
# 2022-07-27 16:19:17,687 INFO CountIterations      :: iteration = 243 / 100000
# 2022-07-27 16:19:17,687 INFO Discrepancy          :: relative discrepancy = 14.191537478196722, tolerance = 1.3
# 2022-07-27 16:19:17,717 INFO CountIterations      :: iteration = 244 / 100000
# 2022-07-27 16:19:17,718 INFO Discrepancy          :: relative discrepancy = 14.191334120196624, tolerance = 1.3
# 2022-07-27 16:19:17,747 INFO CountIterations      :: iteration = 245 / 100000
# 2022-07-27 16:19:17,748 INFO Discrepancy          :: relative discrepancy = 14.191146438321244, tolerance = 1.3
# 2022-07-27 16:19:17,779 INFO CountIterations      :: iteration = 246 / 100000
# 2022-07-27 16:19:17,780 INFO Discrepancy          :: relative discrepancy = 14.19095902480425, tolerance = 1.3
# 2022-07-27 16:19:17,807 INFO CountIterations      :: iteration = 247 / 100000
# 2022-07-27 16:19:17,808 INFO Discrepancy          :: relative discrepancy = 14.19078032687529, tolerance = 1.3
# 2022-07-27 16:19:17,838 INFO CountIterations      :: iteration = 248 / 100000
# 2022-07-27 16:19:17,839 INFO Discrepancy          :: relative discrepancy = 14.190583764426057, tolerance = 1.3
# 2022-07-27 16:19:17,868 INFO CountIterations      :: iteration = 249 / 100000
# 2022-07-27 16:19:17,869 INFO Discrepancy          :: relative discrepancy = 14.190384968722537, tolerance = 1.3
# 2022-07-27 16:19:17,899 INFO CountIterations      :: iteration = 250 / 100000
# 2022-07-27 16:19:17,900 INFO Discrepancy          :: relative discrepancy = 14.190201228986636, tolerance = 1.3
# 2022-07-27 16:19:17,929 INFO CountIterations      :: iteration = 251 / 100000
# 2022-07-27 16:19:17,929 INFO Discrepancy          :: relative discrepancy = 14.190025636605029, tolerance = 1.3
# 2022-07-27 16:19:17,957 INFO CountIterations      :: iteration = 252 / 100000
# 2022-07-27 16:19:17,959 INFO Discrepancy          :: relative discrepancy = 14.189852348271433, tolerance = 1.3
# 2022-07-27 16:19:17,991 INFO CountIterations      :: iteration = 253 / 100000
# 2022-07-27 16:19:17,992 INFO Discrepancy          :: relative discrepancy = 14.189684056172934, tolerance = 1.3
# 2022-07-27 16:19:18,019 INFO CountIterations      :: iteration = 254 / 100000
# ...
# 2022-07-27 16:21:02,204 INFO Discrepancy          :: relative discrepancy = 1.5106007522648266, tolerance = 1.3
# 2022-07-27 16:21:02,259 INFO CountIterations      :: iteration = 3075 / 100000
# 2022-07-27 16:21:02,261 INFO Discrepancy          :: relative discrepancy = 1.5070129425096994, tolerance = 1.3
# 2022-07-27 16:21:02,302 INFO CountIterations      :: iteration = 3076 / 100000
# 2022-07-27 16:21:02,303 INFO Discrepancy          :: relative discrepancy = 1.5034975158168125, tolerance = 1.3
# 2022-07-27 16:21:02,355 INFO CountIterations      :: iteration = 3077 / 100000
# 2022-07-27 16:21:02,356 INFO Discrepancy          :: relative discrepancy = 1.500139378530247, tolerance = 1.3
# 2022-07-27 16:21:02,404 INFO CountIterations      :: iteration = 3078 / 100000
# 2022-07-27 16:21:02,406 INFO Discrepancy          :: relative discrepancy = 1.4971259768694598, tolerance = 1.3
# 2022-07-27 16:21:02,439 INFO CountIterations      :: iteration = 3079 / 100000
# 2022-07-27 16:21:02,440 INFO Discrepancy          :: relative discrepancy = 1.4940246012739853, tolerance = 1.3
# 2022-07-27 16:21:02,487 INFO CountIterations      :: iteration = 3080 / 100000
# 2022-07-27 16:21:02,488 INFO Discrepancy          :: relative discrepancy = 1.4910526722698838, tolerance = 1.3
# 2022-07-27 16:21:02,537 INFO CountIterations      :: iteration = 3081 / 100000
# 2022-07-27 16:21:02,538 INFO Discrepancy          :: relative discrepancy = 1.487874659347437, tolerance = 1.3
# 2022-07-27 16:21:02,582 INFO CountIterations      :: iteration = 3082 / 100000
# 2022-07-27 16:21:02,584 INFO Discrepancy          :: relative discrepancy = 1.4848557034681227, tolerance = 1.3
# 2022-07-27 16:21:02,627 INFO CountIterations      :: iteration = 3083 / 100000
# 2022-07-27 16:21:02,629 INFO Discrepancy          :: relative discrepancy = 1.4817262739780361, tolerance = 1.3
# 2022-07-27 16:21:02,681 INFO CountIterations      :: iteration = 3084 / 100000
# 2022-07-27 16:21:02,682 INFO Discrepancy          :: relative discrepancy = 1.478757887029362, tolerance = 1.3
# 2022-07-27 16:21:02,723 INFO CountIterations      :: iteration = 3085 / 100000
# 2022-07-27 16:21:02,725 INFO Discrepancy          :: relative discrepancy = 1.4758028980559414, tolerance = 1.3
# 2022-07-27 16:21:02,790 INFO CountIterations      :: iteration = 3086 / 100000
# 2022-07-27 16:21:02,791 INFO Discrepancy          :: relative discrepancy = 1.4729193447713276, tolerance = 1.3
# 2022-07-27 16:21:02,842 INFO CountIterations      :: iteration = 3087 / 100000
# 2022-07-27 16:21:02,843 INFO Discrepancy          :: relative discrepancy = 1.4700947850567463, tolerance = 1.3
# 2022-07-27 16:21:02,899 INFO CountIterations      :: iteration = 3088 / 100000
# 2022-07-27 16:21:02,900 INFO Discrepancy          :: relative discrepancy = 1.4672778208938997, tolerance = 1.3
# 2022-07-27 16:21:02,976 INFO CountIterations      :: iteration = 3089 / 100000
# 2022-07-27 16:21:02,977 INFO Discrepancy          :: relative discrepancy = 1.4643963808839122, tolerance = 1.3
# 2022-07-27 16:21:03,047 INFO CountIterations      :: iteration = 3090 / 100000
# 2022-07-27 16:21:03,049 INFO Discrepancy          :: relative discrepancy = 1.4613389033687925, tolerance = 1.3
# 2022-07-27 16:21:03,107 INFO CountIterations      :: iteration = 3091 / 100000
# 2022-07-27 16:21:03,108 INFO Discrepancy          :: relative discrepancy = 1.45852122381404, tolerance = 1.3
# 2022-07-27 16:21:03,158 INFO CountIterations      :: iteration = 3092 / 100000
# 2022-07-27 16:21:03,159 INFO Discrepancy          :: relative discrepancy = 1.4555995547253775, tolerance = 1.3
# 2022-07-27 16:21:03,202 INFO CountIterations      :: iteration = 3093 / 100000
# 2022-07-27 16:21:03,203 INFO Discrepancy          :: relative discrepancy = 1.4526011261858813, tolerance = 1.3
# 2022-07-27 16:21:03,247 INFO CountIterations      :: iteration = 3094 / 100000
# 2022-07-27 16:21:03,248 INFO Discrepancy          :: relative discrepancy = 1.4496747220694346, tolerance = 1.3
# 2022-07-27 16:21:03,298 INFO CountIterations      :: iteration = 3095 / 100000
# 2022-07-27 16:21:03,300 INFO Discrepancy          :: relative discrepancy = 1.4469797618739675, tolerance = 1.3
# 2022-07-27 16:21:03,355 INFO CountIterations      :: iteration = 3096 / 100000
# 2022-07-27 16:21:03,356 INFO Discrepancy          :: relative discrepancy = 1.4444556427668154, tolerance = 1.3
# 2022-07-27 16:21:03,406 INFO CountIterations      :: iteration = 3097 / 100000
# 2022-07-27 16:21:03,407 INFO Discrepancy          :: relative discrepancy = 1.4419589340799381, tolerance = 1.3
# 2022-07-27 16:21:03,459 INFO CountIterations      :: iteration = 3098 / 100000
# 2022-07-27 16:21:03,460 INFO Discrepancy          :: relative discrepancy = 1.4393108660875675, tolerance = 1.3
# 2022-07-27 16:21:03,512 INFO CountIterations      :: iteration = 3099 / 100000
# 2022-07-27 16:21:03,514 INFO Discrepancy          :: relative discrepancy = 1.436806254337747, tolerance = 1.3
# 2022-07-27 16:21:03,574 INFO CountIterations      :: iteration = 3100 / 100000
# 2022-07-27 16:21:03,575 INFO Discrepancy          :: relative discrepancy = 1.4340929585812636, tolerance = 1.3
# 2022-07-27 16:21:03,623 INFO CountIterations      :: iteration = 3101 / 100000
# 2022-07-27 16:21:03,625 INFO Discrepancy          :: relative discrepancy = 1.4313336776916055, tolerance = 1.3
# 2022-07-27 16:21:03,670 INFO CountIterations      :: iteration = 3102 / 100000
# 2022-07-27 16:21:03,671 INFO Discrepancy          :: relative discrepancy = 1.4286605393607719, tolerance = 1.3
# 2022-07-27 16:21:03,724 INFO CountIterations      :: iteration = 3103 / 100000
# 2022-07-27 16:21:03,725 INFO Discrepancy          :: relative discrepancy = 1.426233841867464, tolerance = 1.3
# 2022-07-27 16:21:03,786 INFO CountIterations      :: iteration = 3104 / 100000
# 2022-07-27 16:21:03,787 INFO Discrepancy          :: relative discrepancy = 1.4237276206886509, tolerance = 1.3
# 2022-07-27 16:21:03,838 INFO CountIterations      :: iteration = 3105 / 100000
# 2022-07-27 16:21:03,839 INFO Discrepancy          :: relative discrepancy = 1.4213110694674849, tolerance = 1.3
# 2022-07-27 16:21:03,894 INFO CountIterations      :: iteration = 3106 / 100000
# 2022-07-27 16:21:03,895 INFO Discrepancy          :: relative discrepancy = 1.418702415170199, tolerance = 1.3
# 2022-07-27 16:21:03,952 INFO CountIterations      :: iteration = 3107 / 100000
# 2022-07-27 16:21:03,953 INFO Discrepancy          :: relative discrepancy = 1.4161154884815956, tolerance = 1.3
# 2022-07-27 16:21:04,011 INFO CountIterations      :: iteration = 3108 / 100000
# 2022-07-27 16:21:04,012 INFO Discrepancy          :: relative discrepancy = 1.413523096129424, tolerance = 1.3
# 2022-07-27 16:21:04,076 INFO CountIterations      :: iteration = 3109 / 100000
# 2022-07-27 16:21:04,077 INFO Discrepancy          :: relative discrepancy = 1.4107600094256638, tolerance = 1.3
# 2022-07-27 16:21:04,131 INFO CountIterations      :: iteration = 3110 / 100000
# 2022-07-27 16:21:04,132 INFO Discrepancy          :: relative discrepancy = 1.4079021647304948, tolerance = 1.3
# 2022-07-27 16:21:04,185 INFO CountIterations      :: iteration = 3111 / 100000
# 2022-07-27 16:21:04,187 INFO Discrepancy          :: relative discrepancy = 1.4053187725750234, tolerance = 1.3
# 2022-07-27 16:21:04,281 INFO CountIterations      :: iteration = 3112 / 100000
# 2022-07-27 16:21:04,283 INFO Discrepancy          :: relative discrepancy = 1.4028574419851043, tolerance = 1.3
# 2022-07-27 16:21:04,337 INFO CountIterations      :: iteration = 3113 / 100000
# 2022-07-27 16:21:04,338 INFO Discrepancy          :: relative discrepancy = 1.4003403203046325, tolerance = 1.3
# 2022-07-27 16:21:04,391 INFO CountIterations      :: iteration = 3114 / 100000
# 2022-07-27 16:21:04,392 INFO Discrepancy          :: relative discrepancy = 1.3977007783248014, tolerance = 1.3
# 2022-07-27 16:21:04,442 INFO CountIterations      :: iteration = 3115 / 100000
# 2022-07-27 16:21:04,444 INFO Discrepancy          :: relative discrepancy = 1.3950725713483743, tolerance = 1.3
# 2022-07-27 16:21:04,495 INFO CountIterations      :: iteration = 3116 / 100000
# 2022-07-27 16:21:04,496 INFO Discrepancy          :: relative discrepancy = 1.392463049593613, tolerance = 1.3
# 2022-07-27 16:21:04,546 INFO CountIterations      :: iteration = 3117 / 100000
# 2022-07-27 16:21:04,547 INFO Discrepancy          :: relative discrepancy = 1.390095158618753, tolerance = 1.3
# 2022-07-27 16:21:04,594 INFO CountIterations      :: iteration = 3118 / 100000
# 2022-07-27 16:21:04,595 INFO Discrepancy          :: relative discrepancy = 1.3877098120376299, tolerance = 1.3
# 2022-07-27 16:21:04,639 INFO CountIterations      :: iteration = 3119 / 100000
# 2022-07-27 16:21:04,640 INFO Discrepancy          :: relative discrepancy = 1.3852469431942216, tolerance = 1.3
# 2022-07-27 16:21:04,678 INFO CountIterations      :: iteration = 3120 / 100000
# 2022-07-27 16:21:04,679 INFO Discrepancy          :: relative discrepancy = 1.383189199232328, tolerance = 1.3
# 2022-07-27 16:21:04,728 INFO CountIterations      :: iteration = 3121 / 100000
# 2022-07-27 16:21:04,732 INFO Discrepancy          :: relative discrepancy = 1.3807775471811758, tolerance = 1.3
# 2022-07-27 16:21:04,772 INFO CountIterations      :: iteration = 3122 / 100000
# 2022-07-27 16:21:04,773 INFO Discrepancy          :: relative discrepancy = 1.3783383088253423, tolerance = 1.3
# 2022-07-27 16:21:04,811 INFO CountIterations      :: iteration = 3123 / 100000
# 2022-07-27 16:21:04,813 INFO Discrepancy          :: relative discrepancy = 1.3756984196538764, tolerance = 1.3
# 2022-07-27 16:21:04,852 INFO CountIterations      :: iteration = 3124 / 100000
# 2022-07-27 16:21:04,853 INFO Discrepancy          :: relative discrepancy = 1.3728827194585465, tolerance = 1.3
# 2022-07-27 16:21:04,899 INFO CountIterations      :: iteration = 3125 / 100000
# 2022-07-27 16:21:04,900 INFO Discrepancy          :: relative discrepancy = 1.3699163376881849, tolerance = 1.3
# 2022-07-27 16:21:04,949 INFO CountIterations      :: iteration = 3126 / 100000
# 2022-07-27 16:21:04,950 INFO Discrepancy          :: relative discrepancy = 1.3671322661586447, tolerance = 1.3
# 2022-07-27 16:21:04,995 INFO CountIterations      :: iteration = 3127 / 100000
# 2022-07-27 16:21:04,996 INFO Discrepancy          :: relative discrepancy = 1.3644133983931628, tolerance = 1.3
# 2022-07-27 16:21:05,044 INFO CountIterations      :: iteration = 3128 / 100000
# 2022-07-27 16:21:05,045 INFO Discrepancy          :: relative discrepancy = 1.36179175098996, tolerance = 1.3
# 2022-07-27 16:21:05,086 INFO CountIterations      :: iteration = 3129 / 100000
# 2022-07-27 16:21:05,087 INFO Discrepancy          :: relative discrepancy = 1.3591480036341044, tolerance = 1.3
# 2022-07-27 16:21:05,132 INFO CountIterations      :: iteration = 3130 / 100000
# 2022-07-27 16:21:05,133 INFO Discrepancy          :: relative discrepancy = 1.3564912198342851, tolerance = 1.3
# 2022-07-27 16:21:05,179 INFO CountIterations      :: iteration = 3131 / 100000
# 2022-07-27 16:21:05,181 INFO Discrepancy          :: relative discrepancy = 1.3538507001057218, tolerance = 1.3
# 2022-07-27 16:21:05,226 INFO CountIterations      :: iteration = 3132 / 100000
# 2022-07-27 16:21:05,227 INFO Discrepancy          :: relative discrepancy = 1.3512288529648846, tolerance = 1.3
# 2022-07-27 16:21:05,278 INFO CountIterations      :: iteration = 3133 / 100000
# 2022-07-27 16:21:05,279 INFO Discrepancy          :: relative discrepancy = 1.3485734274646615, tolerance = 1.3
# 2022-07-27 16:21:05,326 INFO CountIterations      :: iteration = 3134 / 100000
# 2022-07-27 16:21:05,327 INFO Discrepancy          :: relative discrepancy = 1.3458479008614186, tolerance = 1.3
# 2022-07-27 16:21:05,373 INFO CountIterations      :: iteration = 3135 / 100000
# 2022-07-27 16:21:05,374 INFO Discrepancy          :: relative discrepancy = 1.3433413859940357, tolerance = 1.3
# 2022-07-27 16:21:05,417 INFO CountIterations      :: iteration = 3136 / 100000
# 2022-07-27 16:21:05,418 INFO Discrepancy          :: relative discrepancy = 1.3410293660800283, tolerance = 1.3
# 2022-07-27 16:21:05,467 INFO CountIterations      :: iteration = 3137 / 100000
# 2022-07-27 16:21:05,468 INFO Discrepancy          :: relative discrepancy = 1.3387607048334125, tolerance = 1.3
# 2022-07-27 16:21:05,508 INFO CountIterations      :: iteration = 3138 / 100000
# 2022-07-27 16:21:05,509 INFO Discrepancy          :: relative discrepancy = 1.3365688800728637, tolerance = 1.3
# 2022-07-27 16:21:05,556 INFO CountIterations      :: iteration = 3139 / 100000
# 2022-07-27 16:21:05,557 INFO Discrepancy          :: relative discrepancy = 1.3344916080948244, tolerance = 1.3
# 2022-07-27 16:21:05,597 INFO CountIterations      :: iteration = 3140 / 100000
# 2022-07-27 16:21:05,598 INFO Discrepancy          :: relative discrepancy = 1.332297614286203, tolerance = 1.3
# 2022-07-27 16:21:05,643 INFO CountIterations      :: iteration = 3141 / 100000
# 2022-07-27 16:21:05,644 INFO Discrepancy          :: relative discrepancy = 1.3302019755019139, tolerance = 1.3
# 2022-07-27 16:21:05,703 INFO CountIterations      :: iteration = 3142 / 100000
# 2022-07-27 16:21:05,704 INFO Discrepancy          :: relative discrepancy = 1.3278887498290637, tolerance = 1.3
# 2022-07-27 16:21:05,741 INFO CountIterations      :: iteration = 3143 / 100000
# 2022-07-27 16:21:05,742 INFO Discrepancy          :: relative discrepancy = 1.3255974845770853, tolerance = 1.3
# 2022-07-27 16:21:05,793 INFO CountIterations      :: iteration = 3144 / 100000
# 2022-07-27 16:21:05,794 INFO Discrepancy          :: relative discrepancy = 1.3230950508780723, tolerance = 1.3
# 2022-07-27 16:21:05,845 INFO CountIterations      :: iteration = 3145 / 100000
# 2022-07-27 16:21:05,846 INFO Discrepancy          :: relative discrepancy = 1.3208264558225211, tolerance = 1.3
# 2022-07-27 16:21:05,900 INFO CountIterations      :: iteration = 3146 / 100000
# 2022-07-27 16:21:05,901 INFO Discrepancy          :: relative discrepancy = 1.3185974201064903, tolerance = 1.3
# 2022-07-27 16:21:05,961 INFO CountIterations      :: iteration = 3147 / 100000
# 2022-07-27 16:21:05,962 INFO Discrepancy          :: relative discrepancy = 1.3167086723235575, tolerance = 1.3
# 2022-07-27 16:21:06,018 INFO CountIterations      :: iteration = 3148 / 100000
# 2022-07-27 16:21:06,019 INFO Discrepancy          :: relative discrepancy = 1.3149773785504422, tolerance = 1.3
# 2022-07-27 16:21:06,078 INFO CountIterations      :: iteration = 3149 / 100000
# 2022-07-27 16:21:06,079 INFO Discrepancy          :: relative discrepancy = 1.313446698275116, tolerance = 1.3
# 2022-07-27 16:21:06,140 INFO CountIterations      :: iteration = 3150 / 100000
# 2022-07-27 16:21:06,141 INFO Discrepancy          :: relative discrepancy = 1.3116170877561437, tolerance = 1.3
# 2022-07-27 16:21:06,203 INFO CountIterations      :: iteration = 3151 / 100000
# 2022-07-27 16:21:06,204 INFO Discrepancy          :: relative discrepancy = 1.3098275486702202, tolerance = 1.3
# 2022-07-27 16:21:06,262 INFO CountIterations      :: iteration = 3152 / 100000
# 2022-07-27 16:21:06,264 INFO Discrepancy          :: relative discrepancy = 1.3078323520262878, tolerance = 1.3
# 2022-07-27 16:21:06,319 INFO CountIterations      :: iteration = 3153 / 100000
# 2022-07-27 16:21:06,320 INFO Discrepancy          :: relative discrepancy = 1.3058383002515093, tolerance = 1.3
# 2022-07-27 16:21:06,369 INFO CountIterations      :: iteration = 3154 / 100000
# 2022-07-27 16:21:06,370 INFO Discrepancy          :: relative discrepancy = 1.3035351347060895, tolerance = 1.3
# 2022-07-27 16:21:06,422 INFO CountIterations      :: iteration = 3155 / 100000
# 2022-07-27 16:21:06,423 INFO Discrepancy          :: relative discrepancy = 1.3015562652904151, tolerance = 1.3
# 2022-07-27 16:21:06,477 INFO CountIterations      :: iteration = 3156 / 100000
# 2022-07-27 16:21:06,479 INFO Discrepancy          :: relative discrepancy = 1.2994939650719446, tolerance = 1.3
# 2022-07-27 16:21:06,481 INFO CombineRules         :: Rule Discrepancy(noiselevel=0.07914343492618821, tau=1.3) triggered.
# 2022-07-27 16:21:06,482 INFO FISTA                :: Stopping rule triggered.

# %% [markdown]
# The reconstructions shows the piece-wise constant and piece-wise smooth feature expected for TV-regularization.
#
# Regpy and imagingbase provide a wide range of possible solvers: IRGNM_CG, Landweber, FISTA, ADMM, Douglas-Rashford, Forward-Backward Splitting, Gradient Descent, Arrow-Hurwisz-Uzawa. Additionally, there is a wrapper for all gradient based optimizer routines in scipy.optimize (imagingbase.solvers.scipy_solver.Minimize).
